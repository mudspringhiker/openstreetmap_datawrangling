# %% [markdown]
# # P3: Wrangle OpenStreetMap Data

# %% [markdown]
# ## Data
#
# The map area I chose is the Austin, TX area. As delineated in the class, I obtained the data by downloading an already-prepared extract which I found in the link below:
#
# https://mapzen.com/data/metro-extracts/metro/austin_texas/
#
# I chose the 66MB raw OpenStreetMap OSM XML dataset. After unzipping the file, it gave about 1.4 GB dataset. Opening this dataset using Sublime took a while.

# %% [markdown]
# ### Preliminary examination of the dataset
#
# This is done to see how the data looks like.

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re

# %%
street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_types = defaultdict(int)

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        street_types[street_type] += 1

# %%
def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k,v)

# %%
def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")

# %%
osmfile = "austin_texas.osm"

# %%
for event, element in ET.iterparse(osmfile):
    if is_street_name(element):
        audit_street_type(street_types, element.attrib['v'])
print_sorted_dict(street_types)
# Out:
# #100: 2
# #101: 1
# #104: 1
# #150: 1
# #203: 2
# #260: 1
# #300: 2
# #3000a: 1
# #306: 1
# #4: 1
# #406: 1
# #600: 1
# #8: 1
# #B100: 1
# #F-4: 1
# #G-145: 1
# #L2: 1
# 100: 2
# 104: 1
# 1100: 45
# 117: 1
# 12: 8
# 120: 1
# 129: 11
# 1327: 61
# 138: 3
# 1431: 121
# 150: 2
# 1625: 76
# 1626: 91
# 163: 1
# 170: 1
# 1805: 1
# 1825: 1
# 1826: 57
# 183: 7
# 213: 1
# 2222: 68
# 2243: 2
# 2244: 1
# 275: 1
# 2769: 163
# 280: 3
# 290: 333
# 298: 1
# 3: 1
# 301: 2
# 3177: 1
# 320: 1
# 35: 25
# 400: 1
# 414: 1
# 45: 1
# 452: 1
# 459: 6
# 535: 2
# 6: 1
# 619: 1
# 620: 551
# 685: 5
# 7: 1
# 71: 17
# 79: 1
# 8: 1
# 812: 176
# 969: 2
# 973: 170
# A: 76
# A-15: 1
# A500: 1
# Acres: 16
# Adventurer: 2
# Affirmed: 7
# Alley: 44
# Alps: 15
# Alto: 28
# Amistad: 26
# Apache: 6
# Arbolago: 21
# Arrow: 17
# Atlantic: 11
# Austin: 1
# Ave: 33
# Ave.: 1
# Avene: 1
# Avenue: 15891
# B: 105
# Barrhead: 12
# Bend: 1777
# Birch: 12
# Blackfoot: 7
# Bluff: 41
# Blvd: 25
# Blvd.: 6
# Boggy: 4
# Bonanza: 20
# Bonita: 18
# Bottom: 1
# Boulevard: 8759
# Branch: 17
# Bridge: 26
# Buckskin: 1
# C: 127
# C-200: 1
# C1-100: 1
# Caliche: 5
# Calle: 24
# Camelback: 6
# Camino: 27
# Cannon: 1
# Cantera: 11
# Canterwood: 27
# Canyon: 79
# Capri: 22
# Carrara: 1
# Casitas: 79
# Castle: 22
# CastlePath: 7
# Catcher: 64
# Catorce: 25
# Cave: 37
# Cc: 16
# Challenger: 121
# Chase: 144
# Chavez: 1
# Circle: 10816
# Clark: 5
# Claro: 6
# Claw: 8
# Clearwater: 4
# Range: 21
# Raphael: 3
# Ravine: 4
# Rd: 105
# Real: 5
# Reinhardt: 24
# Ridge: 548
# River: 2
# RM1431: 18
# Road: 26561
# Road,1100: 1
# Rock: 3
# Roost: 14
# Rope: 45
# Rose: 5
# Row: 139
# Royale: 13
# Run: 1158
# Saddles: 9
# Sage: 7
# Sandpiper: 1
# SB: 2
# Season: 24
# Seawind: 45
# Seco: 39
# Sidewinder: 22
# Silence: 30
# Sioux: 5
# Sky: 6
# Skyline: 45
# Skyview: 37
# Skyway: 131
# Slew: 11
# South: 151
# Southview: 1
# Speedway: 203
# Spicewood: 1
# Spring: 28
# Springwater: 4
# Spur: 26
# Square: 181
# St: 15
# St.: 5
# Stakes: 13
# Station: 1
# Stonebridge: 9
# Stonehedge: 7
# street: 46
# Street: 33851
# Strip: 11
# suite#L131: 1
# Summit: 6
# Sundown: 22
# Sunfish: 116
# Sunterro: 16
# Sutton: 1
# Tahoe: 3
# Talamore: 8
# Tarlton: 1
# Tealwood: 18
# Terrace: 1478
# Terrance: 21
# texas: 1
# Thunder: 17
# Thunderbird: 92
# Tiempo: 19
# Toro: 8
# Tr: 61
# Trace: 454
# Track: 34
# Trail: 17676
# Triangle: 7
# Trl: 108
# Tropez: 38
# Tundra: 24
# Turn: 7
# Turnback: 27
# Vale: 61
# Valley: 60
# Van: 31
# Vanguard: 86
# Verde: 94
# Verdes: 48
# Viejo: 22
# Viento: 37
# View: 202
# Vista: 84
# Voyageurs: 14
# W: 5
# Walk: 203
# Way: 6773
# way: 1
# West: 112
# Wheel: 9
# William: 24
# Willo: 14
# Withers: 6
# Wood: 20
# Woods: 45
# Wow: 2
# Wren: 37
# Yard: 36
# York: 15

# %% [markdown]
# ##### From above, we can see that there are street names that need to be fixed.
#
# Avenue, Ave., Ave, and Avene
#
# Boulevard, Blvd, Blvd.
#
# Circle, Cc(?)
#
# Costa, Corta(?)
#
# Court, court, Ct
#
# Cove, cove, Cv
#
# Drive, Dr, Dr.
#
# "Drive/Rd"?
#
# Highway <= Hwy
#
# FM1431, 1431, RM1431
#
# I35, IH-35, IH35, IH35,
#
# Lane, lane, Lanes(?), Ln
#
# Pass, pass
#
# Parkway, Pkwy
#
# Place, Pl
#
# Overlook, Ovlk
#
# North, N(?)
#
# Ps(?)
#
# Road, Rd, "Road,1100"
#
# SB?
#
# St, St. street, Street
#
# Trail, Tr, Trl
#
# West, W
#
# Way, way

# %% [markdown]
# ## High Level Tags

# %% [markdown]
# To determine the number of high level tags the dataset has, iterative parsing is done.

# %%
import pprint

# %%
def count_tags(filename):
    tag_counts = defaultdict(int)
    for event, elem in ET.iterparse(filename):
        tag_counts[elem.tag] += 1
    return tag_counts

# %%
tags = count_tags(osmfile)

# %%
pprint.pprint(dict(tags))
# Out:
# {'bounds': 1,
#  'member': 20197,
#  'nd': 6985591,
#  'node': 6356394,
#  'osm': 1,
#  'relation': 2357,
#  'tag': 2377504,
#  'way': 666390}

# %% [markdown]
# ## Checking the k values

# %%
import re

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
def key_type(element, keys):
    if element.tag == 'tag':
        try:
            lower.search(element.attrib['k']).group()
            keys["lower"] += 1
        except AttributeError:
            try:
                lower_colon.search(element.attrib['k']).group()
                keys["lower_colon"] += 1
            except AttributeError:
                try:
                    problemchars.search(element.attrib['k']).group()
                    keys["problemchars"] += 1
                except AttributeError:
                    keys["other"] += 1
    return keys

# %%
def process_map_tagtypes(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other":0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
    return keys

# %%
keys = process_map_tagtypes(osmfile)

# %%
pprint.pprint(keys)
# Out:
# {'lower': 1297812, 'lower_colon': 1067727, 'other': 11964, 'problemchars': 1}

# %% [markdown]
# ## Exploring Users

# %%
def get_user(element):
    return

# %%
def process_map_users(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for key in element.attrib:
            if key == 'uid':
                users.add(element.attrib[key])
    return users

# %%
users = process_map_users(osmfile)

# %%
len(users)
# Out:
# 1155

# %% [markdown]
# ## Auditing and Improving Street Names

# %% [markdown]
# Auditing the osmfile and using the variable 'mapping', check to see the changes needed to fix the unexpected street types to the appropriate ones in the expected list.

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

# %%
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Cove", "Highway", "Lane"]

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

# %%
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

# %%
def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

# %%
st_types = audit(osmfile)

# %%
mapping = { "St": "Street",
            "St.": "Street",
            "st": "Street",
            "street": "Street",
            "Street,": "Street",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "Avene": "Avenue",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Boulevard,": "Boulevard",
            "Blvd,": "Boulevard",
            "Blvd.,": "Boulevard",
            "Dr": "Drive",
            "Dr.": "Drive",
            "Ct": "Court",
            "Ct.": "Court",
            "court": "Court",
            "Cv": "Cove",
            "cove": "Cove",
            "Cc": "Cove",
            "Pl": "Place",
            "Pl.": "Place",
            "lane": "Lane",
            "Ln": "Lane",
            "Rd": "Road", 
            "Rd.": "Road",
            "R": "Road",
            "Trl": "Trail",
            "Tr": "Trail",
            "Pkwy": "Parkway",
            "Hwy": "Highway",
            "HWY": "Highway",
            "Hwy,": "Highway",
            "H": "Highway",
            "I35": "Interstate Highway 35",
            "IH35": "Interstate Highway 35",
            "IH35,": "Interstate Highway 35",
            "IH-35": "Interstate Highway 35",
            "I-35": "Interstate Highway 35",
            "IH": "Interstate Highway",
            "I": "Interstate",
            "35,": "35",
            "main": "Main",
            "N": "North",
            "N.": "North",
            "Ovlk": "Overlook",
            "pass": "Pass",
            "Ps": "Pass",
            "W": "West",
            "W.": "West",
            "E": "East",
            "E.": "East",
            "texas": "Texas",
            "TX": "Texas",
            "FM": "Farm-to-Market Road",
            "F.M.": "Farm-to-Market Road",
            "U.S.": "United States",
            "US": "United States",
            "RM": "Ranch-to-Market Road",
            "RM1431": "Ranch-to-Market Road 1431",
            "RR": "Ranch Road",
            "S": "South",
            "S.": "South",
            "south": "South",
            "Bldg": "Building",
            "Bldg.": "Building",
            "Bld": "Building",
            "Ste": "Suite",
            "Ste,": "Suite",
            "STE": "Suite",
            "Ste.": "Suite",
            "suite": "Suite",
            "C": "Country",
            "church": "Church",
            "brigadoon": "Brigadoon",
            "Drive/Rd": "Drive/Road",
            "Mo-Pac": "MoPac", 
            "Avenue,Ste": "Avenue Suite",
            "suite#L131": "Suite L131"}

# %%
def append_highway(name):
    newparts = []
    parts = name.split()
    for item in parts:
        if (item == "Interstate" or item == "States") and "Highway" not in parts:
            newparts.append(item)
            newparts.append("Highway")
        else:
            newparts.append(item)
    new_name = ' '.join(newparts)
    return new_name

# %%
def update_farm_ranch_to_market(name):
    parts = name.split()
    if "Farm-to-Market" in parts or "Ranch-to-Market" in parts:
        if "Road" in parts:
            return name
        else:
            try:
                parts.insert(parts.index("Farm-to-Market")+1, "Road")
                name = " ".join(parts)
            except ValueError:
                parts.insert(parts.index("Ranch-to-Market")+1, "Road")  
                name = " ".join(parts)
    elif "Farm" in parts and "to" in parts and "Market" in parts:
        newname = []
        for i in range(parts.index("Farm")):
            newname.append(parts[parts.index(i)])
        newname.append("Farm-to-Market")
        newname += parts[parts.index("Market")+1:]

        if "Road" in parts:
            name = " ".join(newname)
        else:
            newname.insert(newname.index("Farm-to-Market")+1,"Road")
            name = " ".join(newname)
    
    elif "Ranch" in parts and "to" in parts and "Market" in parts:
        newname = []
        for i in range(parts.index("Ranch")):
            newname.append(parts[parts.index(i)])
        newname.append("Ranch-to-Market")
        newname += parts[parts.index("Market")+1:]

        if "Road" in parts:
            name = " ".join(newname)
        else:
            newname.insert(newname.index("Ranch-to-Market")+1,"Road")
            name = " ".join(newname)
        
    return name

# %%
update_farm_ranch_to_market("Farm-to-Market 620 N")
# Out:
# 'Farm-to-Market Road 620 N'

# %%
update_farm_ranch_to_market("werwelrj")
# Out:
# 'werwelrj'

# %%
update_farm_ranch_to_market("Ranch to Market 620 N")
# Out:
# 'Ranch-to-Market Road 620 N'

# %%
name = "Farm to Market 620 N"

# %%
parts = name.split()
parts
# Out:
# ['Farm', 'to', 'Market', '620', 'N']

# %%
["Farm", "to", "Market"] in parts
# Out:
# False

# %%
def update_name(name, mapping):
    parts = name.split()
    newparts = []
    for item in parts:
        if item == "St" and "Rue" in parts:
            newparts.append("Saint")
        elif item == "N" or item == "C" or item == "I" or item == "H": 
            try:
                if newparts[0] == "Avenue":
                    newparts.append(item)
                else:
                    newparts.append(mapping[item])
            except IndexError:
                newparts.append(mapping[item])
        else:
            if item in mapping.keys():
                newparts.append(mapping[item])
            else:
                newparts.append(item)
    name = ' '.join(newparts)
    name = append_highway(name)
    name = update_farm_ranch_to_market(name)
    return name

# %%
update_farm_ranch_to_market("Farm to Market 620 N")
# Out:
# 'Farm to Market 620 N'

# %%
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# Merimac => Merimac
# Clara Van => Clara Van
# Capri => Capri
# Chelsea Moor => Chelsea Moor
# Royal Birkdale Ovlk => Royal Birkdale Overlook
# Lions Lair => Lions Lair
# Apache => Apache
# Farm-to-Market Road 812 => Farm-to-Market Road 812
# Bee Cave Road Suite 163 => Bee Cave Road Suite 163
# Adventurer => Adventurer
# Affirmed => Affirmed
# West 35th Street Cutoff => West 35th Street Cutoff
# Ferguson Cutoff => Ferguson Cutoff
# House Wren => House Wren
# N I-35 Suite 298 => North Interstate Highway 35 Suite 298
# Melody => Melody
# East Highway 290 => East Highway 290
# Quail Cover Circle => Quail Cover Circle
# Briar Wood Circle => Briar Wood Circle
# Gateshead Circle => Gateshead Circle
# Post Oak Circle => Post Oak Circle
# Lee Sage Circle => Lee Sage Circle
# Westledge Circle => Westledge Circle
# Sweeney Circle => Sweeney Circle
# Three Oaks Circle => Three Oaks Circle
# Hamilton Point Circle => Hamilton Point Circle
# Woodbrook Circle => Woodbrook Circle
# Paloma Circle => Paloma Circle
# Abbate Circle => Abbate Circle
# Soft Wind Circle => Soft Wind Circle
# Knight Circle => Knight Circle
# Ardmore Circle => Ardmore Circle
# Earl Circle => Earl Circle
# Berrylawn Circle => Berrylawn Circle
# Caisson Circle => Caisson Circle
# Taline Circle => Taline Circle
# Dawnridge Circle => Dawnridge Circle
# Palmetto Circle => Palmetto Circle
# Desert Oak Circle => Desert Oak Circle
# Bexton Circle => Bexton Circle
# Penelope Circle => Penelope Circle
# Lakepoint Circle => Lakepoint Circle
# Summer Circle => Summer Circle
# Indio Circle => Indio Circle
# Glenview Circle => Glenview Circle
# Timberwood Circle => Timberwood Circle
# Kollmeyer Circle => Kollmeyer Circle
# Jill Sue Circle => Jill Sue Circle
# Birdlip Circle => Birdlip Circle
# Fox Chase Circle => Fox Chase Circle
# Centimeter Circle => Centimeter Circle
# Manor Circle => Manor Circle
# Aguila Circle => Aguila Circle
# Cliff Circle => Cliff Circle
# Cedarlawn Circle => Cedarlawn Circle
# Valley Hill Circle => Valley Hill Circle
# Geneva Circle => Geneva Circle
# Blinn Circle => Blinn Circle
# Inspiration Circle => Inspiration Circle
# Sea Ash Circle => Sea Ash Circle
# Overlook Circle => Overlook Circle
# Park Circle => Park Circle
# Hillview Circle => Hillview Circle
# Mistyglen Circle => Mistyglen Circle
# Berry Hill Circle => Berry Hill Circle
# Darvone Circle => Darvone Circle
# Spruceleaf Circle => Spruceleaf Circle
# Belo Horizonte Circle => Belo Horizonte Circle
# Stoneham Circle => Stoneham Circle
# Kentshire Circle => Kentshire Circle
# Sparkling Creek Circle => Sparkling Creek Circle
# Pistol Pass Circle => Pistol Pass Circle
# Hood Circle => Hood Circle
# Framingham Circle => Framingham Circle
# Tamarisk Circle => Tamarisk Circle
# Dry Run Circle => Dry Run Circle
# Manana Mountain Circle => Manana Mountain Circle
# Rock Terrace Circle => Rock Terrace Circle
# Manchester Circle => Manchester Circle
# Oak Cliff Circle => Oak Cliff Circle
# Valencia Circle => Valencia Circle
# Galliano Circle => Galliano Circle
# Townesouth Circle => Townesouth Circle
# Cromwell Circle => Cromwell Circle
# Silver Dollar Circle => Silver Dollar Circle
# Paseo de Vaca Circle => Paseo de Vaca Circle
# Donovan Circle => Donovan Circle
# Terra Oak Circle => Terra Oak Circle
# River Crossing Circle => River Crossing Circle
# Howden Circle => Howden Circle
# Leesburg Circle => Leesburg Circle
# Range Oak Circle => Range Oak Circle
# Minda Circle => Minda Circle
# The Circle => The Circle
# Flagstaff Circle => Flagstaff Circle
# Bluffridge Circle => Bluffridge Circle
# Southill Circle => Southill Circle
# Sandy Meadow Circle => Sandy Meadow Circle
# North Ridge Circle => North Ridge Circle
# Crosby Circle => Crosby Circle
# Pond View Circle => Pond View Circle
# Garcreek Circle => Garcreek Circle
# Mecca Circle => Mecca Circle
# Stoutwood Circle => Stoutwood Circle
# Twin Valley Circle => Twin Valley Circle
# Garrison Circle => Garrison Circle
# Fairlake Circle => Fairlake Circle
# Leaf Circle => Leaf Circle
# Chittim Circle => Chittim Circle
# Barton Point Circle => Barton Point Circle
# Joshua Tree Circle => Joshua Tree Circle
# Talon Circle => Talon Circle
# Belmont Circle => Belmont Circle
# Mooring Circle => Mooring Circle
# Celeste Circle => Celeste Circle
# Sandshof Circle => Sandshof Circle
# Chase Circle => Chase Circle
# Brandywine Circle => Brandywine Circle
# Willowbridge Circle => Willowbridge Circle
# Crest Ridge Circle => Crest Ridge Circle
# Denell Circle => Denell Circle
# Caravan Circle => Caravan Circle
# Marston Circle => Marston Circle
# Masters Circle => Masters Circle
# Mountbatten Circle => Mountbatten Circle
# Cadiz Circle => Cadiz Circle
# Murillo Circle => Murillo Circle
# Burly Oak Circle => Burly Oak Circle
# Quicksilver Circle => Quicksilver Circle
# Springmail Circle => Springmail Circle
# Tom Kite Circle => Tom Kite Circle
# Oak Meadow Circle => Oak Meadow Circle
# Deercreek Circle => Deercreek Circle
# Mosquero Circle => Mosquero Circle
# Beartree Circle => Beartree Circle
# Stage Stop Circle => Stage Stop Circle
# Stubble Quail Circle => Stubble Quail Circle
# Hitching Post Circle => Hitching Post Circle
# Park Thirty Five Circle => Park Thirty Five Circle
# Treaty Oak Circle => Treaty Oak Circle
# Brownlee Circle => Brownlee Circle
# Plumcreek Circle => Plumcreek Circle
# Hidden View Circle => Hidden View Circle
# Alcorn Circle => Alcorn Circle
# Ashland Circle => Ashland Circle
# Tahoe Parke Circle => Tahoe Parke Circle
# Lakefront Circle => Lakefront Circle
# Mesa Trails Circle => Mesa Trails Circle
# Coronado Circle => Coronado Circle
# Strader Circle => Strader Circle
# Stone Ridge Circle => Stone Ridge Circle
# Masthead Circle => Masthead Circle
# Bighorn Circle => Bighorn Circle
# Leaning Rock Circle => Leaning Rock Circle
# Radam Circle => Radam Circle
# Lakeview Circle => Lakeview Circle
# Burning Tree Circle => Burning Tree Circle
# Terraza Circle => Terraza Circle
# Silver Circle => Silver Circle
# Canyon Glen Circle => Canyon Glen Circle
# Canard Circle => Canard Circle
# Bronco Circle => Bronco Circle
# Holly Oak Circle => Holly Oak Circle
# Mosswood Circle => Mosswood Circle
# Brook Valley Circle => Brook Valley Circle
# Debba Circle => Debba Circle
# Chimney Creek Circle => Chimney Creek Circle
# Hyclimb Circle => Hyclimb Circle
# Seneca Circle => Seneca Circle
# Phillips Circle => Phillips Circle
# Tiber Circle => Tiber Circle
# Cedar Springs Circle => Cedar Springs Circle
# Hanging Oak Circle => Hanging Oak Circle
# Monmouth Circle => Monmouth Circle
# Lambert Circle => Lambert Circle
# Westbluff Circle => Westbluff Circle
# Silverhill Circle => Silverhill Circle
# Bruno Circle => Bruno Circle
# Encino Circle => Encino Circle
# Amy Circle => Amy Circle
# Skyway Circle => Skyway Circle
# Quartz Circle => Quartz Circle
# Round Mountain Circle => Round Mountain Circle
# Sambuca Circle => Sambuca Circle
# Birdwood Circle => Birdwood Circle
# Cliffwood Circle => Cliffwood Circle
# Map Circle => Map Circle
# Poteau Circle => Poteau Circle
# Paddington Circle => Paddington Circle
# Lazy Brook Circle => Lazy Brook Circle
# Wisteria Circle => Wisteria Circle
# Bolles Circle => Bolles Circle
# Dymalor Circle => Dymalor Circle
# Mandeville Circle => Mandeville Circle
# Oak Creek Circle => Oak Creek Circle
# Village Circle => Village Circle
# Gentilly Circle => Gentilly Circle
# Emerald Forest Circle => Emerald Forest Circle
# Cherry Tree Circle => Cherry Tree Circle
# Oliver Circle => Oliver Circle
# Egret Circle => Egret Circle
# Bunratty Circle => Bunratty Circle
# Orangewood Circle => Orangewood Circle
# Fountainbleu Circle => Fountainbleu Circle
# Cloudberry Circle => Cloudberry Circle
# Zopilote Circle => Zopilote Circle
# Mansfield Circle => Mansfield Circle
# Riata Vista Circle => Riata Vista Circle
# Overland Hills Circle => Overland Hills Circle
# Santa Cruz Circle => Santa Cruz Circle
# Quail Hill Circle => Quail Hill Circle
# Hyland Circle => Hyland Circle
# Transit Circle => Transit Circle
# Ridgeview Circle => Ridgeview Circle
# Chama Circle => Chama Circle
# Lost Ridge Circle => Lost Ridge Circle
# Dupree Circle => Dupree Circle
# Mission Hill Circle => Mission Hill Circle
# Belclaire Circle => Belclaire Circle
# Gem Circle => Gem Circle
# Travis Country Circle => Travis Country Circle
# Bluebonnet Circle => Bluebonnet Circle
# Apple Valley Circle => Apple Valley Circle
# Bat Hawk Circle => Bat Hawk Circle
# Canteen Circle => Canteen Circle
# Pinto Circle => Pinto Circle
# Timothy Circle => Timothy Circle
# Trone Circle => Trone Circle
# Valiant Circle => Valiant Circle
# Marks Circle => Marks Circle
# Hillspring Circle => Hillspring Circle
# Cade Circle => Cade Circle
# Bundyhill Circle => Bundyhill Circle
# Spiceland Circle => Spiceland Circle
# Juno Circle => Juno Circle
# Fora Circle => Fora Circle
# Rabbit Run Circle => Rabbit Run Circle
# Meadgreen Circle => Meadgreen Circle
# Windshill Circle => Windshill Circle
# Fathom Circle => Fathom Circle
# Benwick Circle => Benwick Circle
# Fawnridge Circle => Fawnridge Circle
# Spancreek Circle => Spancreek Circle
# Goeth Circle => Goeth Circle
# Cardinal Hill Circle => Cardinal Hill Circle
# Hidden Hill Circle => Hidden Hill Circle
# Breezeknoll Circle => Breezeknoll Circle
# Silverarrow Circle => Silverarrow Circle
# Bridlington Circle => Bridlington Circle
# Eleos Circle => Eleos Circle
# Willowood Circle => Willowood Circle
# Artesian Circle => Artesian Circle
# Diamond Head Circle => Diamond Head Circle
# Twin Ledge Circle => Twin Ledge Circle
# Mystic Oaks Circle => Mystic Oaks Circle
# Cornish Circle => Cornish Circle
# Merion Cricket Circle => Merion Cricket Circle
# Shumard Circle => Shumard Circle
# Colmenero Circle => Colmenero Circle
# Hilwin Circle => Hilwin Circle
# Knollpark Circle => Knollpark Circle
# Silverado Circle => Silverado Circle
# Buckhorn Circle => Buckhorn Circle
# Creeks Edge Circle => Creeks Edge Circle
# Grand Oak Circle => Grand Oak Circle
# Rising Hills Circle => Rising Hills Circle
# Dime Circle => Dime Circle
# Villa Oaks Circle => Villa Oaks Circle
# Nob Hill Circle => Nob Hill Circle
# Founders Circle => Founders Circle
# Live Oak Circle => Live Oak Circle
# Vigen Circle => Vigen Circle
# Hymeadow Circle => Hymeadow Circle
# Sunset Heights Circle => Sunset Heights Circle
# Lime Stone Circle => Lime Stone Circle
# Green Shore Circle => Green Shore Circle
# Rockwood Circle => Rockwood Circle
# Berwyn Circle => Berwyn Circle
# Mason Dixon Circle => Mason Dixon Circle
# Lakeridge Circle => Lakeridge Circle
# Windmill Circle => Windmill Circle
# Indian Quail Circle => Indian Quail Circle
# Glazier Circle => Glazier Circle
# Salt Block Circle => Salt Block Circle
# Silverplume Circle => Silverplume Circle
# Robinwood Circle => Robinwood Circle
# Orchard Park Circle => Orchard Park Circle
# Squirrel Oak Circle => Squirrel Oak Circle
# Valley High Circle => Valley High Circle
# Williamsburg Circle => Williamsburg Circle
# Candleberry Circle => Candleberry Circle
# Scenic Oaks Circle => Scenic Oaks Circle
# Honeycomb Rock Circle => Honeycomb Rock Circle
# Antelope Circle => Antelope Circle
# Harwill Circle => Harwill Circle
# Mini Circle => Mini Circle
# Thames Circle => Thames Circle
# Aberdeen Circle => Aberdeen Circle
# Alazan Circle => Alazan Circle
# Tophill Circle => Tophill Circle
# Socorro Circle => Socorro Circle
# Cree Circle => Cree Circle
# Laurel Creek Circle => Laurel Creek Circle
# Commodore Circle => Commodore Circle
# Leaning Oak Circle => Leaning Oak Circle
# Honeycomb Circle => Honeycomb Circle
# Mc Carthy Circle => Mc Carthy Circle
# Bent Oak Circle => Bent Oak Circle
# Silvercrest Circle => Silvercrest Circle
# Valleyridge Circle => Valleyridge Circle
# Clemente Circle => Clemente Circle
# Bunyon Circle => Bunyon Circle
# Highland Hills Circle => Highland Hills Circle
# Javelina Circle => Javelina Circle
# Meadow Creek Circle => Meadow Creek Circle
# Verde Bank Circle => Verde Bank Circle
# Lakeland Circle => Lakeland Circle
# North Scout Island Circle => North Scout Island Circle
# Sagebrush Circle => Sagebrush Circle
# Montoya Circle => Montoya Circle
# Grove Crest Circle => Grove Crest Circle
# Lomita Verde Circle => Lomita Verde Circle
# Carefree Circle => Carefree Circle
# Vinca Circle => Vinca Circle
# Welland Circle => Welland Circle
# Rampart Circle => Rampart Circle
# Sunset Circle => Sunset Circle
# Jekel Circle => Jekel Circle
# Hubbard Circle => Hubbard Circle
# Windy Trail Circle => Windy Trail Circle
# Konstanty Circle => Konstanty Circle
# Woodmoor Circle => Woodmoor Circle
# Gunsmoke Circle => Gunsmoke Circle
# Sage Hen Circle => Sage Hen Circle
# Culebra Circle => Culebra Circle
# Abbey Circle => Abbey Circle
# Matador Circle => Matador Circle
# East Leslie Circle => East Leslie Circle
# Oakwood Circle => Oakwood Circle
# Cooper Circle => Cooper Circle
# Partage Circle => Partage Circle
# Mathis Circle => Mathis Circle
# Mesa Verde Circle => Mesa Verde Circle
# Kafka Circle => Kafka Circle
# Spotted Owl Circle => Spotted Owl Circle
# Cypress Knee Circle => Cypress Knee Circle
# Fort Sumter Circle => Fort Sumter Circle
# Ironwood Circle => Ironwood Circle
# Randy Circle => Randy Circle
# Bull Run Circle => Bull Run Circle
# Beckett Circle => Beckett Circle
# Prairie Dove Circle => Prairie Dove Circle
# Barranca Circle => Barranca Circle
# Westslope Circle => Westslope Circle
# Eanes Circle => Eanes Circle
# Dorsett Oaks Circle => Dorsett Oaks Circle
# Northland Circle => Northland Circle
# Crownspoint Circle => Crownspoint Circle
# Maplewood Circle => Maplewood Circle
# Burnside Circle => Burnside Circle
# Red Oak Circle => Red Oak Circle
# Golden Hills Circle => Golden Hills Circle
# Iguana Circle => Iguana Circle
# Tawny Circle => Tawny Circle
# Arronimink Circle => Arronimink Circle
# Cottonwood Circle => Cottonwood Circle
# Aldford Circle => Aldford Circle
# Tolstoy Circle => Tolstoy Circle
# Gungrove Circle => Gungrove Circle
# Pringle Circle => Pringle Circle
# Boca Chica Circle => Boca Chica Circle
# Endeavor Circle => Endeavor Circle
# Laurel Circle => Laurel Circle
# Dawn Hill Circle => Dawn Hill Circle
# Village Trail Circle => Village Trail Circle
# Willowwick Circle => Willowwick Circle
# Marlborough Circle => Marlborough Circle
# Disraeli Circle => Disraeli Circle
# Brookwood Circle => Brookwood Circle
# Coral Ridge Circle => Coral Ridge Circle
# Sunnylawn Circle => Sunnylawn Circle
# Baxter Circle => Baxter Circle
# Village Creek Circle => Village Creek Circle
# Oakmountain Circle => Oakmountain Circle
# Cone Circle => Cone Circle
# Timber Creek Circle => Timber Creek Circle
# Saddle Circle => Saddle Circle
# Union Circle => Union Circle
# Sam Houston Circle => Sam Houston Circle
# Saint John's Circle => Saint John's Circle
# Blueberry Circle => Blueberry Circle
# Lyra Circle => Lyra Circle
# Meadow Circle => Meadow Circle
# Citation Circle => Citation Circle
# Cocao Circle => Cocao Circle
# Parkview Circle => Parkview Circle
# Butler Circle => Butler Circle
# Glowworm Circle => Glowworm Circle
# Summer Wind Circle => Summer Wind Circle
# Rockingham Circle => Rockingham Circle
# Woodlake Circle => Woodlake Circle
# Rockcrest Circle => Rockcrest Circle
# Bluebell Circle => Bluebell Circle
# Enclave Mesa Circle => Enclave Mesa Circle
# Prestonwood Circle => Prestonwood Circle
# Rustling Circle => Rustling Circle
# Spotted Fawn Circle => Spotted Fawn Circle
# Mustang Island Circle => Mustang Island Circle
# Elm Grove Circle => Elm Grove Circle
# De Soto Circle => De Soto Circle
# Cedar Ridge Circle => Cedar Ridge Circle
# Gallo Circle => Gallo Circle
# Chatsworth Circle => Chatsworth Circle
# Minot Circle => Minot Circle
# Silverleaf Circle => Silverleaf Circle
# Pebblestone Circle => Pebblestone Circle
# Bee Hill Circle => Bee Hill Circle
# Chalet Circle => Chalet Circle
# Wilton Circle => Wilton Circle
# Dueling Oak Circle => Dueling Oak Circle
# Headway Circle => Headway Circle
# Helmway Circle => Helmway Circle
# Pescado Circle => Pescado Circle
# Mountain Villa Circle => Mountain Villa Circle
# Clearsky Circle => Clearsky Circle
# Knollwood Circle => Knollwood Circle
# Glenhaven Circle => Glenhaven Circle
# Craybrough Circle => Craybrough Circle
# Current Circle => Current Circle
# Huntridge Circle => Huntridge Circle
# Brock Circle => Brock Circle
# Oxbow Circle => Oxbow Circle
# Teck Circle => Teck Circle
# Dumaine Circle => Dumaine Circle
# Thurgood Circle => Thurgood Circle
# Wildwood Circle => Wildwood Circle
# Wild Oak Circle => Wild Oak Circle
# Cherrylawn Circle => Cherrylawn Circle
# Ledgerock Circle => Ledgerock Circle
# Deep Circle => Deep Circle
# Dillard Circle => Dillard Circle
# Mountain Top Circle => Mountain Top Circle
# Begonia Circle => Begonia Circle
# Chukar Circle => Chukar Circle
# Star Grass Circle => Star Grass Circle
# Stonecliff Circle => Stonecliff Circle
# Clarewood Circle => Clarewood Circle
# Tern Circle => Tern Circle
# Waterton Parke Circle => Waterton Parke Circle
# Timber Circle => Timber Circle
# Poe Circle => Poe Circle
# Wood Ibis Circle => Wood Ibis Circle
# Hundred Oaks Circle => Hundred Oaks Circle
# Arbor Circle => Arbor Circle
# Metairie Circle => Metairie Circle
# Pinehurst Circle => Pinehurst Circle
# Utah Circle => Utah Circle
# Irongate Circle => Irongate Circle
# Thousand Oaks Circle => Thousand Oaks Circle
# Vista View Circle => Vista View Circle
# Lakeshore Circle => Lakeshore Circle
# Boffi Circle => Boffi Circle
# Stableford Circle => Stableford Circle
# Sandringham Circle => Sandringham Circle
# Blanco Circle => Blanco Circle
# Eric Circle => Eric Circle
# Town Lake Circle => Town Lake Circle
# Shawnee Circle => Shawnee Circle
# Walton Heath Circle => Walton Heath Circle
# Stuart Circle => Stuart Circle
# Devon Circle => Devon Circle
# Bundy Crest Circle => Bundy Crest Circle
# Brown Bluff Circle => Brown Bluff Circle
# Trail Crest Circle => Trail Crest Circle
# Blake Manor Circle => Blake Manor Circle
# Mesa Oaks Circle => Mesa Oaks Circle
# Channing Circle => Channing Circle
# Stonehaven Circle => Stonehaven Circle
# Carbine Circle => Carbine Circle
# Travis Circle => Travis Circle
# Rose Hill Circle => Rose Hill Circle
# Elder Circle => Elder Circle
# Clivden Circle => Clivden Circle
# Marywood Circle => Marywood Circle
# Apple Vista Circle => Apple Vista Circle
# South Ridge Circle => South Ridge Circle
# Westgate Circle => Westgate Circle
# Deer Ridge Circle => Deer Ridge Circle
# Rush Pea Circle => Rush Pea Circle
# Bell Rock Circle => Bell Rock Circle
# Bramble Bush Circle => Bramble Bush Circle
# Towana Circle => Towana Circle
# Big Horn Circle => Big Horn Circle
# Stone Gate Circle => Stone Gate Circle
# Steamline Circle => Steamline Circle
# Oakleaf Circle => Oakleaf Circle
# Wickford Circle => Wickford Circle
# Esplanade Circle => Esplanade Circle
# Running Rope Circle => Running Rope Circle
# Libyan Circle => Libyan Circle
# Barton Village Circle => Barton Village Circle
# Ten Oaks Circle => Ten Oaks Circle
# Greenslope Circle => Greenslope Circle
# Farm to Market 620 N => Farm to Market 620 North
# Calle Limon => Calle Limon
# Creek Mountain => Creek Mountain
# Pecan St. => Pecan Street
# E 38th 1/2 St. => East 38th 1/2 Street
# E. 43rd St. => East 43rd Street
# Camelback => Camelback
# Green Acres => Green Acres
# Clearwater => Clearwater
# Michael Dale => Michael Dale
# Old Walsh Tarlton => Old Walsh Tarlton
# Pasa Tiempo => Pasa Tiempo
# Green Lanes => Green Lanes
# Explorer => Explorer
# N IH 35 Bldg. 6 => North Interstate Highway 35 Building 6
# Gunsmoke => Gunsmoke
# Hambletonian => Hambletonian
# Dream Catcher => Dream Catcher
# Avenue F => Avenue F
# Voyageurs => Voyageurs
# Shepherds Corral => Shepherds Corral
# O K Corral => O K Corral
# Raglan CastlePath => Raglan CastlePath
# FM 1626 => Farm-to-Market Road 1626
# Farm-to-Market Road 1626 => Farm-to-Market Road 1626
# F.M. 1626 => Farm-to-Market Road 1626
# Farm-to-Market Road 1625 => Farm-to-Market Road 1625
# Leafdale Point => Leafdale Point
# Arrowhead Point => Arrowhead Point
# Eagle Point => Eagle Point
# Moss Point => Moss Point
# Craggy Point => Craggy Point
# Klondike Rush Point => Klondike Rush Point
# Hunterwood Point => Hunterwood Point
# Cliff Point => Cliff Point
# Lookout Point => Lookout Point
# Mariners Point => Mariners Point
# Osage Point => Osage Point
# Signal Point => Signal Point
# Blue Jay Point => Blue Jay Point
# Mediterra Point => Mediterra Point
# Kings Point => Kings Point
# Yellow Sage => Yellow Sage
# Mount Bonnell Hollow => Mount Bonnell Hollow
# Beechwood Hollow => Beechwood Hollow
# Wild Cat Hollow => Wild Cat Hollow
# Jessamine Hollow => Jessamine Hollow
# Maury Hollow => Maury Hollow
# Cave Hollow => Cave Hollow
# Dogwood Hollow => Dogwood Hollow
# Cedar Hollow => Cedar Hollow
# Grass Hollow => Grass Hollow
# Firewheel Hollow => Firewheel Hollow
# Hudson Hollow => Hudson Hollow
# Quail Hollow => Quail Hollow
# Balsam Hollow => Balsam Hollow
# Black Mesa Hollow => Black Mesa Hollow
# Lakewood Hollow => Lakewood Hollow
# Pepper Mill Hollow => Pepper Mill Hollow
# Fern Hollow => Fern Hollow
# Bittern Hollow => Bittern Hollow
# Winecup Hollow => Winecup Hollow
# Knapp Hollow => Knapp Hollow
# Turkey Hollow => Turkey Hollow
# Coachwhip Hollow => Coachwhip Hollow
# Sunset Hollow => Sunset Hollow
# Twin Creek Hollow => Twin Creek Hollow
# Salt Mill Hollow => Salt Mill Hollow
# Haley Hollow => Haley Hollow
# Logans Hollow => Logans Hollow
# Brushy Hollow => Brushy Hollow
# Chestnut Hollow => Chestnut Hollow
# Squirrel Hollow => Squirrel Hollow
# Hickory Hollow => Hickory Hollow
# Autumnleaf Hollow => Autumnleaf Hollow
# Big Oak Hollow => Big Oak Hollow
# Hideaway Hollow => Hideaway Hollow
# Red Mesa Hollow => Red Mesa Hollow
# Gardenridge Hollow => Gardenridge Hollow
# Lantana Hollow => Lantana Hollow
# Horseback Hollow => Horseback Hollow
# Hood Hollow => Hood Hollow
# Creek Hollow => Creek Hollow
# Honeycomb Hollow => Honeycomb Hollow
# Sandalwood Hollow => Sandalwood Hollow
# Apple Springs Hollow => Apple Springs Hollow
# Pecan Hollow => Pecan Hollow
# Breeze Hollow => Breeze Hollow
# Gold Flower Hollow => Gold Flower Hollow
# Mill Hollow => Mill Hollow
# Hurst Hollow => Hurst Hollow
# Hidden Hollow => Hidden Hollow
# Secluded Hollow => Secluded Hollow
# Dewberry Hollow => Dewberry Hollow
# Lost Oasis Hollow => Lost Oasis Hollow
# Paintbrush Hollow => Paintbrush Hollow
# Bold Sundown => Bold Sundown
# South I-35 Service SB => South Interstate Highway 35 Service SB
# Mustang => Mustang
# Sendera Bonita => Sendera Bonita
# West Parmer Ln => West Parmer Lane
# Hidden Hills Ln => Hidden Hills Lane
# Calhoun Ln => Calhoun Lane
# Buzz Schneider Ln => Buzz Schneider Lane
# Laguna Seca Ln => Laguna Seca Lane
# Lantana Ln => Lantana Lane
# Sky Ridge Ln => Sky Ridge Lane
# W Braker Ln => West Braker Lane
# W Anderson Ln => West Anderson Lane
# Rocky Top Ln => Rocky Top Lane
# Chick Pea Ln => Chick Pea Lane
# Pfennig Ln => Pfennig Lane
# Pasadera Ln => Pasadera Lane
# Rockwood Ln => Rockwood Lane
# Via Media => Via Media
# Wagon Wheel => Wagon Wheel
# San Jacinto => San Jacinto
# Fleming court => Fleming Court
# West William Cannon => West William Cannon
# Ranch to Market Road 2222 => Ranch to Market Road 2222
# El Viejo Camino => El Viejo Camino
# Springwater => Springwater
# River Birch => River Birch
# Falcon => Falcon
# Eagle Cliff => Eagle Cliff
# Gila Cliff => Gila Cliff
# Avenue A => Avenue A
# 9600 IH 35 C-200 => 9600 Interstate Highway 35 C-200
# Laughing Dog => Laughing Dog
# Running Rope => Running Rope
# Research Blvd #L2 => Research Boulevard #L2
# Fandango => Fandango
# Woody Ridge View => Woody Ridge View
# Hurst View => Hurst View
# Pleasant Panorama View => Pleasant Panorama View
# Valley View => Valley View
# Canyon View => Canyon View
# Rotunda View => Rotunda View
# Key View => Key View
# Summit View => Summit View
# Morning View => Morning View
# Sunset View => Sunset View
# La Fauna View => La Fauna View
# Sea Eagle View => Sea Eagle View
# Panoramic View => Panoramic View
# South Congress Avene => South Congress Avenue
# Highlander => Highlander
# Farm to Market 685 => Farm to Market 685
# FM 685 => Farm-to-Market Road 685
# Stonebridge => Stonebridge
# Burnet Rd Ste, A500 => Burnet Road Suite A500
# Creek Bottom => Creek Bottom
# Gonzales => Gonzales
# S. Capitol of Texas Hwy, #F-4 => South Capitol of Texas Highway #F-4
# Red Pebble Rd => Red Pebble Road
# Barley Rd => Barley Road
# Barton Springs Rd => Barton Springs Road
# Moon Rock Rd => Moon Rock Road
# Bee Creek Rd => Bee Creek Road
# N Interstate 35 Frontage Rd => North Interstate Highway 35 Frontage Road
# Spicewood Springs Rd => Spicewood Springs Road
# Big Meadow Rd => Big Meadow Road
# Palomino Ranch Rd => Palomino Ranch Road
# Commons Rd => Commons Road
# Burnet Rd => Burnet Road
# Tawny Farms Rd => Tawny Farms Road
# Switch Willo => Switch Willo
# Mesa Oaks => Mesa Oaks
# Sierra Oaks => Sierra Oaks
# County Road 138 => County Road 138
# N. Lamar suite#L131 => North Lamar Suite L131
# Longhorn Landing => Longhorn Landing
# Richfield Landing => Richfield Landing
# North Highway 183 #406 => North Highway 183 #406
# North Lakeline Boulevard, Ste. 400 => North Lakeline Boulevard Suite 400
# Portchester Castle Path => Portchester Castle Path
# Tortosa Path => Tortosa Path
# Gato Path => Gato Path
# Santaluz Path => Santaluz Path
# Moccasin Path => Moccasin Path
# Bridle Path => Bridle Path
# Prairie Clover Path => Prairie Clover Path
# Allwood Path => Allwood Path
# Trawood Path => Trawood Path
# La Fauna Path => La Fauna Path
# Peace Pipe Path => Peace Pipe Path
# Petes Path => Petes Path
# Sun Drenched Path => Sun Drenched Path
# Fawn Creek Path => Fawn Creek Path
# Petra Path => Petra Path
# Arena Path => Arena Path
# Trevone Path => Trevone Path
# Comiso Pala Path => Comiso Pala Path
# South Path => South Path
# American Robin Path => American Robin Path
# Glebe Path => Glebe Path
# Lasso Path => Lasso Path
# Tello Path => Tello Path
# Peddle Path => Peddle Path
# Peace on Earth Path => Peace on Earth Path
# Wagon Crossing Path => Wagon Crossing Path
# Great Hills Sierra Nevada Path => Great Hills Sierra Nevada Path
# Coopers Hawk Path => Coopers Hawk Path
# Rim Rock Path => Rim Rock Path
# North Path => North Path
# Parco Path => Parco Path
# Grey Fawn Path => Grey Fawn Path
# Wild Bear Path => Wild Bear Path
# Evening Primrose Path => Evening Primrose Path
# Primwood Path => Primwood Path
# Sidehill Path => Sidehill Path
# Pokealong Path => Pokealong Path
# Woodhill Path => Woodhill Path
# Pebble Run Path => Pebble Run Path
# Periwinkle Path => Periwinkle Path
# Cinnamon Path => Cinnamon Path
# Ursa Major Path => Ursa Major Path
# Craig's Crest Path => Craig's Crest Path
# Monterey Path => Monterey Path
# Garden Rose Path => Garden Rose Path
# Potomac Path => Potomac Path
# Edenvale Path => Edenvale Path
# Ferret Path => Ferret Path
# War Path => War Path
# Sean Avery Path => Sean Avery Path
# West Cow Path => West Cow Path
# Village Path => Village Path
# Glenhollow Path => Glenhollow Path
# Kirkland Hill Path => Kirkland Hill Path
# Navajo Path => Navajo Path
# Pin Oak Path => Pin Oak Path
# Pinto Path => Pinto Path
# Miss Adrienne's Path => Miss Adrienne's Path
# Daisy Path => Daisy Path
# Pebble Path => Pebble Path
# Parell Path => Parell Path
# Cork Path => Cork Path
# Ozarks Path => Ozarks Path
# Nevada Path => Nevada Path
# Stokesay Castle Path => Stokesay Castle Path
# Crown Ridge Path => Crown Ridge Path
# Little Dipper Path => Little Dipper Path
# Circle Haven => Circle Haven
# Troll Haven => Troll Haven
# 9901 N Capital Of texas => 9901 North Capital Of Texas
# E. Whitestone Blvd #G-145 => East Whitestone Boulevard #G-145
# Calle Caliche => Calle Caliche
# High Lonesome => High Lonesome
# Messenger Stakes => Messenger Stakes
# Hill Country Blvd., Suite C1-100 => Hill Country Boulevard Suite C1-100
# Rue de St Tropez => Rue de Saint Tropez
# Twin Saddles => Twin Saddles
# Sandpiper => Sandpiper
# The Living End => The Living End
# Indiana Dunes => Indiana Dunes
# Rock Rose => Rock Rose
# Pow Wow => Pow Wow
# W. Liberty => West Liberty
# FM 619 => Farm-to-Market Road 619
# Paw Print => Paw Print
# Tortilla Flat => Tortilla Flat
# Wet Season => Wet Season
# 1500 S. IH35 => 1500 South Interstate Highway 35
# Prince William => Prince William
# Seawind => Seawind
# N I H 35 Bldg 7 => North Interstate Highway 35 Building 7
# Camino Viejo => Camino Viejo
# RM1431 => Ranch-to-Market Road 1431
# Avenue G => Avenue G
# China Grove => China Grove
# Palma Plaza => Palma Plaza
# Amy Donovan Plaza => Amy Donovan Plaza
# Oak Plaza => Oak Plaza
# North Plaza => North Plaza
# Park Plaza => Park Plaza
# Centre Plaza => Centre Plaza
# I35 => Interstate Highway 35
# La Cantera => La Cantera
# Highway 71 W => Highway 71 West
# Hwy 290 W => Highway 290 West
# Ranch Road 620 North => Ranch Road 620 North
# Lake Hills Drive North => Lake Hills Drive North
# Tumbleweed Trail North => Tumbleweed Trail North
# Summit Ridge Drive North => Summit Ridge Drive North
# Redondo Drive North => Redondo Drive North
# Cowal Drive North => Cowal Drive North
# Meadows Drive North => Meadows Drive North
# Interstate Highway 35 Service Road North => Interstate Highway 35 Service Road North
# Ute Trail North => Ute Trail North
# State Highway 95 North => State Highway 95 North
# Sioux Trail North => Sioux Trail North
# Hideaway North => Hideaway North
# Augusta Drive North => Augusta Drive North
# IH 35 North => Interstate Highway 35 North
# FM 620 North => Farm-to-Market Road 620 North
# Fresco Drive North => Fresco Drive North
# Chesapeake Bay Lane North => Chesapeake Bay Lane North
# Cuernavaca Drive North => Cuernavaca Drive North
# Dunlap Road North => Dunlap Road North
# Ashwood North => Ashwood North
# Venture Boulevard North => Venture Boulevard North
# 5th Street North => 5th Street North
# Weston Lane North => Weston Lane North
# Kettleman Lane North => Kettleman Lane North
# 4th Street North => 4th Street North
# Pace Bend Road North => Pace Bend Road North
# Hillside North => Hillside North
# Highway 95 North => Highway 95 North
# Lowell Lane North => Lowell Lane North
# Laurelwood Drive North => Laurelwood Drive North
# Tandem Blvd. => Tandem Boulevard
# South Lamar Blvd. => South Lamar Boulevard
# South Exposition Blvd. => South Exposition Boulevard
# W North Loop Blvd. => West North Loop Boulevard
# East Old Settlers Blvd. => East Old Settlers Boulevard
# Research Blvd. => Research Boulevard
# Old Farm-to-Market 1431 => Old Farm-to-Market 1431
# Farm-to-Market Road 1431 => Farm-to-Market Road 1431
# Big Horn => Big Horn
# Austrina Pass => Austrina Pass
# San Juan Pass => San Juan Pass
# Chisos Pass => Chisos Pass
# Pack Saddle Pass => Pack Saddle Pass
# Smoke Signal Pass => Smoke Signal Pass
# Petrove Pass => Petrove Pass
# Branding Iron Pass => Branding Iron Pass
# Durango Pass => Durango Pass
# Arrowhead Pass => Arrowhead Pass
# Maulding Pass => Maulding Pass
# Black Gap Pass => Black Gap Pass
# Quadros Pass => Quadros Pass
# Ravello Pass => Ravello Pass
# Berryessa Pass => Berryessa Pass
# Outrider Pass => Outrider Pass
# Serene Hills Pass => Serene Hills Pass
# Jacks Pass => Jacks Pass
# Buckskin Pass => Buckskin Pass
# Raton Pass => Raton Pass
# Kenosha Pass => Kenosha Pass
# Siringo Pass => Siringo Pass
# McCallen Pass => McCallen Pass
# Wild Briar Pass => Wild Briar Pass
# Quiet Water Pass => Quiet Water Pass
# Alegre Pass => Alegre Pass
# Payload Pass => Payload Pass
# Arapahoe Pass => Arapahoe Pass
# Belfry Pass => Belfry Pass
# Oasis Pass => Oasis Pass
# Passionflower Pass => Passionflower Pass
# White Dove Pass => White Dove Pass
# Temecula Pass => Temecula Pass
# Bill Hickcock Pass => Bill Hickcock Pass
# Sailboat Pass => Sailboat Pass
# Salida del Sol Pass => Salida del Sol Pass
# Quitman Pass => Quitman Pass
# Wild Turkey Pass => Wild Turkey Pass
# Sunken Creek Pass => Sunken Creek Pass
# Overlook Pass => Overlook Pass
# Turks Cap Pass => Turks Cap Pass
# Red Deer Pass => Red Deer Pass
# Couri Pass => Couri Pass
# Gunnison Pass => Gunnison Pass
# Highland Pass => Highland Pass
# Overland Pass => Overland Pass
# Dawn River Pass => Dawn River Pass
# Arrowmound Pass => Arrowmound Pass
# Wolfcreek Pass => Wolfcreek Pass
# Pyrenees Pass => Pyrenees Pass
# Covered Wagon Pass => Covered Wagon Pass
# Eagle Pass => Eagle Pass
# Huebinger Pass => Huebinger Pass
# Navajo Pass => Navajo Pass
# Sly Pass => Sly Pass
# Trophy Pass => Trophy Pass
# Pontic Pass => Pontic Pass
# Kiowa Pass => Kiowa Pass
# Montana Ridge Pass => Montana Ridge Pass
# Poppy Pass => Poppy Pass
# Teton Pass => Teton Pass
# Double Eagle Pass => Double Eagle Pass
# Lakota Pass => Lakota Pass
# Sam Maverick Pass => Sam Maverick Pass
# Mid Bark Pass => Mid Bark Pass
# Pawnee Pass => Pawnee Pass
# Ferrystone Pass => Ferrystone Pass
# Maritime Pass => Maritime Pass
# Broken Bow Pass => Broken Bow Pass
# Bloomfield Hills Pass => Bloomfield Hills Pass
# Paul Jones Pass => Paul Jones Pass
# Latigo Pass => Latigo Pass
# High Canyon Pass => High Canyon Pass
# Westlake Pass => Westlake Pass
# Irby Pass => Irby Pass
# Melba Pass => Melba Pass
# Apache Pass => Apache Pass
# Lakewood Hills Pass => Lakewood Hills Pass
# Lone Mountain Pass => Lone Mountain Pass
# Barley Field Pass => Barley Field Pass
# Telegraph Pass => Telegraph Pass
# Masterson Pass => Masterson Pass
# Piedmont Hills Pass => Piedmont Hills Pass
# Clay Allison Pass => Clay Allison Pass
# Bullet Pass => Bullet Pass
# Pavelich Pass => Pavelich Pass
# Breezy Pass => Breezy Pass
# Buffalo Pass => Buffalo Pass
# Hogg Pecan Pass => Hogg Pecan Pass
# Timber Ridge Pass => Timber Ridge Pass
# Dan Pass => Dan Pass
# Gila Pass => Gila Pass
# Trace Creek Pass => Trace Creek Pass
# Gift Horse Pass => Gift Horse Pass
# Corner Brook Pass => Corner Brook Pass
# Crazyhorse Pass => Crazyhorse Pass
# Strontian Pass => Strontian Pass
# Patagonia Pass => Patagonia Pass
# Amber Pass => Amber Pass
# Blanco River Pass => Blanco River Pass
# Continental Pass => Continental Pass
# Timber Pass => Timber Pass
# Kinder Pass => Kinder Pass
# Hunters Pass => Hunters Pass
# Bird Call Pass => Bird Call Pass
# Thornwild Pass => Thornwild Pass
# Platte Pass => Platte Pass
# Splendor Pass => Splendor Pass
# Ebony Hollow Pass => Ebony Hollow Pass
# Davis Mountain Pass => Davis Mountain Pass
# Walton Hill Pass => Walton Hill Pass
# Saddle Back Pass => Saddle Back Pass
# Whitetail Pass => Whitetail Pass
# Grider Pass => Grider Pass
# Long Lasso Pass => Long Lasso Pass
# Barker Hollow Pass => Barker Hollow Pass
# Snowbird Pass => Snowbird Pass
# Wildcat Pass => Wildcat Pass
# Wyoming Pass => Wyoming Pass
# Cielo Azul Pass => Cielo Azul Pass
# Martinique Pass => Martinique Pass
# Overton Pass => Overton Pass
# Billy Bonney Pass => Billy Bonney Pass
# Ruskin Pass => Ruskin Pass
# Deer Pass => Deer Pass
# Plain Rock Pass => Plain Rock Pass
# Cottage Grove Pass => Cottage Grove Pass
# Phoenix Pass => Phoenix Pass
# Lookout Cliff Pass => Lookout Cliff Pass
# Poncha Pass => Poncha Pass
# La Concha Pass => La Concha Pass
# Golddust Pass => Golddust Pass
# Majestic Oaks Pass => Majestic Oaks Pass
# Rio Pass => Rio Pass
# County Road 459 => County Road 459
# RM 620 => Ranch-to-Market Road 620
# FM 620 => Farm-to-Market Road 620
# N FM 620 => North Farm-to-Market Road 620
# Ranch Road 620 => Ranch Road 620
# Ranch-to-Market Road 620 => Ranch-to-Market Road 620
# RR 620 => Ranch Road 620
# Pheasant Roost => Pheasant Roost
# Country Rd. 452 => Country Road 452
# County Road 170 => County Road 170
# Lido => Lido
# Farm-to-Market Road 973 => Farm-to-Market Road 973
# N Farm-To-Market Road 973 => North Farm-To-Market Road 973
# Montana Norte => Montana Norte
# Ladera Norte => Ladera Norte
# Broken Arrow => Broken Arrow
# East Meadow Vale => East Meadow Vale
# US 183 => United States Highway 183
# US Highway 183 => United States Highway 183
# U.S. 183 => United States Highway 183
# N HWY 183 => North Highway 183
# United States Highway 183 => United States Highway 183
# Barton Skyway => Barton Skyway
# Longhorn Skyway => Longhorn Skyway
# Picadilly => Picadilly
# Bachelor Gulch => Bachelor Gulch
# Thunder Gulch => Thunder Gulch
# Grubstake Gulch => Grubstake Gulch
# Hidden Mesa => Hidden Mesa
# Lone Mesa => Lone Mesa
# Spicewood Mesa => Spicewood Mesa
# Mustang Mesa => Mustang Mesa
# Alta Mesa => Alta Mesa
# Via Fortuna => Via Fortuna
# Avenue B => Avenue B
# South Interstate 35, Suite B => South Interstate Highway 35 Suite B
# Chimney Corners => Chimney Corners
# Tall Withers => Tall Withers
# Indian Summit => Indian Summit
# Hitching Post => Hitching Post
# Sidewinder => Sidewinder
# Ranch to Market Road 12 => Ranch to Market Road 12
# Sierra Colorado => Sierra Colorado
# Crescent Bluff => Crescent Bluff
# Bullick Bluff => Bullick Bluff
# Travis Bluff => Travis Bluff
# Scout Bluff => Scout Bluff
# S Capital of Texas Hwy => South Capital of Texas Highway
# Avenue I => Avenue I
# Thunderbird => Thunderbird
# Sylvan Glade => Sylvan Glade
# Rue de St Raphael => Rue de Saint Raphael
# Vista Corta => Vista Corta
# Branding Iron => Branding Iron
# Kyle Crossing => Kyle Crossing
# Roller Crossing => Roller Crossing
# Hidden Lake Crossing => Hidden Lake Crossing
# Colorado Crossing => Colorado Crossing
# Bratton Ridge Crossing => Bratton Ridge Crossing
# Kenter Crossing => Kenter Crossing
# Mackinaw Crossing => Mackinaw Crossing
# Fritz Falls Crossing => Fritz Falls Crossing
# Hammetts Crossing => Hammetts Crossing
# Cloud Mountain Crossing => Cloud Mountain Crossing
# Walnut Park Crossing => Walnut Park Crossing
# Steeds Crossing => Steeds Crossing
# Lady Lauras Crossing => Lady Lauras Crossing
# Mandarin Crossing => Mandarin Crossing
# Kohlers Crossing => Kohlers Crossing
# Dover Ferry Crossing => Dover Ferry Crossing
# Little Deer Crossing => Little Deer Crossing
# West Cave Crossing => West Cave Crossing
# Coaches Crossing => Coaches Crossing
# Campina Crossing => Campina Crossing
# Cherry Hollow Crossing => Cherry Hollow Crossing
# Esperanza Crossing => Esperanza Crossing
# Cliff Crossing => Cliff Crossing
# Hyson Crossing => Hyson Crossing
# Nuckols Crossing => Nuckols Crossing
# Dry Brook Crossing => Dry Brook Crossing
# Surveyors Crossing => Surveyors Crossing
# Brown Juniper => Brown Juniper
# Stillhouse Spring => Stillhouse Spring
# Challenger => Challenger
# Stoneridge Terrace => Stoneridge Terrace
# River Terrace => River Terrace
# Preserve Vista Terrace => Preserve Vista Terrace
# White Rim Terrace => White Rim Terrace
# Kisoba Terrace => Kisoba Terrace
# Tallison Terrace => Tallison Terrace
# Vikki Terrace => Vikki Terrace
# Ledgestone Terrace => Ledgestone Terrace
# Crystal Terrace => Crystal Terrace
# Timarou Terrace => Timarou Terrace
# Theckla Terrace => Theckla Terrace
# Bayridge Terrace => Bayridge Terrace
# Begonia Terrace => Begonia Terrace
# Rosedale Terrace => Rosedale Terrace
# Rockbridge Terrace => Rockbridge Terrace
# Reagan Terrace => Reagan Terrace
# Highland Terrace => Highland Terrace
# Lily Terrace => Lily Terrace
# Carnation Terrace => Carnation Terrace
# Carrizo Terrace => Carrizo Terrace
# Swelfling Terrace => Swelfling Terrace
# Edgecliff Terrace => Edgecliff Terrace
# Niagara Falls Terrace => Niagara Falls Terrace
# Yellowpine Terrace => Yellowpine Terrace
# Arren Terrace => Arren Terrace
# Foothill Terrace => Foothill Terrace
# Norseman Terrace => Norseman Terrace
# Cradlerock Terrace => Cradlerock Terrace
# Larch Terrace => Larch Terrace
# Ski Shores Terrace => Ski Shores Terrace
# Club Terrace => Club Terrace
# Spanish Oak Terrace => Spanish Oak Terrace
# Highland Hills Terrace => Highland Hills Terrace
# Windy Terrace => Windy Terrace
# Eagle Fledge Terrace => Eagle Fledge Terrace
# Star Light Terrace => Star Light Terrace
# Cherry Laurel Terrace => Cherry Laurel Terrace
# Arch Terrace => Arch Terrace
# Ludlow Terrace => Ludlow Terrace
# Westwood Terrace => Westwood Terrace
# Callisto Terrace => Callisto Terrace
# Pinewood Terrace => Pinewood Terrace
# Breeze Terrace => Breeze Terrace
# Trailview Mesa Terrace => Trailview Mesa Terrace
# Algerita Terrace => Algerita Terrace
# Century Oaks Terrace => Century Oaks Terrace
# Teasdale Terrace => Teasdale Terrace
# Greenridge Terrace => Greenridge Terrace
# Lookout Bluff Terrace => Lookout Bluff Terrace
# Tay Terrace => Tay Terrace
# Marigold Terrace => Marigold Terrace
# Sterling Panorama Terrace => Sterling Panorama Terrace
# Shady Oak Terrace => Shady Oak Terrace
# Dunlop Terrace => Dunlop Terrace
# Green Emerald Terrace => Green Emerald Terrace
# Mifflin Kenedy Terrace => Mifflin Kenedy Terrace
# Industrial Terrace => Industrial Terrace
# Highgrove Terrace => Highgrove Terrace
# Gentle Breeze Terrace => Gentle Breeze Terrace
# Ridgetop Terrace => Ridgetop Terrace
# Lakewood Hills Terrace => Lakewood Hills Terrace
# Dark Star Terrace => Dark Star Terrace
# Buckingham Gate Terrace => Buckingham Gate Terrace
# Honey Dew Terrace => Honey Dew Terrace
# Airline Terrace => Airline Terrace
# Box Canyon Terrace => Box Canyon Terrace
# Fargo Terrace => Fargo Terrace
# Eastridge Terrace => Eastridge Terrace
# Bonham Terrace => Bonham Terrace
# Lago Viento => Lago Viento
# Desert Flower => Desert Flower
# Executive Center Drive Suite 213 => Executive Center Drive Suite 213
# Wind Cave => Wind Cave
# Aleppo Pine => Aleppo Pine
# Sierra Madre => Sierra Madre
# Spring Branch => Spring Branch
# Malaquita Branch => Malaquita Branch
# Maverick => Maverick
# Buffalo Gap => Buffalo Gap
# Gnu Gap => Gnu Gap
# Encino Verde => Encino Verde
# Cuesta Verde => Cuesta Verde
# Casa Verde => Casa Verde
# 4201 South Congress Avenue #4 => 4201 South Congress Avenue #4
# County Road 280 => County Road 280
# Buckskin => Buckskin
# Criswell => Criswell
# Camino Alto => Camino Alto
# Palo Alto => Palo Alto
# Avenue D => Avenue D
# Channel Island => Channel Island
# Camino Seco => Camino Seco
# Arroyo Seco => Arroyo Seco
# Rio Seco => Rio Seco
# Greenlawn Pkwy => Greenlawn Parkway
# Roger Hanks Pkwy => Roger Hanks Parkway
# Soter Pkwy => Soter Parkway
# Riata Trace Pkwy => Riata Trace Parkway
# Beverly Skyline => Beverly Skyline
# Hill Country Skyline => Hill Country Skyline
# S Interstate 35, #260 => South Interstate Highway 35 #260
# Laguna Grande => Laguna Grande
# Mesa Grande => Mesa Grande
# Rio Grande => Rio Grande
# Rain Lily Creek => Rain Lily Creek
# Boulder Creek => Boulder Creek
# Canyon Creek => Canyon Creek
# Deep Creek => Deep Creek
# Cross Creek => Cross Creek
# Rock Creek => Rock Creek
# Tealwood => Tealwood
# FM 535 => Farm-to-Market Road 535
# FM 1327 => Farm-to-Market Road 1327
# Farm-to-Market Road 1327 => Farm-to-Market Road 1327
# Buffalo Thunder => Buffalo Thunder
# Olympic Overlook => Olympic Overlook
# Bright Sky Overlook => Bright Sky Overlook
# Plum Hollow Overlook => Plum Hollow Overlook
# Cliff Overlook => Cliff Overlook
# County Road 117 => County Road 117
# Bonanza => Bonanza
# Stonebridge Dr. => Stonebridge Drive
# Sportsplex Dr. => Sportsplex Drive
# Cannon Dr. => Cannon Drive
# 11928 Stonehollow Dr. => 11928 Stonehollow Drive
# Pawnee Pathway => Pawnee Pathway
# Jigsaw Pathway => Jigsaw Pathway
# Happy Vale Pathway => Happy Vale Pathway
# Blackfoot => Blackfoot
# Quarry => Quarry
# Sierra Montana => Sierra Montana
# Greenway => Greenway
# West 5th Street #300 => West 5th Street #300
# 321 W Ben White Blvd #300 => 321 West Ben White Boulevard #300
# S Bell Blvd., Suite 301 => South Bell Boulevard Suite 301
# Hwy 290 W. Ste. 301 => Highway 290 West Suite 301
# Meadows Dr #306 => Meadows Drive #306
# Medio Calle => Medio Calle
# Cane Pace => Cane Pace
# Rambling Range => Rambling Range
# Speaking Rock => Speaking Rock
# Amberwood Loop => Amberwood Loop
# La Plata Loop => La Plata Loop
# Stagecoach Ranch Loop => Stagecoach Ranch Loop
# Horseshoe Loop => Horseshoe Loop
# Masi Loop => Masi Loop
# Rector Loop => Rector Loop
# Knoll Crest Loop => Knoll Crest Loop
# Circletree Loop => Circletree Loop
# Corran Ferry Loop => Corran Ferry Loop
# Outlook Ridge Loop => Outlook Ridge Loop
# Village Oak Loop => Village Oak Loop
# Silent Harbor Loop => Silent Harbor Loop
# Scotia Bluff Loop => Scotia Bluff Loop
# Osprey Ridge Loop => Osprey Ridge Loop
# Anarosa Loop => Anarosa Loop
# Bayton Loop => Bayton Loop
# Village View Loop => Village View Loop
# Fantail Loop => Fantail Loop
# Little Loop => Little Loop
# Candace Loop => Candace Loop
# Saville Loop => Saville Loop
# Sunrise Ridge Loop => Sunrise Ridge Loop
# Kirtomy Loop => Kirtomy Loop
# Lakehurst Loop => Lakehurst Loop
# Franklins Tale Loop => Franklins Tale Loop
# Rowe Loop => Rowe Loop
# Old Post Loop => Old Post Loop
# Mirasol Loop => Mirasol Loop
# Lake Loop => Lake Loop
# Double Spur Loop => Double Spur Loop
# E. North Loop => East North Loop
# Janet Loop => Janet Loop
# Staked Plains Loop => Staked Plains Loop
# Twin Lake Loop => Twin Lake Loop
# Whitebrush Loop => Whitebrush Loop
# Barrow Glen Loop => Barrow Glen Loop
# Ponciana Loop => Ponciana Loop
# West Loop => West Loop
# Spillman Ranch Loop => Spillman Ranch Loop
# Layne Loop => Layne Loop
# Donna Jane Loop => Donna Jane Loop
# Cameron Loop => Cameron Loop
# Magna Carta Loop => Magna Carta Loop
# Hansa Loop => Hansa Loop
# Walsall Loop => Walsall Loop
# West Pflugerville Loop => West Pflugerville Loop
# Witsome Loop => Witsome Loop
# Lily Lake Loop => Lily Lake Loop
# Gerald Allen Loop => Gerald Allen Loop
# Cardinal Loop => Cardinal Loop
# Dry Brook Loop => Dry Brook Loop
# Wayne Riddell Loop => Wayne Riddell Loop
# Leanna Oaks Loop => Leanna Oaks Loop
# Briarcreek Loop => Briarcreek Loop
# Post Oak Bend Loop => Post Oak Bend Loop
# Crane Creek Loop => Crane Creek Loop
# Ridgeview Loop => Ridgeview Loop
# Seneca Falls Loop => Seneca Falls Loop
# Foothill Farms Loop => Foothill Farms Loop
# Travis View Loop => Travis View Loop
# Wingreen Loop => Wingreen Loop
# Loch Linnhe Loop => Loch Linnhe Loop
# Panther Loop => Panther Loop
# West Hove Loop => West Hove Loop
# Christoff Loop => Christoff Loop
# Lightwood Loop => Lightwood Loop
# Cherry Loop => Cherry Loop
# Windy Shores Loop => Windy Shores Loop
# Lanna Bluff Loop => Lanna Bluff Loop
# Bastogne Loop => Bastogne Loop
# Olympia Fields Loop => Olympia Fields Loop
# Lanark Loop => Lanark Loop
# Celery Loop => Celery Loop
# Lockleven Loop => Lockleven Loop
# Lipton Loop => Lipton Loop
# Whiteworth Loop => Whiteworth Loop
# Wild Canyon Loop => Wild Canyon Loop
# Linden Loop => Linden Loop
# Bronco Bend Loop => Bronco Bend Loop
# Calhoun Canyon Loop => Calhoun Canyon Loop
# Colonel Winn Loop => Colonel Winn Loop
# Austral Loop => Austral Loop
# Maravillas Loop => Maravillas Loop
# Croydon Loop => Croydon Loop
# Marble Creek Loop => Marble Creek Loop
# Grand Oaks Loop => Grand Oaks Loop
# East Hove Loop => East Hove Loop
# Highland Lake Loop => Highland Lake Loop
# Long Hollow Loop => Long Hollow Loop
# Hudson Loop => Hudson Loop
# Rennalee Loop => Rennalee Loop
# Sage Creek Loop => Sage Creek Loop
# Independence Loop => Independence Loop
# Rising Smoke Loop => Rising Smoke Loop
# Vizquel Loop => Vizquel Loop
# Desert Willow Loop => Desert Willow Loop
# Whitt Loop => Whitt Loop
# Levander Loop => Levander Loop
# Indigo Broom Loop => Indigo Broom Loop
# Lindeman Loop => Lindeman Loop
# Springs Head Loop => Springs Head Loop
# West Cave Loop => West Cave Loop
# Pusch Ridge Loop => Pusch Ridge Loop
# Big Boggy => Big Boggy
# Governors Row => Governors Row
# Regal Row => Regal Row
# Fence Row => Fence Row
# Henry Kinney Row => Henry Kinney Row
# College Row => College Row
# Kings Row => Kings Row
# Warehouse Row => Warehouse Row
# Fuzz Fairway => Fuzz Fairway
# Lajitas => Lajitas
# Rue de St Germaine => Rue de Saint Germaine
# Meadow Crest => Meadow Crest
# FM1431 => FM1431
# Research Blvd #3000a => Research Boulevard #3000a
# Real Catorce => Real Catorce
# Physicians way => Physicians way
# Pfluger Street West => Pfluger Street West
# Rutland Village West => Rutland Village West
# View West => View West
# Wagon Road West => Wagon Road West
# Crystalbrook West => Crystalbrook West
# Alpine Road West => Alpine Road West
# Old 2243 West => Old 2243 West
# Carrie Manor Street West => Carrie Manor Street West
# Saint Elmo Road West => Saint Elmo Road West
# Julian Alps => Julian Alps
# Sutton => Sutton
# Firebird => Firebird
# Speedway Stop D5000 => Speedway Stop D5000
# Business Interstate Highway 35 J => Business Interstate Highway 35 J
# N Interstate 35, Suite 1805 => North Interstate Highway 35 Suite 1805
# Caisteal Castle => Caisteal Castle
# Research Blvd, Austin => Research Boulevard Austin
# FM 3177 => Farm-to-Market Road 3177
# Turnback => Turnback
# Sierra Leon => Sierra Leon
# Melanie's Walk => Melanie's Walk
# Fairfax Walk => Fairfax Walk
# Winding Walk => Winding Walk
# Gillians Walk => Gillians Walk
# Whitemarsh Valley Walk => Whitemarsh Valley Walk
# Midland Walk => Midland Walk
# Julies Walk => Julies Walk
# Village Walk => Village Walk
# Liberty Walk => Liberty Walk
# Regents Walk => Regents Walk
# Round Rock Ave => Round Rock Avenue
# Barstow Ave => Barstow Avenue
# South Congress Ave => South Congress Avenue
# E. University Ave => East University Avenue
# S Congress Ave => South Congress Avenue
# House of Lancaster => House of Lancaster
# Farm-to-Market Road 150 => Farm-to-Market Road 150
# IH-35 South, #150 => Interstate Highway 35 South, #150
# Buena Vista => Buena Vista
# Twilight Vista => Twilight Vista
# Mira Vista => Mira Vista
# Agua Vista => Agua Vista
# Puerta Vista => Puerta Vista
# Verde Vista => Verde Vista
# Burnet Road #600 => Burnet Road #600
# Sycamore Tr => Sycamore Trail
# Posse Tr => Posse Trail
# Sunflower Tr => Sunflower Trail
# Plaza on the Lake => Plaza on the Lake
# Buffalo Lake => Buffalo Lake
# Crater Lake => Crater Lake
# Circulo de Amistad => Circulo de Amistad
# Loma Linda => Loma Linda
# Casitas => Casitas
# El Camino Real => El Camino Real
# Camino Real => Camino Real
# Una Mas => Una Mas
# State Highway 71 W Spicewood => State Highway 71 West Spicewood
# Hampton Bliss Trace => Hampton Bliss Trace
# Tall Sky Trace => Tall Sky Trace
# Mill Ridge Trace => Mill Ridge Trace
# Juniper Trace => Juniper Trace
# Outpost Trace => Outpost Trace
# Dayflower Trace => Dayflower Trace
# Shadowglen Trace => Shadowglen Trace
# Tercel Trace => Tercel Trace
# Hunters Trace => Hunters Trace
# Single Trace => Single Trace
# Shadowlawn Trace => Shadowlawn Trace
# Flintrock Trace => Flintrock Trace
# Deer Track => Deer Track
# TX 45 => Texas 45
# Greenwich Meridian => Greenwich Meridian
# Atlantic => Atlantic
# La Costa => La Costa
# Camino La Costa => Camino La Costa
# I-35 Frontage => Interstate Highway 35 Frontage
# Elysian Fields => Elysian Fields
# devonshire cove => devonshire Cove
# Hidden Estates => Hidden Estates
# Pecan St => Pecan Street
# N Main St => North Main Street
# S 1st St => South 1st Street
# E Oltorf St => East Oltorf Street
# E 43rd St => East 43rd Street
# Red River St => Red River Street
# W 10th St => West 10th Street
# W Annie St => West Annie Street
# E 51st St => East 51st Street
# Rio Grande St => Rio Grande Street
# W 6th St => West 6th Street
# West Lynn St => West Lynn Street
# Duval St => Duval Street
# Amberwood South => Amberwood South
# Venture Boulevard South => Venture Boulevard South
# Whippoorwill Street South => Whippoorwill Street South
# Sioux Trail South => Sioux Trail South
# Farm-to-Market Road 973 South => Farm-to-Market Road 973 South
# Ranch Road 620 South => Ranch Road 620 South
# Comanche => Comanche
# brigadoon lane => Brigadoon Lane
# Victory Gallop => Victory Gallop
# Pawnee => Pawnee
# Scott Crescent => Scott Crescent
# Margranita Crescent => Margranita Crescent
# Canyon Maple => Canyon Maple
# Sunfish => Sunfish

# %%
update_farm_ranch_tomarket

# %% [markdown]
# ##### More things to fix:
#
# - postal code (even k value postal code varies (other are postcode))

# %% [markdown]
# ## Preparing for Database

# %%
import csv
import codecs
import cerberus
import schema

# %%
NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

# %%
LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
SCHEMA = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

# %% [markdown]
# Make sure the fields order in the csvs matches the column order in the sql table schema.

# %%
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS= ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %%
def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, lower_colon=LOWER_COLON, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    # YOUR CODE HERE
    if element.tag == 'node':
        for field in node_attr_fields:
            node_attribs[field] = element.attrib[field]
        
        for tag in element.iter("tag"):
            nodetags = {}
            nodetags['id'] = element.attrib['id']
            
            if is_street_name(tag):
                nodetags['value'] = update_name(tag.attrib'v', mapping)
            elif 
            
            else:
                nodetags['value'] = tag.attrib['v']
            
            
            try:
                problem_chars.search(tag.attrib['k']).group()
            except AttributeError:
                try:    
                    lower_colon.search(tag.attrib['k']).group()
                    kvalue = tag.attrib['k'].split(":")
                    nodetags['type'] = kvalue[0]
                    if len(kvalue) == 2:                        
                        nodetags['key'] = kvalue[1]
                    else:
                        nodetags['key'] = ':'.join(kvalue[1:])
                except AttributeError:
                    nodetags['type'] = default_tag_type
                    nodetags['key'] = tag.attrib['k']
            tags.append(nodetags) 
    
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        for item in WAY_FIELDS:
            way_attribs[item] = element.attrib[item]
        
        for wtag in element.iter("tag"):
            waytags = {}
            waytags['id'] = element.attrib['id']
            waytags['value'] = wtag.attrib['v']
            try:
                problem_chars.search(wtag.attrib['k']).group()
            except AttributeError:
                try:
                    lower_colon.search(wtag.attrib['k']).group()
                    wkvalue = wtag.attrib['k'].split(":")
                    waytags['type'] = wkvalue[0]
                    if len(wkvalue) == 2:
                        waytags['key'] = wkvalue[1]
                    else:
                        waytags['key'] = ':'.join(wkvalue[1:])
                except AttributeError:
                    waytags['type'] = default_tag_type
                    waytags['key'] = wtag.attrib['k']
            tags.append(waytags) 
                
        position = 0
        for waytag in element.iter("nd"):
            waynd = {}
            waynd['id'] = element.attrib['id']
            waynd['node_id'] = waytag.attrib['ref']
            waynd['position'] = position
            position += 1
            way_nodes.append(waynd)

        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# %%
def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, str) else ", ".join(v))
            for k, v in errors.iteritems()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-2645ceaeef32> in <module>()
# ----> 1 def validate_element(element, validator, schema=SCHEMA):
#       2     """Raise ValidationError if element does not match schema"""
#       3     if validator.validate(element, schema) is not True:
#       4         field, errors = next(validator.errors.iteritems())
#       5         message_string = "\nElement of type '{0}' has the following errors:\n{1}"
#
# NameError: name 'SCHEMA' is not defined

# %%
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-e5bab4b96d86> in <module>()
# ----> 1 class UnicodeDictWriter(csv.DictWriter, object):
#       2     """Extend csv.DictWriter to handle Unicode input"""
#       3
#       4     def writerow(self, row):
#       5         super(UnicodeDictWriter, self).writerow({
#
# NameError: name 'csv' is not defined

# %%
def process_map_db(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, codecs.open(WAYS_PATH, 'w') as ways_file, codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:
        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

# %% [markdown]
# #### Processing the whole Austin, TX map:

# %%
process_map_db(osmfile, validate=True)

# %% [markdown]
# ## Exploring the data more

# %% [markdown]
# Create set of k values:

# %%
k = set()

# %%
for event, element in ET.iterparse(osmfile):
    if element.tag == "tag" or element.tag == "way":
        for tag in element.iter("tag"):
             k.add(tag.attrib['k'])

# %%
len(k)
# Out:
# 851

# %%
k
# Out:
# {'FIXME',
#  'FIXME:ref',
#  'Grills',
#  'ISO3166-1',
#  'ISO3166-1:alpha2',
#  'ISO3166-1:alpha3',
#  'ISO3166-1:numeric',
#  'ISO3166-2',
#  'Keyword',
#  'Keywords',
#  'NHS',
#  'Texas_Trunk_System',
#  'Type',
#  'abandoned',
#  'access',
#  'acreage',
#  'acres',
#  'addr:city',
#  'addr:country',
#  'addr:county',
#  'addr:door',
#  'addr:full',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:place',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:streetnumber',
#  'addr:suite',
#  'addr:unit',
#  'admin_level',
#  'advertising',
#  'aeroway',
#  'alt_name',
#  'alt_name:vi',
#  'amenity',
#  'amperage',
#  'area',
#  'artist_name',
#  'artwork_type',
#  'atm',
#  'attribution',
#  'automated',
#  'baby',
#  'backrest',
#  'barrier',
#  'barrier:personnel',
#  'baseball',
#  'basin',
#  'beauty',
#  'bench',
#  'bicycle',
#  'bicycle:oneway',
#  'bicycle_parking',
#  'boat',
#  'border_type',
#  'boules',
#  'boundary',
#  'brand',
#  'bridge',
#  'bridge:name',
#  'bridge_name',
#  'building',
#  'building:description',
#  'building:levels',
#  'building:min_level',
#  'building:part',
#  'building:use',
#  'building_1',
#  'bus',
#  'button_operated',
#  'cables',
#  'capacity',
#  'capacity:disabled',
#  'capacity:parent',
#  'capacity:women',
#  'capital',
#  'car_wash',
#  'cartype',
#  'cash',
#  'cash_in',
#  'census:population',
#  'circuits',
#  'city_served',
#  'climbing',
#  'climbing:bolted',
#  'climbing:orientation',
#  'climbing:rock',
#  'climbing:sport',
#  'clothes',
#  'coa:place_id',
#  'collection_times',
#  'color',
#  'colour',
#  'comment',
#  'commercial',
#  'communication:mobile_phone',
#  'construction',
#  'construction:tourism',
#  'contact:email',
#  'contact:facebook',
#  'contact:phone',
#  'contact:website',
#  'content',
#  'covered',
#  'craft',
#  'created_by',
#  'crop',
#  'crossing',
#  'crossing:barrier',
#  'crossing:bell',
#  'crossing:light',
#  'crossing_ref',
#  'cuisine',
#  'cuisine_1',
#  'currency:XBT',
#  'cutting',
#  'cycleway',
#  'cycleway:foot',
#  'cycleway:left',
#  'cycleway:right',
#  'delivery',
#  'denomination',
#  'denotation',
#  'description',
#  'description:en',
#  'design',
#  'designation',
#  'destination',
#  'destination:lanes',
#  'destination:lanes:backward',
#  'destination:lanes:forward',
#  'destination:left',
#  'destination:ref',
#  'destination:ref:backward',
#  'destination:ref:lanes',
#  'destination:ref:lanes:backward',
#  'destination:ref:lanes:forward',
#  'destination:ref:to',
#  'destination:right',
#  'destination:street',
#  'destination:symbol',
#  'destination:symbol:lanes',
#  'destination:symbol:lanes:forward',
#  'developer',
#  'diesel',
#  'diet:gluten_free',
#  'diet:vegetarian',
#  'direction',
#  'dispensing',
#  'distance',
#  'disused',
#  'disused:amenity',
#  'disused:highway',
#  'disused:shop',
#  'drinking_water',
#  'drive_in',
#  'drive_through',
#  'drive_thru',
#  'ele',
#  'ele:feet',
#  'electrified',
#  'elevation',
#  'email',
#  'embankment',
#  'emergency',
#  'enforcement',
#  'entrance',
#  'exit_to',
#  'exit_to:left',
#  'exit_to:right',
#  'expressway',
#  'fax',
#  'fee',
#  'fence_type',
#  'fenced',
#  'fire_hydrant:type',
#  'fireplace',
#  'fixme',
#  'flag',
#  'flood_prone',
#  'foot',
#  'footway',
#  'ford',
#  'frequency',
#  'from',
#  'fuel:biodiesel',
#  'fuel:biogas',
#  'fuel:diesel',
#  'fuel:e10',
#  'fuel:gas',
#  'fuel:octane_87',
#  'fuel:octane_89',
#  'fuel:octane_91',
#  'fuel:octane_92',
#  'fuel:octane_95',
#  'fuel:octane_98',
#  'full_name',
#  'garage',
#  'garden:style',
#  'garden:type',
#  'gas_insulated',
#  'gate',
#  'gauge',
#  'gay',
#  'generator:method',
#  'generator:output:electricity',
#  'generator:source',
#  'generator:type',
#  'gnis:Class',
#  'gnis:County',
#  'gnis:County_num',
#  'gnis:ST_alpha',
#  'gnis:ST_num',
#  'gnis:county_id',
#  'gnis:county_name',
#  'gnis:created',
#  'gnis:edited',
#  'gnis:fcode',
#  'gnis:feature_id',
#  'gnis:feature_type',
#  'gnis:id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'gnis:state_id',
#  'golf',
#  'golf_cart',
#  'government',
#  'grades',
#  'group_only',
#  'have_riverbed',
#  'health_facility:type',
#  'health_specialty:palliative_medicine',
#  'healthcare',
#  'height',
#  'heritage',
#  'heritage:operator',
#  'hgv',
#  'highway',
#  'highway_1',
#  'historic',
#  'history',
#  'hoops',
#  'horse',
#  'iata',
#  'icao',
#  'image',
#  'import',
#  'import_uuid',
#  'incline',
#  'indoor',
#  'information',
#  'intermittent',
#  'internet_access',
#  'internet_access:fee',
#  'is_in',
#  'is_in:continent',
#  'is_in:country',
#  'is_in:country_code',
#  'is_in:iso_3166_2',
#  'is_in:state',
#  'is_in:state_code',
#  'isced',
#  'isced:level',
#  'junction',
#  'junction:ref',
#  'key',
#  'keywords',
#  'lake:max_depth',
#  'lake:max_depth:feet',
#  'lake:shore_length',
#  'lake:shore_length:miles',
#  'lake:surface_area',
#  'lake:surface_area:acres',
#  'lamp_type',
#  'landuse',
#  'lanes',
#  'lanes:backward',
#  'lanes:both_ways',
#  'lanes:forward',
#  'layer',
#  'lcn',
#  'lcn_ref',
#  'leaf_cycle',
#  'leaf_type',
#  'leisure',
#  'leisure_1',
#  'length',
#  'level',
#  'line',
#  'lit',
#  'loc_name',
#  'local',
#  'local_ref',
#  'location',
#  'man_made',
#  'material',
#  'maxheight',
#  'maxspeed',
#  'maxspeed:advisory',
#  'maxspeed:backward',
#  'maxspeed:conditional',
#  'maxspeed:forward',
#  'maxspeed:note',
#  'maxstay',
#  'menu',
#  'microbrewery',
#  'military',
#  'modifier',
#  'motor_vehicle',
#  'motorcycle',
#  'mtb:scale',
#  'mtb:scale:imba',
#  'mtb:scale:uphill',
#  'name',
#  'name:ab',
#  'name:ace',
#  'name:af',
#  'name:als',
#  'name:am',
#  'name:an',
#  'name:ang',
#  'name:ar',
#  'name:arc',
#  'name:arz',
#  'name:as',
#  'name:ast',
#  'name:av',
#  'name:ay',
#  'name:az',
#  'name:ba',
#  'name:backward',
#  'name:bar',
#  'name:bat-smg',
#  'name:bcl',
#  'name:be',
#  'name:be-tarask',
#  'name:bg',
#  'name:bi',
#  'name:bm',
#  'name:bn',
#  'name:bo',
#  'name:bpy',
#  'name:br',
#  'name:brand',
#  'name:bs',
#  'name:bxr',
#  'name:ca',
#  'name:cbk-zam',
#  'name:cdo',
#  'name:ce',
#  'name:ceb',
#  'name:chr',
#  'name:chy',
#  'name:ckb',
#  'name:co',
#  'name:crh',
#  'name:cs',
#  'name:csb',
#  'name:cu',
#  'name:cv',
#  'name:cy',
#  'name:da',
#  'name:de',
#  'name:diq',
#  'name:dsb',
#  'name:dv',
#  'name:dz',
#  'name:ee',
#  'name:el',
#  'name:eml',
#  'name:en',
#  'name:eo',
#  'name:es',
#  'name:et',
#  'name:eu',
#  'name:ext',
#  'name:fa',
#  'name:ff',
#  'name:fi',
#  'name:fiu-vro',
#  'name:fo',
#  'name:fr',
#  'name:frp',
#  'name:frr',
#  'name:fur',
#  'name:fy',
#  'name:ga',
#  'name:gag',
#  'name:gan',
#  'name:gd',
#  'name:gl',
#  'name:glk',
#  'name:gn',
#  'name:gu',
#  'name:gv',
#  'name:ha',
#  'name:hak',
#  'name:haw',
#  'name:he',
#  'name:hi',
#  'name:hif',
#  'name:hr',
#  'name:hsb',
#  'name:ht',
#  'name:hu',
#  'name:hy',
#  'name:ia',
#  'name:id',
#  'name:ie',
#  'name:ig',
#  'name:ik',
#  'name:ilo',
#  'name:io',
#  'name:is',
#  'name:it',
#  'name:iu',
#  'name:ja',
#  'name:jbo',
#  'name:jv',
#  'name:ka',
#  'name:kaa',
#  'name:kab',
#  'name:kbd',
#  'name:ki',
#  'name:kk',
#  'name:kl',
#  'name:km',
#  'name:kn',
#  'name:ko',
#  'name:koi',
#  'name:krc',
#  'name:ks',
#  'name:ksh',
#  'name:ku',
#  'name:kv',
#  'name:kw',
#  'name:ky',
#  'name:la',
#  'name:lad',
#  'name:lb',
#  'name:lbe',
#  'name:lez',
#  'name:lg',
#  'name:li',
#  'name:lij',
#  'name:lmo',
#  'name:ln',
#  'name:lo',
#  'name:lt',
#  'name:ltg',
#  'name:lv',
#  'name:map-bms',
#  'name:mdf',
#  'name:mg',
#  'name:mhr',
#  'name:mi',
#  'name:min',
#  'name:mk',
#  'name:ml',
#  'name:mn',
#  'name:mr',
#  'name:mrj',
#  'name:ms',
#  'name:mt',
#  'name:mwl',
#  'name:my',
#  'name:myv',
#  'name:mzn',
#  'name:na',
#  'name:nah',
#  'name:nap',
#  'name:nds',
#  'name:nds-nl',
#  'name:ne',
#  'name:new',
#  'name:nl',
#  'name:nn',
#  'name:no',
#  'name:nov',
#  'name:nrm',
#  'name:nso',
#  'name:nv',
#  'name:oc',
#  'name:om',
#  'name:or',
#  'name:os',
#  'name:pa',
#  'name:pag',
#  'name:pam',
#  'name:pap',
#  'name:pcd',
#  'name:pdc',
#  'name:pfl',
#  'name:pih',
#  'name:pl',
#  'name:pms',
#  'name:pnb',
#  'name:ps',
#  'name:pt',
#  'name:qu',
#  'name:rm',
#  'name:rn',
#  'name:ro',
#  'name:roa-tara',
#  'name:ru',
#  'name:rue',
#  'name:rw',
#  'name:sa',
#  'name:sah',
#  'name:sc',
#  'name:scn',
#  'name:sco',
#  'name:sd',
#  'name:se',
#  'name:sg',
#  'name:sh',
#  'name:si',
#  'name:simple',
#  'name:sk',
#  'name:sl',
#  'name:sm',
#  'name:sn',
#  'name:so',
#  'name:sq',
#  'name:sr',
#  'name:srn',
#  'name:ss',
#  'name:stq',
#  'name:su',
#  'name:sv',
#  'name:sw',
#  'name:szl',
#  'name:ta',
#  'name:te',
#  'name:tet',
#  'name:tg',
#  'name:th',
#  'name:tk',
#  'name:tl',
#  'name:tn',
#  'name:to',
#  'name:tpi',
#  'name:tr',
#  'name:ts',
#  'name:tt',
#  'name:tw',
#  'name:ty',
#  'name:tzl',
#  'name:udm',
#  'name:ug',
#  'name:uk',
#  'name:ur',
#  'name:uz',
#  'name:vec',
#  'name:vep',
#  'name:vi',
#  'name:vls',
#  'name:vo',
#  'name:wa',
#  'name:war',
#  'name:wo',
#  'name:wuu',
#  'name:xal',
#  'name:xh',
#  'name:xmf',
#  'name:yi',
#  'name:yo',
#  'name:za',
#  'name:zea',
#  'name:zh',
#  'name:zh-classical',
#  'name:zh-min-nan',
#  'name:zh-yue',
#  'name:zu',
#  'name_1',
#  'name_2',
#  'name_3',
#  'narrow',
#  'natural',
#  'natural_1',
#  'network',
#  'nhd:com_id',
#  'nhd:reach_code',
#  'nist:fips_code',
#  'nist:state_fips',
#  'noexit',
#  'noname',
#  'noref',
#  'note',
#  'note:lanes',
#  'note:odbl',
#  'note:ref',
#  'noturn',
#  'nrhp:id',
#  'nudism',
#  'odbl',
#  'odbl:note',
#  'office',
#  'official_name',
#  'official_name:vi',
#  'official_ref',
#  'old_name',
#  'old_name:vi',
#  'old_railway_operator',
#  'old_ref',
#  'oneway',
#  'oneway:bicycle',
#  'opening_date',
#  'opening_hours',
#  'operator',
#  'organic',
#  'origin',
#  'osmarenderer',
#  'others',
#  'outdoor_seating',
#  'par',
#  'park_ride',
#  'parking',
#  'parking:condition:both',
#  'parking:condition:left',
#  'parking:condition:right',
#  'parking:lane:both',
#  'parking:lane:left',
#  'parking:lane:right',
#  'parts',
#  'passenger',
#  'payment:bitcoin',
#  'payment:cash',
#  'payment:coins',
#  'payment:credit_cards',
#  'payment:debit_cards',
#  'payment:litecoin',
#  'payment:notes',
#  'payment:vertcoin',
#  'phone',
#  'place',
#  'placement',
#  'plant:method',
#  'plant:output:electricity',
#  'plant:source',
#  'playground',
#  'population',
#  'population:date',
#  'postal_code',
#  'power',
#  'practice',
#  'presbyterian',
#  'priority_road',
#  'proposed',
#  'public_transport',
#  'public_transport:version',
#  'railway',
#  'ramp:wheelchair',
#  'recycling:aluminium',
#  'recycling:beverage_cartons',
#  'recycling:cans',
#  'recycling:cardboard',
#  'recycling:cartons',
#  'recycling:glass',
#  'recycling:glass_bottles',
#  'recycling:green_waste',
#  'recycling:magazines',
#  'recycling:newspaper',
#  'recycling:paper',
#  'recycling:paper_packaging',
#  'recycling:plastic',
#  'recycling:plastic_bags',
#  'recycling:plastic_bottles',
#  'recycling:scrap_metal',
#  'recycling:wood',
#  'recycling_type',
#  'ref',
#  'ref:fips',
#  'ref:left',
#  'ref:nrhp',
#  'ref:right',
#  'ref:shop:num',
#  'reference',
#  'reg_name',
#  'reg_ref',
#  'religion',
#  'rental',
#  'restriction',
#  'restriction:truck',
#  'roof:shape',
#  'room',
#  'rooms',
#  'roundabout',
#  'route',
#  'route_master',
#  'route_ref',
#  'sac_scale',
#  'sale',
#  'school',
#  'school_type',
#  'second_hand',
#  'segregated',
#  'self_service',
#  'service',
#  'service area',
#  'service:bicycle:chain_tool',
#  'service:bicycle:pump',
#  'shelter',
#  'shelter_type',
#  'shop',
#  'short_name',
#  'short_name:eo',
#  'short_name:vi',
#  'shoulder',
#  'shoulder:width',
#  'sidewalk',
#  'sloped_curb',
#  'smoking',
#  'smoothness',
#  'social_facility',
#  'social_facility:for',
#  'socket:chademo',
#  'socket:type1',
#  'socket:type1_combo',
#  'source',
#  'source:Texas_Trunk_System',
#  'source:ele',
#  'source:geometry',
#  'source:maxspeed',
#  'source:name',
#  'source:noname',
#  'source:note',
#  'source:population',
#  'source:ref',
#  'source:ref:note',
#  'source_date',
#  'source_ref',
#  'sport',
#  'stable',
#  'stars',
#  'start_date',
#  'state_capital',
#  'stateofrepair',
#  'stop',
#  'structure',
#  'studio',
#  'substance',
#  'substation',
#  'suite',
#  'supervised',
#  'surface',
#  'surveillance',
#  'surveillance:type',
#  'symbol',
#  'tactile_paving',
#  'takeaway',
#  'technology',
#  'text',
#  'theatre',
#  'tiger:CLASSFP',
#  'tiger:CPI',
#  'tiger:FUNCSTAT',
#  'tiger:LSAD',
#  'tiger:MTFCC',
#  'tiger:NAME',
#  'tiger:NAMELSAD',
#  'tiger:PCICBSA',
#  'tiger:PCINECTA',
#  'tiger:PLACEFP',
#  'tiger:PLACENS',
#  'tiger:PLCIDFP',
#  'tiger:STATEFP',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_base_2',
#  'tiger:name_base_3',
#  'tiger:name_direction_prefix',
#  'tiger:name_direction_prefix_1',
#  'tiger:name_direction_prefix_2',
#  'tiger:name_direction_suffix',
#  'tiger:name_direction_suffix_1',
#  'tiger:name_direction_suffix_2',
#  'tiger:name_direction_suffix_3',
#  'tiger:name_type',
#  'tiger:name_type_1',
#  'tiger:name_type_2',
#  'tiger:name_type_3',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:upload_uuid',
#  'tiger:zip_left',
#  'tiger:zip_left_1',
#  'tiger:zip_left_2',
#  'tiger:zip_left_3',
#  'tiger:zip_left_4',
#  'tiger:zip_right',
#  'tiger:zip_right_1',
#  'tiger:zip_right_2',
#  'tiger:zip_right_3',
#  'tiger:zip_right_4',
#  'to',
#  'toilets',
#  'toilets:disposal',
#  'toilets:wheelchair',
#  'toll',
#  'toll:automatic',
#  'tourism',
#  'tower:type',
#  'tracktype',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_signals',
#  'traffic_signals:direction',
#  'traffic_signals:sound',
#  'trail_visibility',
#  'trees',
#  'tunnel',
#  'turn',
#  'turn:lanes',
#  'turn:lanes:backward',
#  'turn:lanes:both_ways',
#  'turn:lanes:forward',
#  'twoway',
#  'type',
#  'undefined',
#  'unisex',
#  'unsigned_ref',
#  'url',
#  'usage',
#  'valves',
#  'vending',
#  'voltage',
#  'voltage-high',
#  'voltage-low',
#  'waste',
#  'water',
#  'waterway',
#  'website',
#  'wetap:status',
#  'wetap:statusnote',
#  'wheelchair',
#  'wheelchair_toilet',
#  'width',
#  'width:lanes:backward',
#  'width:lanes:forward',
#  'wifi',
#  'wikidata',
#  'wikipedia',
#  'wood',
#  'wpt_symbol'}

# %% [markdown]
# Exploration of websites:

# %%
for event, element in ET.iterparse(osmfile):
    if element.tag == "tag" or element.tag == "way":
        for tag in element.iter("tag"):
             if tag.attrib['k'] == 'website':
                    print tag.attrib['v']
# Out:
# http://crownandanchorpub.com
# premiumoutlets.com
# http://www.stpetersaustin.org/
# http://delvalle.tx.schoolwebpages.com/education/school/school.php?sectiondetailid=75
# http://www.fvcofc.com/
# http://www.southaustinnaz.org/
# http://www.felcaustin.org/
# http://www.stricklandschool.com/
# http://www.kacfaustin.org/
# http://www.christapostolicaustin.faithweb.com/
# http://cottonwood-ministries.org/
# http://www.faithbaptistaustin.org/
# http://www.austinparks.org/our-parks.html?parkid=239
# http://www.cccaustin.org/
# http://fumcaustin.org/
# http://www.heightsassembly.com/
# http://www.hillcrestaustin.org/
# http://stmarksaustin.org/
# http://www.stmattsaustin.org/
# http://www.sunriseaustin.org/
# http://www.templomontesinai.com/
# http://www.clcaustin.com/
# http://swcofc.org/
# http://www.ecraustin.org/
# http://www.uachurch.org/
# http://www.ucc-austin.org/
# http://www.uumc.org/
# http://westover.org/
# http://texasmilitaryforcesmuseum.org/
# www.austinexecutiveairport.com
# http://www.musashinosushi.com/
# http://www.austinquakers.org/
# http://thefriscoaustin.com
# http://www.kerbeylanecafe.com/
# http://thaikitchentx.com/
# http://www.nxnwbrew.com/
# http://www.manchacavet.com
# http://www.epochcoffee.com/
# http://greatwallleander.com/
# http://www.trento360.com/
# http://www.cedarcreekumc.org/
# http://www.capmetro.org/gismaps/stops/5225.html
# www.mimadresrestaurant.com
# http://gumbosaustin.com/gumbosroundrock.html
# http://www.rei.com
# http://farrensheehanlaw.com/
# http://www.pflame.org/
# http://moonlightbakery.com/
# http://austin.shambhala.org/
# http://www.omnihotels.com/hotels/austin-southpark
# http://www.marriott.com/hotels/travel/ausrs-residence-inn-austin-south/
# http://www.mrnatural-austin.com/
# http://www.resistenciabooks.com/
# http://www.peddlerbike.com/
# www.FlemingsSteakhouse.com
# http://www.astiaustin.com/asti/
# http://www.quacksbakery.com/
# http://north.bamboobistroonline.menufy.com/
# http://bombay-bistro-research.menufy.com/
# http://www.patsgames.com
# http://local.randalls.com/tx/austin-2490.html
# http://flightpathcoffeehouse.com/
# http://monkeywrenchbooks.org/
# http://www.juicelandaustin.com/home
# http://housepizzeria.com/
# astersethiopian.com
# http://www.newindia.us/
# http://www.southsideflyingpizza.com/
# http://lucky-bakery.com/
# http://www.habanaaustin.com/
# http://arirangaustin.com/
# http://tandooribistroaustin.net/
# http://www.tienjinrestaurant.com/
# dinhochinesebbq.com
# https://www.facebook.com/cheerupcharliesaustin
# http://elsolylalunaaustin.com/
# http://flamingocantina.com/
# https://dirtydogbar.com/
# http://www.coyoteuglysaloon.com/austin/
# http://ironcactus.com/austin-downtown
# http://drafthouse.com/austin
# http://www.roppolospizzaaustin.com/
# http://www.shakespearesaustin.com/
# http://oldpecanstcafe.com/
# http://www.bikinissportsbarandgrill.com/Locations/austin-tx-6th-st/
# http://theparishaustin.com/
# http://bdrileys.com/
# http://handlebaraustin.com/
# www.leafsalad.com
# http://www.tejifoods.com/teji/index.php
# http://www.tejifoods.com/teji/index.php
# http://www.roundrockdonuts.com/
# http://www.pho-hoang.com/
# http://www.cholaonline.com/
# http://www.sichuangardentx.com/
# http://www.quattrogattiaustin.com/
# http://www.quiznos.com
# http://www.tjs-cycle.com/
# http://www.kome-austin.com/
# cornucopiapopcorn.com
# bitemiaustin.com
# www.consciouscravingsaustin.com/
# madammam.com
# haiky.zzl.org
# dimassisbuffet.com
# casa-colombia.com
# tinosgreekcafe.com
# realespizza.com
# hooverscooking.com
# http://www.capmetro.org/gismaps/stops/5548.html
# madraspavilion.us
# http://http://www.thaihouseaustin.com
# mikadoryotei.com
# www.mywpd.com
# http://www.cutlooseaustin.com/
# www.cover-3.com
# http://phothaisonaustin.com/
# weirdosaustin.com
# http://www.paisanosinc.com/
# http://mcintiresgarden.com/
# http://www.dossalsas.com/
# http://minhscafe.menufy.com/
# http://eatdrinkdocs.com/
# http://www.apple.com/thedomain
# www.austincakeball.com
# http://www.santaritacantina.com/
# http://www.noblepigaustin.com
# eastsideshowroom.com
# http://www.waterlooicehouse.com/
# First-leap.com
# http://www.monkeynestcoffee.com
# http://pinthousepizza.com/
# http://www.capmetro.org/gismaps/stops/5552.html
# www.gattispizza.com
# www.beallstx.com/loc/167
# www.nylemaxwellcjd.com
# http://www.southwestsolutions.com/
# http://www.7-eleven.com/Stores/Default.aspx?1=1&find=78681
# www.freddysusa.com
# www.hoodyssubs.com
# http://www.omnihotels.com/hotels/austin-downtown
# http://www.spinzonewash.com/
# www.workhorsebar.com
# http://www.benderbar.com
# https://www.facebook.com/pages/Rivercity-Market/
# http://bravenewbookstore.com/
# http://www.crowdtorch.com
# http://www.clarusagency.com
# championsaustin.com
# http://maithaionline.com/
# http://www.texashoneyham.com
# http://www.casawatchers.com
# http://sienaaustin.com/
# http://quiznosfarwest.com/
# http://www.mangiapizza.com/
# http://www.austintechnologylawblog.com/
# http://tomosushiaustin.com/
# http://www.calxeda.com
# http://cozzolisaustin.com/
# http://www.haymakeraustin.com/
# http://in.gredients.com/
# http://www.motoza.com/
# http://frankbryanlaw.com
# http://moorecoverage.com
# http://www.chinacafelakecreek.com/
# http://www.subway.com/
# www.cherrywoodcoffeehouse.com/
# http://www.allstarroofingtexas.com
# http://www.gsdentalstudio.com/
# http://risaustin.com/
# http://guerinpropertyservices.com/
# http://www.bellusflooring.com/
# www.nwiron.com
# www.robertberrylaw.com
# http://www.sundancemetal.com/
# http://ringerwindows.com
# http://www.voscomovingaustin.com
# http://www.flexsolarcells.com
# http://www.hohochinesebbq.com/
# http://www.discounttire.com
# http://www.sonicdrivein.com/
# http://www.davidmcdavidacuraofaustin.com/
# http://www.solidconcepts.com/
# http://capitalcoinandbullion.com
# http://havihair.com/
# http://www.vistaridgefamilydentistry.com/
# http://www.TSONorthRoundRock.com
# www.artoftacos.com
# https://www.facebook.com/FrostHomestead
# http://www.karmakaze.tv/
# http://crossfitcitylimits.com/
# http://www.ionvapor.com/
# http://bestcleanerstexas.com/
# https://plus.google.com/109336551242545521693/about?gl=us&hl=en
# http://www.nextgen.com/
# advanceautoparts.com
# http://austin.iflyworld.com/
# goldsgym.com
# http://atfcu.org/index.php/component/content/article/36-locations-a-hours/157-brodie-lane
# http://newks.com/locations/austin/
# http://toptierrides.com/
# http://www.yelp.com/biz/la-canasta-market-leander
# http://www.lakewayaviation.com
# http://www.zestfamily.com
# http://www.skinologie.com
# http://www.atpcweb.org/
# http://centraltexasgunworks.com
# http://www.theunconventionaloven.com/
# http://pignottimusicstudios.com
# http://mylocalbitcoinatm.com/
# www.austintablestudio.com
# http://www.chaoticmoon.com
# http://thesocialapartments.com/
# http://www.coinvaultatm.com/
# http://problemsolved512.com
# http://www.breathandbalancebodyworks.com
# http://www.diveaustin.com/
# http://www.austincarpetclean.com
# http://www.trtexas.com
# http://www.drafthouse.com
# www.twinliquors.com
# http://aasichuanchina.menufy.com/
# http://south.bamboobistroonline.menufy.com/
# http://bombay-bistro-larmar.menufy.com/
# http://brooklynheightspizzeria.menufy.com/
# http://changthaithaicuisine.com/
# http://emoskitchen.com/
# http://freshhealthycafeut.menufy.com/
# http://hoamyrestaurant.com/
# http://austin.imthaicuisine.com/
# http://indianfoodaustin.menufy.com/
# http://eatnagoya.menufy.com/
# http://nanamiaustin.com/
# http://nankingrestaurantaustin.com/
# http://oceanchinaonline.com/
# http://prima-pizza-pasta.menufy.com/
# http://superchinarestaurant.com/
# http://sushidotcomaustin.com/
# http://thaipassionsouth.menufy.com/
# http://thaispoonrestaurant.menufy.com/
# http://towerpizzabistro.menufy.com/
# http://umiaustin.menufy.com/
# http://yayacafeaustin.com/
# http://buda.imthaicuisine.com/
# tonyandluigistx.com
# http://www.austincc.edu/locations/campuses/hays-campus
# http://www.carlsjr.com
# http://greatwallpflugerville.com/
# http://greatwallroundrock.com/
# https://www.facebook.com/pages/Ampo-Firearms/1427376977498890
# https://premiumgiftcards.com
# http://www.apogeeresults.com
# www.castledental.com
# http://www.thaihowareyou.com/
# http://tejifoods.com/tejis2014/
# http://austindailypress.com/
# http://fourkitchens.com/
# http://www.ecobox.com/
# http://www.ecobox.com/
# http://holtcat.com/contact_us/locations/caterpillar_austin.aspx
# http://holttruckcenters.com/locations/pflugerville.aspx
# http://holtcat.com/contact_us/locations/pflugerville_cat_rental.aspx
# http://www.txdps.state.tx.us/
# http://www.hechoenmexico-restaurant.com
# http://elsapoatx.com/
# http://www.redeemer.net/
# http://taquerialosaltosaustin.eat24hour.com/
# http://www.tornadobus.com/
# http://www.fastfolks.com/
# www.yarddog.com
# http://franklinbarbecue.com/
# http://www.jackalopebar.com/
# http://www.hopdoddy.com/
# http://www.saltysow.com/
# http://torchystacos.com/location/trailer-park/
# http://www.uchiaustin.com/
# http://www.draughthouse.com/
# http://www.chilantrobbq.com/index
# http://www.casinoelcamino.net/
# http://www.grajmahalaustin.com/
# http://www.capmetro.org/gismaps/stops/5275.html
# http://www.capmetro.org/gismaps/stops/5275.html
# http://www.capmetro.org/gismaps/stops/5544.html
# http://www.capmetro.org/gismaps/stops/5544.html
# http://www.capmetro.org/gismaps/stops/5545.html
# http://www.capmetro.org/gismaps/stops/5545.html
# http://www.capmetro.org/gismaps/stops/5546.html
# http://www.capmetro.org/gismaps/stops/5546.html
# http://www.capmetro.org/gismaps/stops/5547.html
# http://www.capmetro.org/gismaps/stops/5547.html
# http://www.capmetro.org/gismaps/stops/5548.html
# http://www.capmetro.org/gismaps/stops/5549.html
# http://www.capmetro.org/gismaps/stops/5549.html
# http://www.capmetro.org/gismaps/stops/5550.html
# http://www.capmetro.org/gismaps/stops/5550.html
# http://www.capmetro.org/gismaps/stops/5551.html
# http://www.capmetro.org/gismaps/stops/5551.html
# http://www.capmetro.org/gismaps/stops/5552.html
# http://www.capmetro.org/gismaps/stops/5553.html
# http://www.capmetro.org/gismaps/stops/5553.html
# http://www.capmetro.org/gismaps/stops/5225.html
# http://www.capmetro.org/gismaps/stops/5225.html
# http://www.capmetro.org/gismaps/stops/5226.html
# http://www.capmetro.org/gismaps/stops/5227.html
# http://www.capmetro.org/gismaps/stops/5227.html
# http://www.capmetro.org/gismaps/stops/5274.html
# http://www.capmetro.org/gismaps/stops/5274.html
# http://www.capmetro.org/gismaps/stops/5272.html
# http://www.capmetro.org/gismaps/stops/5272.html
# http://www.capmetro.org/gismaps/stops/5273.html
# http://www.capmetro.org/gismaps/stops/5273.html
# http://oneworldvanlines.com/
# http://www.austinbahai.org/
# http://www.stannieamec.org/
# http://www.evo-entertainment.com/
# http://www.subway.com/
# www.elchilito.com
# http://www.fumc-rr.org/
# http://www.batteriesplus.com/
# http://www.batteriesplus.com/
# http://www.batteriesplus.com/
# http://www.berkeleyumc.org/
# http://woodlawnbc.org/
# http://www.bluebonnetvapor.com
# http://www.mrcassette.com
# http://www.mwbicycles.info/
# http://www.batteriesplus.com/
# http://www.OReillyAuto.com
# http://www.mobiledestination.com
# http://austin-downtown.planetsub.com/
# http://bourbongirlaustin.com/site/
# http://www.friendsbar.com/
# http://recessarcadebar.com/
# http://thechicagohouse.com/
# https://www.facebook.com/pages/Buckshot-6th-St/359712537432946
# https://www.facebook.com/cheersshotbar
# http://www.chupacabracantina.com/
# http://www.mugshotsaustin.com/
# http://www.museumoftheweird.com
# https://twitter.com/peckerheads
# http://www.the512on6th.com/
# http://vulcanatx.com/
# http://www.ampedaustin.com/
# https://www.facebook.com/KRAVEaustin
# http://www.dizzyrooster.com
# http://www.allsaintstattoo.com/
# http://www.collectivestatus.com/
# http://www.geisha6th.com/
# http://www.koriente.com/
# http://www.plushatx.com/
# http://red7austin.com/
# http://www.tearsofjoysauces.com/
# http://truebluetattoo.com/
# http://affinitybodypiercing.com/home.html
# http://www.bobalu.com/
# http://www.esthersfollies.com/
# http://thevelveetaroom.com/
# http://www.walmart.com/store/4130
# http://www.thermapuretexas.com/locations/austin-tx.php
# http://www.jerseymikes.com
# http://www.mamafus.com
# http://www.hillcountryeyecare.com
# http://zigzagsalon.com/
# http://ozonebikes.com
# http://sustainablefoodcenter.org/programs/sfc-farmers-market/sfc-farmers-market-at-sunset-valley
# http://www.thebrewandbrew.com/
# http://www.cah.utexas.edu/exhibits/StatuesExhibit/page3.html
# http://cenoteaustin.com
# www.tiempoaustin.com/
# http://www.austintexas.gov/pools
# sustainablefoodcenter.org/
# http://www.spin-n-kleen.com/
# http://www.moontowersaloon.com
# http://www.sevencustomhomes.com/
# http://www.jovanpros.com/
# http://www.northshoreaustin.com/
# http://library.austintexas.gov/
# http://boutiqueplasticsurgery.com
# www.austinwellnesschiropractic.com
# http://radhamadhavdham.org/
# www.MassageArtistsTX.com
# https://www.ufonetcomm.com
# http://www.lakewayresortandspa.com/
# http://www.redstellasalonaustin.com/
# http://www.austinaikikai.org
# http://www.averyranchdental.com
# http://passagestopotential.com
# http://adelbertsbeer.com/
# http://www.circlebrewing.com/
# http://austinbeerworks.com/
# http://blueowlbrewing.com/
# http://www.hopsandgrain.com/
# http://gunsandoil.com/
# http://www.zilkerbeer.com/
# http://friendsandallies.beer/
# http://www.lovethysandwich.com/
# http://www.dogandduckpub.com/
# http://www.arpeggiogrill.com/
# http://www.austincc.edu/highland-campus
# http://aviatorpizza.com
# http://education.utexas.edu/
# http://bicyclesportshop.com/about/parmer-pg1722.htm
# http://www.ajcyclery.com/index.php
# http://peddlerbike.com/
# http://www.vertskebap.com/
# http://www.precision-camera.com/
# http://epochcoffee.com/
# http://www.antiquegalleryroundrock.com/
# http://www.prelogs.com/
# http://www.iairservices.com/
# https://www.shrednations.com/round-rock
# https://www.brookshirebrothers.com/store-location/store-67
# http://www.sfanthor.com/
# http://www.kyleer.com
# http://www.comfortsuites.choicehotels.com
# http://www.eastwestautos.com
# http://www.smartcitylocating.com
# dlair.net
# dlair.net
# http://www.jamesavery.com/custserv/store_details.jsp?storeId=754
# http://www.jamesavery.com/custserv/store_details.jsp?storeId=699
# http://www.jamesavery.com/custserv/store_details.jsp?storeId=691
# http://www.jamesavery.com/custserv/store_details.jsp?storeId=702
# http://www.jamesavery.com/custserv/store_details.jsp?storeId=721
# http://www.jamesavery.com/custserv/store_details.jsp?storeId=738
# http://www.jamesavery.com/custserv/store_details.jsp?storeId=730
# http://www.atc1.com
# http://radiocoffeeandbeer.com
# http://lookandseevision.com
# http://birdsbarbershop.com/location/austin-rock-rose/
# http://jackandgingers.pub/
# http://kungfusaloonrockrose.com/
# http://stgen.co/
# https://tarkaindiankitchen.com/
# http://texaspetstyling.com
# http://www.kennyscards.com
# http://www.miniofaustin.com
# http://www.sgchurch.org
# www.tracking-point.com
# http://jessinsuresme.net
# http://www.txdot.gov/tpp/hwy/rm/rm0967.htm
# http://www.txdot.gov/tpp/hwy/rm/rm0967.htm
# https://texashomeoffers.com/austin/
# https://texashomeoffers.com/austin/
# http://www.transitionroofing.com
# http://www.transitionroofing.com
# http://dce.leanderisd.org
# http://dce.leanderisd.org
# http://www.discovernewhope.com/
# http://www.discovernewhope.com/
# http://local.randalls.com/tx/cedar-park-1896.html
# http://local.randalls.com/tx/cedar-park-1896.html
# http://www.austintexas.gov/department/hancock-golf-course
# http://www.austintexas.gov/department/hancock-golf-course
# http://www.tandcsports.org/
# http://www.tandcsports.org/
# http://www.monteronecanyoncreek.com/
# http://www.monteronecanyoncreek.com/
# http://www.frys.com
# http://www.frys.com
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# http://www.channingsmark.com/
# http://www.channingsmark.com/
# http://www.countyline.com/CountyLineLake.html
# http://www.countyline.com/CountyLineLake.html
# http://local.randalls.com/tx/austin-2483.html
# http://local.randalls.com/tx/austin-2483.html
# http://www.faithlutheranaustin.org/
# http://www.faithlutheranaustin.org/
# http://hope.org/
# http://hope.org/
# http://austinfirstcumberland.org/
# http://austinfirstcumberland.org/
# http://austinuu.org/
# http://austinuu.org/
# http://hiltongardeninn3.hilton.com/en/hotels/texas/hilton-garden-inn-austin-downtown-convention-center-AUSGIGI/index.html
# http://hiltongardeninn3.hilton.com/en/hotels/texas/hilton-garden-inn-austin-downtown-convention-center-AUSGIGI/index.html
# http://www.bbvacompass.com/
# http://www.bbvacompass.com/
# http://www.jesusdeafchurch.com/
# http://www.jesusdeafchurch.com/
# http://bicyclesportshop.com/about/research-pg1721.htm
# http://bicyclesportshop.com/about/research-pg1721.htm
# http://embassysuites3.hilton.com/en/hotels/texas/embassy-suites-austin-arboretum-AUSESES/index.html
# http://embassysuites3.hilton.com/en/hotels/texas/embassy-suites-austin-arboretum-AUSESES/index.html
# http://pollosricos.com/
# http://pollosricos.com/
# http://techranchaustin.com/
# http://techranchaustin.com/
# http://www.mrteegolf.com/
# http://www.mrteegolf.com/
# http://www.sienaaustin.com
# http://www.sienaaustin.com
# http://ilcpville.org/about-the-day-school/
# http://ilcpville.org/about-the-day-school/
# http://ilcpville.org/
# http://ilcpville.org/
# http://www.rrhsfootball.net/
# http://www.rrhsfootball.net/
# www.saltlickbbq.com
# www.saltlickbbq.com
# http://www.hiexpress.com/hotels/us/en/sunset-valley/aussv/hoteldetail?hotelCode=aussv
# http://www.hiexpress.com/hotels/us/en/sunset-valley/aussv/hoteldetail?hotelCode=aussv
# southwestern.edu
# southwestern.edu
# http://zaxaustin.com
# http://zaxaustin.com
# www.realtyaustin.com
# www.realtyaustin.com
# http://winkley.leanderisd.org
# http://winkley.leanderisd.org
# http://www.mqgreathills.com
# http://www.mqgreathills.com
# http://www.motherscafeaustin.com/
# http://www.motherscafeaustin.com/
# http://www.simon.com/mall/the-domain
# http://www.simon.com/mall/the-domain
# http://www.rulesbasedmedicine.com/
# http://www.rulesbasedmedicine.com/
# http://www.batteriesplus.com/
# http://www.batteriesplus.com/
# https://www.ischool.utexas.edu
# https://www.ischool.utexas.edu
# http://local.randalls.com/tx/west-lake-hills-2477.html
# http://local.randalls.com/tx/west-lake-hills-2477.html
# http://local.randalls.com/tx/round-rock-2636.html
# http://local.randalls.com/tx/round-rock-2636.html
# http://local.randalls.com/tx/lakeway-1779.html
# http://local.randalls.com/tx/lakeway-1779.html
# http://local.randalls.com/tx/austin-2490.html
# http://local.randalls.com/tx/austin-2490.html
# http://local.randalls.com/tx/austin-2485.html
# http://local.randalls.com/tx/austin-2485.html
# http://local.randalls.com/tx/austin-2482.html
# http://local.randalls.com/tx/austin-2482.html
# http://local.randalls.com/tx/austin-2481.html
# http://local.randalls.com/tx/austin-2481.html
in-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/south-austin-tx/your-lt.html
# http://www.walmart.com/storeLocator/ca_storefinder_details_short.do?edit_object_id=77&sfsearch_zip=&searchRadius=50&sftype_sel=&sfsearch_single_line_address=&sfsearch_city=temple&sfsearch_state=TX
# http://www.walmart.com/storeLocator/ca_storefinder_details_short.do?edit_object_id=77&sfsearch_zip=&searchRadius=50&sftype_sel=&sfsearch_single_line_address=&sfsearch_city=temple&sfsearch_state=TX
# http://roundrockdonuts.com
# http://roundrockdonuts.com
# http://www.enchantedfloristaustin.com/
# http://www.enchantedfloristaustin.com/
# http://schools.roundrockisd.org/RRHS/
# http://schools.roundrockisd.org/RRHS/
# http://roundrocktexas.gov/mainstreetplaza
# http://roundrocktexas.gov/mainstreetplaza
# http://schools.roundrockisd.org/chisholmtrail/
# http://schools.roundrockisd.org/chisholmtrail/
# http://schools.roundrockisd.org/chisholmtrail/
# http://schools.roundrockisd.org/chisholmtrail/
# http://www.jwmarriottaustin.com/
# http://www.jwmarriottaustin.com/
# http://coloradotower.com/
# http://coloradotower.com/
# http://www.marriott.com/hotels/travel/ausne-springhill-suites-austin-north-parmer-lane/
# http://www.marriott.com/hotels/travel/ausne-springhill-suites-austin-north-parmer-lane/
# http://www.centralrr.com/
# http://www.centralrr.com/
# http://www.bushschicken.com
# http://www.bushschicken.com
# http://www.velocitycu.com
# http://www.velocitycu.com
# http://www.ieccorporation.com/
# http://www.ieccorporation.com/
# http://www.concordia.edu
# http://www.concordia.edu
# http://www.butlerparkpitchandputt.com
# http://www.butlerparkpitchandputt.com
# http://www.thehumansolution.com
# http://www.thehumansolution.com
# ventanaoaks.com
# ventanaoaks.com
# http://www.lasbrisasroundrock.com/
# http://www.lasbrisasroundrock.com/
# austinguitarhouse.com
# austinguitarhouse.com
# http://austinsimplyfit.com/loc/burnet/
# http://austinsimplyfit.com/loc/burnet/
# http://www.walmart.com/
# http://www.walmart.com/
# http://www.austinparks.org/our-parks.html?parkid=408
# http://www.austinparks.org/our-parks.html?parkid=408
# http://schools.bisdtx.org/default.aspx?name=ccis.homepage
# http://schools.bisdtx.org/default.aspx?name=ccis.homepage
# http://schools.bisdtx.org/default.aspx?name=ccms.homepage
# http://schools.bisdtx.org/default.aspx?name=ccms.homepage
# http://www.mcspaddenautomotive.com
# http://www.mcspaddenautomotive.com
# www.oreillyauto.com
# www.oreillyauto.com
# http://www.cityofkyle.com/cityadministration
# http://www.cityofkyle.com/cityadministration
# http://www.kylemarketplace.com/
# http://www.kylemarketplace.com/
# http://www.sccdevelopment.net/project/the-village-at-kyle
# http://www.sccdevelopment.net/project/the-village-at-kyle
# https://www.usps.com/
# https://www.usps.com/
# http://www.cityofkyle.com/police
# http://www.cityofkyle.com/police
# http://www.cityofkyle.com/recreation/city-square-park
# http://www.cityofkyle.com/recreation/city-square-park
# http://www.cityofkyle.com/recreation/gregg-clarke-park
# http://www.cityofkyle.com/recreation/gregg-clarke-park
# https://parks.traviscountytx.gov/find-a-park/webberville
# https://parks.traviscountytx.gov/find-a-park/webberville
# https://parks.traviscountytx.gov/find-a-park/east-metro
# https://parks.traviscountytx.gov/find-a-park/east-metro
# http://www.pinballzarcade.com
# http://www.pinballzarcade.com
# http://crossplantsandproduce.com/
# http://crossplantsandproduce.com/
# https://parks.co.travis.tx.us/find-a-park/mansfield-dam
# https://parks.co.travis.tx.us/find-a-park/mansfield-dam
# http://cms.pflugervilleisd.net/Domain/32
# http://cms.pflugervilleisd.net/Domain/32
# http://www.shoreline.net/
# http://www.shoreline.net/
# http://www.cedarparktexas.gov/modules/showdocument.aspx?documentid=1319
# http://www.cedarparktexas.gov/modules/showdocument.aspx?documentid=1319
# http://www.traderjoes.com
# http://www.traderjoes.com
# http://texaneyecare.com
# http://texaneyecare.com
# http://texashillcountryreservations.com/property/new-trach-ranch-log-cabin/
# http://texashillcountryreservations.com/property/new-trach-ranch-log-cabin/
# http://quickiepickieaustin.com
# http://quickiepickieaustin.com
# http://schools.bisdtx.org/default.aspx?name=gs.homepage
# http://schools.bisdtx.org/default.aspx?name=gs.homepage
# http://austintexas.gov/department/conley-guerrero-senior-activity-center
# http://austintexas.gov/department/conley-guerrero-senior-activity-center
# http://www.mtzion-baptist.org/
# http://www.mtzion-baptist.org/
# http://www.myec.net/
# http://www.myec.net/
# http://www.austincc.edu/
# http://www.austincc.edu/
# http://www.austintexas.org/listings/lady-bird-lake-hike-and-bike-trail/4369/
# http://www.austintexas.org/listings/lady-bird-lake-hike-and-bike-trail/4369/
# http://www.austintexas.gov/sites/default/files/files/Public_Works/Boardwalk_Trail_Project/BOARDWALK_MAP.pdf
# http://www.austintexas.gov/sites/default/files/files/Public_Works/Boardwalk_Trail_Project/BOARDWALK_MAP.pdf
# http://dell.com/
# http://dell.com/
# http://www.techshop.ws/
# http://www.techshop.ws/
# http://www.cheaperthandirt.com/
# http://www.cheaperthandirt.com/
# http://www.plateauwildlife.com/
# http://www.plateauwildlife.com/
# http://lostpines.regency.hyatt.com
# http://lostpines.regency.hyatt.com
# http://vainaustin.com/
# http://vainaustin.com/
# http://www.cityofkyle.com/recreation/steeplechase-park
# http://www.cityofkyle.com/recreation/steeplechase-park
# http://www.centralmarket.com/Home?store=austin_lamar
# http://www.centralmarket.com/Home?store=austin_lamar
# http://www.c-fan.com/
# http://www.c-fan.com/
# www.samc-kyle.org
# www.samc-kyle.org
# http://www.biglots.com/
# http://www.biglots.com/
# http://www.allensboots.com/
# http://www.allensboots.com/
# http://elevenaustin.com/
# http://elevenaustin.com/
# https://momentsfromtheheart.com
# https://momentsfromtheheart.com
# http://crestviewpharmacy.com/
# http://crestviewpharmacy.com/
# http://trailerspacerecords.blogspot.com/
# http://trailerspacerecords.blogspot.com/
# http://www.austinparks.org/our-parks.html?parkid=373
# http://www.austinparks.org/our-parks.html?parkid=373
# http://elsapoatx.com/
# http://elsapoatx.com/
# http://eastsidepies.com/
# http://eastsidepies.com/
# http://www.austintexas.gov/pools#east
# http://www.austintexas.gov/pools#east
# http://texashotelvegas.com/
# http://texashotelvegas.com/
# http://www.craftmeats.com/
# http://www.craftmeats.com/
# http://www.littledeliandpizza.com/index.html
# http://www.littledeliandpizza.com/index.html
# http://www.kerbeylanecafe.com/
# http://www.kerbeylanecafe.com/
# http://www.capmetro.org/gismaps/stops/5275.html
# http://www.capmetro.org/gismaps/stops/5275.html
# http://www.capmetro.org/gismaps/stops/5544.html
# http://www.capmetro.org/gismaps/stops/5544.html
# http://www.capmetro.org/gismaps/stops/5545.html
# http://www.capmetro.org/gismaps/stops/5545.html
# http://www.capmetro.org/gismaps/stops/5546.html
# http://www.capmetro.org/gismaps/stops/5546.html
# http://www.capmetro.org/gismaps/stops/5547.html
# http://www.capmetro.org/gismaps/stops/5547.html
# http://www.capmetro.org/gismaps/stops/5548.html
# http://www.capmetro.org/gismaps/stops/5548.html
# http://www.capmetro.org/gismaps/stops/5549.html
# http://www.capmetro.org/gismaps/stops/5549.html
# http://www.capmetro.org/gismaps/stops/5550.html
# http://www.capmetro.org/gismaps/stops/5550.html
# http://www.capmetro.org/gismaps/stops/5551.html
# http://www.capmetro.org/gismaps/stops/5551.html
# http://www.capmetro.org/gismaps/stops/5552.html
# http://www.capmetro.org/gismaps/stops/5552.html
# http://www.capmetro.org/gismaps/stops/5553.html
# http://www.capmetro.org/gismaps/stops/5553.html
# http://www.capmetro.org/gismaps/stops/5274.html
# http://www.capmetro.org/gismaps/stops/5274.html
# http://www.capmetro.org/gismaps/stops/5272.html
# http://www.capmetro.org/gismaps/stops/5272.html
# http://www.capmetro.org/gismaps/stops/5273.html
# http://www.capmetro.org/gismaps/stops/5273.html
# http://www.oakhillappliance.com/
# http://www.oakhillappliance.com/
# http://www.downsouthrailhouse.com
# http://www.downsouthrailhouse.com
# https://www.lifetimefitness.com/en/clubs/south-austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/south-austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/south-austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/south-austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/south-austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/south-austin-tx/your-lt.html
# http://www.austinfilm.org
# http://www.austinfilm.org
# http://schools.bisdtx.org/default.aspx?name=cces.homepage
# http://schools.bisdtx.org/default.aspx?name=cces.homepage
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# https://www.lifetimefitness.com/en/clubs/austin-tx/your-lt.html
# http://www.pfisd.net//site/Default.aspx?PageID=45
# http://www.pfisd.net//site/Default.aspx?PageID=45
# http://www.batteriesplus.com/
# http://www.batteriesplus.com/
# https://www.uhcu.org/
# https://www.uhcu.org/
# http://www.elginfamilypetcenter.com/
# http://www.elginfamilypetcenter.com/
# http://www.schlotzskys.com/
# http://www.schlotzskys.com/
# http://serviceking.com/locations/82-service-king-round-rock
# http://serviceking.com/locations/82-service-king-round-rock
# http://www.ihg.com/intercontinental/hotels/gb/en/austin/ausha/hoteldetail
# http://www.ihg.com/intercontinental/hotels/gb/en/austin/ausha/hoteldetail
# http://www.austintheatre.org
# http://www.austintheatre.org
# http://www.austintheatre.org
# http://www.austintheatre.org
# http://www.palmdoor.com/sixth
# http://www.palmdoor.com/sixth
# http://www.fbcaustin.org/
# http://www.fbcaustin.org/
# http://smcaustin.org/
# http://smcaustin.org/
# http://www.texaco.com/
# http://www.texaco.com/
# http://www.wallerballroom.com/
# http://www.wallerballroom.com/
# http://www3.hilton.com/en/hotels/texas/hilton-austin-AUSCVHH/index.html
# http://www3.hilton.com/en/hotels/texas/hilton-austin-AUSCVHH/index.html
# http://www.austinpublicaccess.org
# http://www.austinpublicaccess.org
# http://westside.leanderisd.org
# http://westside.leanderisd.org
# http://www.greenmesquite.net
# http://www.greenmesquite.net
# http://www.austinexecutiveairport.com/
# http://www.austinexecutiveairport.com/
# http://www.scubaland.com/
# http://www.scubaland.com/
# http://ee.eanesisd.net/
# http://ee.eanesisd.net/
# http://www.elchilecafe.com/
# http://www.elchilecafe.com/
# http://www.floresmexican.com/
# http://www.floresmexican.com/
# http://hhs.hipponation.org
# http://hhs.hipponation.org
# library.georgetown.org
# library.georgetown.org
# http://www.walgreens.com/locator/walgreens-4501-Guadalupe-Austin-TX-78751/id=4704
# http://www.walgreens.com/locator/walgreens-4501-Guadalupe-Austin-TX-78751/id=4704
# http://danesbodyshop.com/
# http://danesbodyshop.com/
# https://maps.georgetown.org/city-hall/
# https://maps.georgetown.org/city-hall/
# http://locators.bankofamerica.com/locator/locator/624__S__Austin__Ave_78626_GEORGETOWN_TX/bank_branch_locations/
# http://locators.bankofamerica.com/locator/locator/624__S__Austin__Ave_78626_GEORGETOWN_TX/bank_branch_locations/
# http://www.eltacorrido.com/sur.html
# http://www.eltacorrido.com/sur.html
# http://www.ltisdschools.org/site/Default.aspx?PageID=8354
# http://www.ltisdschools.org/site/Default.aspx?PageID=8354
# http://www.co.hays.tx.us/five-mile-dam-park.aspx
# http://www.co.hays.tx.us/five-mile-dam-park.aspx
# http://www.crickethollowapts.com/
# http://www.crickethollowapts.com/
# http://www.argosyatcrestview.com/
# http://www.argosyatcrestview.com/
# http://www.tdcj.state.tx.us/unit_directory/ti.html
# http://www.tdcj.state.tx.us/unit_directory/ti.html
# http://www.bop.gov/locations/institutions/bas/
# http://www.bop.gov/locations/institutions/bas/
# http://blazertag.com
# http://blazertag.com
# http://parkside.leanderisd.org/
# http://parkside.leanderisd.org/
# http://www.hayscisd.net/BlancoVista.cfm
# http://www.hayscisd.net/BlancoVista.cfm
# http://www.takobarestaurant.com/
# http://www.takobarestaurant.com/
# https://www.mobileaustinnotary.com
# https://www.mobileaustinnotary.com
# http://www.allsaints-austin.org/
# http://www.allsaints-austin.org/
# http://www.dreamcarsaustin.com
# http://www.dreamcarsaustin.com
# http://vfw8925.org
# http://vfw8925.org
# http://cchs.bisdtx.org/
# http://cchs.bisdtx.org/
# http://downhomeranch.org
# http://downhomeranch.org
# http://www.bushschicken.com/
# http://www.bushschicken.com/
# http://www.khabele.org/
# http://www.khabele.org/
# https://www.brookshirebrothers.com/store-location/store-67
# https://www.brookshirebrothers.com/store-location/store-67
# http://www.kingfeedandhardware.com/
# http://www.kingfeedandhardware.com/
# http://www.wimberleyace.com/
# http://www.wimberleyace.com/
# http://www.wimberly.org
# http://www.wimberly.org
# http://www.concordhoa.com
# http://www.concordhoa.com
# https://foxhollowcondos.wordpress.com
# https://foxhollowcondos.wordpress.com
# http://www.machaikfl.com/
# http://www.machaikfl.com/
# http://www.swf-wc.usace.army.mil/granger/Recreation/Parks/Corpsparks.asp
# http://www.swf-wc.usace.army.mil/granger/Recreation/Parks/Corpsparks.asp
# http://www.lcra.org/parks/developed-parks/Pages/mckinney-roughs-nature-park.aspx
# http://www.dot.state.tx.us/tpp/hwy/ur/ur1825.htm

# %%
def update_website(website):
    if website[:7] != "http://":
        website = "http://" + website
    return website

# %%
update_website("eastsideshowroom.com")
# Out:
# 'http://eastsideshowroom.com'

# %%
update_website("http://alonavarshal.com")
# Out:
# 'http://alonavarshal.com'

# %% [markdown]
# Exploration of Phone Numbers

# %%
counter = 0
for element in get_element(osmfile, tags=('node', 'way')):
    if counter == 100:
        break
    
    for tag in element.iter("tag"):
        if tag.attrib['k'] == 'phone':
            try:
                re.compile(r'\d\d\d\-\d\d\d\-\d\d\d\d').search(tag.attrib['v']).group()
                
            except AttributeError:
                
                phno = []
                numbers = list(tag.attrib['v'].lstrip("+1").strip("("))
#                print numbers
                counter += 1
                for char in numbers:
                    try:
                        if int(char) in [x for x in range(10)]:
                            phno.append(char)
                    except ValueError:
                        continue
                newnum = "".join(phno)
                newnum = newnum[:3] + "-" + newnum[3:6] + "-" + newnum[6:]
                    
                print tag.attrib['v'], "=>", newnum
# Out:
# +1 512 322-9168 => 512-322-9168
# (512) 282-0182 => 512-282-0182
# (512) 782-5659 => 512-782-5659
# (512) 795-8593 => 512-795-8593
# (512) 835-5400 => 512-835-5400
# (512) 454-6691 => 512-454-6691
# +1 512 459-6279 => 512-459-6279
# 5122821326 => 512-282-1326
# (512) 339-1181 => 512-339-1181
# +1 512 480 8441 => 512-480-8441
# (512) 251-9037 => 512-251-9037
# (512) 251-4553 => 512-251-4553
# (512) 326-4395 => 512-326-4395
# (512) 443-1057 => 512-443-1057
# (512) 448-2222 => 512-448-2222
# (512) 469-5966 => 512-469-5966
# (512) 892-6699 => 512-892-6699
# (512) 339-7860 => 512-339-7860
# (512) 832-8788 => 512-832-8788
# (512) 444-2205 => 512-444-2205
# (512) 431-2133 => 512-431-2133
# (512) 444-7770 => 512-444-7770
# (512) 494-9336 => 512-494-9336
# (512) 472-9240 => 512-472-9240
# (512) 861-7020 => 512-861-7020
# (512) 476-1490 => 512-476-1490
# (512) 255 - 3629 => 512-255-3629
# (512) 238-8008 => 512-238-8008
# (512) 244-2222 => 512-244-2222
# (512) 255-6952 => 512-255-6952
# (512) 334-4684 => 512-334-4684
# (512) 494-9300 => 512-494-9300
# (512) 477-2676 => 512-477-2676
# (512) 501-6738 => 512-501-6738
# (512) 472-8306 => 512-472-8306
# (512) 693-2464 => 512-693-2464
# (512) 996-8900 => 512-996-8900
# (512) 495-9425 => 512-495-9425
# (512) 474-7749 => 512-474-7749
# (512) 494-1150 => 512-494-1150
# (512) 336-5999 => 512-336-5999
# (512) 335-5115 => 512-335-5115
# (512) 335-0300 => 512-335-0300
# (512) 336-8888 => 512-336-8888
# 512) 719-5575 => 512-719-5575
# (512) 832-9722 => 512-832-9722
# (512) 833-8188 => 512-833-8188
# (512) 912-0033 => 512-912-0033
# (512) 445-5101 => 512-445-5101
# (512) 363-5622 => 512-363-5622
# +1 512 368 1818 => 512-368-1818
# +1 512 454 3664 => 512-454-3664
# 512- 514-0755 => 512-514-0755
# 5123361328 => 512-336-1328
# 5124763700 => 512-476-3700
# +1 512 323 5700 => 512-323-5700
# 5124730405 => 512-473-0405
# 512 328 2114 => 512-328-2114
# 512 330 9888 => 512-330-9888
# 5123947041 => 512-394-7041
# 512.391.1668 => 512-391-1668
# 15124209035 => 512-420-9035
# (512) 459-6513 => 512-459-6513
# +15 12 554 4678 => 512-554-4678
# 512 335 5555 => 512-335-5555
# 512 258 8114 => 512-258-8114
# (512) 821-1112 => 512-821-1112
# +1 512 836 7644 => 512-836-7644
# +1 512 402 7811 => 512-402-7811
# +1 512 246 9800 => 512-246-9800
# (512) 828-5500 => 512-828-5500
# (512) 478-7328 => 512-478-7328
# (512) 800-3833 => 512-800-3833
# (512) 250-9347 => 512-250-9347
# (512) 335-0770 => 512-335-0770
# (512) 258-5545 => 512-258-5545
# (512) 258-0647 => 512-258-0647
# (512) 219-8366 => 512-219-8366
# (512) 996-0095 => 512-996-0095
# (512) 336-7200 => 512-336-7200
# (512) 996-0504 => 512-996-0504
# (512) 774-4359 => 512-774-4359
# (512) 333-1112 => 512-333-1112
# (512) 249-7447 => 512-249-7447
# (512) 782-9263 => 512-782-9263
# (512) 864-8000 => 512-864-8000
# (512) 478-8086 => 512-478-8086
# (512) 441-3692 => 512-441-3692
# (512) 459-8308 => 512-459-8308
# (512) 506-9250 => 512-506-9250
# (512) 973-8753 => 512-973-8753
# (512) 251-5286 => 512-251-5286
# (512) 442-1578 => 512-442-1578
# (512) 288-5713 => 512-288-5713
# (512) 301-9772 => 512-301-9772
# (512) 282-0990 => 512-282-0990
# (512) 926-0586 => 512-926-0586
# (512) 259-5755 => 512-259-5755
# (512) 837-9580 => 512-837-9580
# (512) 794-8227 => 512-794-8227

# %%
def is_phone_num(element):
    return (element.attrib['k'] == "phone" or element.attrib['k'] == "contact:phone")

# %%
def update_phone(number):
    phno = []
    numbers = list(number.lstrip("+1").strip("("))
    for char in numbers:
        try:
            if int(char) in [x for x in range(10)]:
                phno.append(char)
        except ValueError:
            continue
    newnum = "".join(phno)
    newnum = newnum[:3] + "-" + newnum[3:6] + "-" + newnum[6:]
                    
    return newnum

# %%
counter = 0
for element in get_element(osmfile):
    if counter == 10:
        break
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_phone_num(tag):
                print update_phone(tag.attrib['v'])
                counter += 1
# Out:
# 512-322-9168
# 512-282-0182
# 512-442-0655
# 512-386-3300
# 512-447-8288
# 512-442-8476
# 512-478-1933
# 512-447-1447
# 512-442-6719
# 512-892-6038

# %%
def is_country(element):
    return (element.attrib['k'] == "addr:country")

# %%
counter = 0
for element in get_element(osmfile):
    if counter == 10:
        break
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_country(tag):
                print tag.attrib['v']
                counter += 1
# Out:
# US
# US
# US
# US
# US
# US
# US
# US
# US
# US

# %%
def is_postcode(element):
    return (element.attrib['k'] == "postcode" or element.attrib['k'] == "postal_code")

# %%
counter = 0
for element in get_element(osmfile):
    if counter == 10:
        break
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_postcode(tag):
                print tag.attrib['v']
                counter += 1
# Out:
# 78721
# 78735
# 78757
# 78757
# 78735
# 78735
# 78735
