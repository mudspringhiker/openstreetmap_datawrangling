# %% [markdown]
# # P3: Wrangling OpenStreetMap Data of Austin, TX
#
# ## Part 1. Exploring and auditing data

# %% [markdown]
# ## Data
#
# This project looks at the Austin, TX area, where I live. As delineated in the class, the data was obtained by downloading an already-prepared extract which I found in the link below:
#
# https://mapzen.com/data/metro-extracts/metro/austin_texas/
#
# The 66MB raw OpenStreetMap OSM XML dataset was chosen. After unzipping, the file was about 1.4 GB dataset. Opening this dataset using Sublime took a while.

# %% [markdown]
# ## Obtaining a sample data set
#
# Since the data were too large to do preliminary investigation, a sample was taken using the code provided in the project details instructions. This smaller data were produced by taking only the 10th top level element in the xml tree.

# %%
import xml.etree.cElementTree as ET

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# %%
OSM_FILE = "austin_texas.osm"
SAMPLE_FILE = "sample.osm"
k = 10

# %%
with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# ##### The link to the sample.osm is here:
#
# https://www.dropbox.com/s/084lnztuwgxdgtm/sample.osm?dl=0

# %% [markdown]
# #### Alternative way of examining smaller data set
#
# In some cases, the complete data were used but instead of iterating through all the elements, the number of iterations was set to a certain number. For example:

# %%
from IPython.display import Image
Image("counter.png")

# %% [markdown]
# ## Exploration of Dataset

# %% [markdown]
# ### High Level Tags

# %% [markdown]
# To determine the number of high level tags the dataset has, iterative parsing is done. The tags can be counted using a defaultdict.

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import pprint

# %%
def count_tags(filename):
    tag_counts = defaultdict(int)
    for event, elem in ET.iterparse(filename):
        tag_counts[elem.tag] += 1
    return tag_counts

# %% [markdown]
# Examination of high level tags in the whole dataset:

# %%
tags = count_tags(OSM_FILE)

# %%
pprint.pprint(dict(tags))
# Out:
# {'bounds': 1,
#  'member': 20197,
#  'nd': 6985591,
#  'node': 6356394,
#  'osm': 1,
#  'relation': 2357,
#  'tag': 2377504,
#  'way': 666390}

# %% [markdown]
# ### Checking the k values

# %% [markdown]
# Checking the k values will give us an idea of how much parameters we're dealing with. The following is the code from the quiz from the case study:

# %%
import re

# %% [markdown]
# The quiz introduced the following regex expressions, which were contructed based on prior knowledge of the structure/format of the k values.
#
# The "lower" regex is meant to look for any word that must start with a character from a-z or could contain an underscore.
#
# The "lower_colon" regex represents values with a colon.
#
# "Problemchars" are those that have any of the characters within the square brackets.

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
def key_type(element, keys):
    if element.tag == 'tag':
        try:
            lower.search(element.attrib['k']).group()
            keys["lower"] += 1
        except AttributeError:
            try:
                lower_colon.search(element.attrib['k']).group()
                keys["lower_colon"] += 1
            except AttributeError:
                try:
                    problemchars.search(element.attrib['k']).group()
                    keys["problemchars"] += 1
                except AttributeError:
                    keys["other"] += 1
    return keys

# %%
def process_map_tagtypes(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other":0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
    return keys

# %%
keys = process_map_tagtypes(OSM_FILE)

# %%
pprint.pprint(keys)
# Out:
# {'lower': 1297812, 'lower_colon': 1067727, 'other': 11964, 'problemchars': 1}

# %% [markdown]
# ### Exploring Users

# %% [markdown]
# This gives how many users have contributed to the Austin, TX osm file.

# %%
def get_user(element):
    return

# %%
def process_map_users(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for key in element.attrib:
            if key == 'uid':
                users.add(element.attrib[key])
    return users

# %%
users = process_map_users(OSM_FILE)

# %%
len(users)
# Out:
# 1155

# %% [markdown]
# ### Auditing and Improving Street Names

# %% [markdown]
# Auditing the osmfile and using the variable 'mapping', check to see the changes needed to fix the unexpected street types to the appropriate ones in the expected list.

# %% [markdown]
# The following regex was used to look for street names.

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

# %% [markdown]
# During auditing, street names that have the following elements to the expected list are omitted.

# %%
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Cove", "Highway", "Lane"]

# %% [markdown]
# audit_street_type function searches for the street name using the regex and adding the name to a set.

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

# %% [markdown]
# The function below determines whether a tag value is a street name.

# %%
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

# %% [markdown]
# Audits the osm file.

# %%
def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

# %% [markdown]
# Auditing the sample osm file:

# %%
st_types = audit(OSM_FILE)

# %% [markdown]
# ##### Printing out st_types showed streets that need to be fixed.

# %%
st_types
# Out:
# defaultdict(set,
#             {'100': {'Avery Ranch Blvd Building A #100',
#               'Jollyville Road Suite 100',
#               'Old Jollyville Road, Suite 100'},
#              '101': {'4207 James Casey st #101'},
#              '104': {'11410 Century Oaks Terrace Suite #104',
#               'S 1st St, Suite 104'},
#              '1100': {'Farm-to-Market Road 1100'},
#              '117': {'County Road 117'},
#              '12': {'Ranch to Market Road 12'},
#              '120': {'Building B Suite 120'},
#              '129': {'County Road 129'},
#              '1327': {'FM 1327', 'Farm-to-Market Road 1327'},
#              '138': {'County Road 138'},
#              '1431': {'Farm-to-Market Road 1431', 'Old Farm-to-Market 1431'},
#              '150': {'Farm-to-Market Road 150', 'IH-35 South, #150'},
#              '1625': {'Farm-to-Market Road 1625'},
#              '1626': {'F.M. 1626', 'FM 1626', 'Farm-to-Market Road 1626'},
#              '163': {'Bee Cave Road Suite 163'},
#              '170': {'County Road 170'},
#              '1805': {'N Interstate 35, Suite 1805'},
#              '1825': {'FM 1825'},
#              '1826': {'Farm To Market Road 1826', 'Ranch to Market Road 1826'},
#              '183': {'N HWY 183',
#               'U.S. 183',
#               'US 183',
#               'US Highway 183',
#               'United States Highway 183'},
#              '203': {'West Ben White Boulevard #203',
#               'West Ben White Boulevard, #203'},
#              '213': {'Executive Center Drive Suite 213'},
#              '2222': {'Ranch to Market Road 2222'},
#              '2243': {'Old FM 2243'},
#              '2244': {'RM 2244'},
#              '260': {'S Interstate 35, #260'},
#              '275': {'West 11th Street, Suite 275'},
#              '2769': {'Farm-to-Market Road 2769'},
#              '280': {'County Road 280'},
#              '290': {'C R 290',
#               'County Road 290',
#               'E Hwy 290',
#               'East Highway 290',
#               'East Hwy 290',
#               'Helios Way, Bldg 2, Suite 290',
#               'Highway 290',
#               'U.S. 290',
#               'US 290',
#               'US Highway 290',
#               'W HWY 290',
#               'W Highway 290',
#               'W Hwy 290',
#               'W. Highway 290',
#               'West Highway 290',
#               'West US Highway 290'},
#              '298': {'N I-35 Suite 298'},
#              '3': {'Shoal Creek Blvd, Bld 3'},
#              '300': {'321 W Ben White Blvd #300', 'West 5th Street #300'},
#              '3000a': {'Research Blvd #3000a'},
#              '301': {'Hwy 290 W. Ste. 301', 'S Bell Blvd., Suite 301'},
#              '306': {'Meadows Dr #306'},
#              '3177': {'FM 3177'},
#              '320': {'W. University Avenue,Ste 320'},
#              '35': {'9600 S IH 35',
#               'Highway Interstate 35',
#               'I 35',
#               'Interstate 35',
#               'Interstate Highway 35',
#               'N Interstate Highway 35',
#               'N. IH 35',
#               'North IH 35',
#               'North Interstate Highway 35',
#               'S Interstate 35',
#               'S Interstate Highway 35',
#               'South I 35',
#               'South Interstate 35'},
#              '4': {'4201 South Congress Avenue #4'},
#              '400': {'North Lakeline Boulevard, Ste. 400'},
#              '406': {'North Highway 183 #406'},
#              '414': {'County Road 414'},
#              '45': {'TX 45'},
#              '452': {'Country Rd. 452'},
#              '459': {'County Road 459'},
#              '535': {'FM 535'},
#              '6': {'N IH 35 Bldg. 6'},
#              '600': {'Burnet Road #600'},
#              '619': {'FM 619'},
#              '620': {'FM 620',
#               'N FM 620',
#               'RM 620',
#               'RR 620',
#               'Ranch Road 620',
#               'Ranch-to-Market Road 620'},
#              '685': {'FM 685', 'Farm to Market 685'},
#              '7': {'N I H 35 Bldg 7'},
#              '71': {'Hwy 71', 'TX 71', 'W Hwy 71', 'West Highway 71'},
#              '79': {'U.S. 79'},
#              '8': {'Arterial 8', 'Burnet Road #8'},
#              '812': {'Farm-to-Market Road 812'},
#              '969': {'FM 969'},
#              '973': {'Farm-to-Market Road 973', 'N Farm-To-Market Road 973'},
#              'A': {'Avenue A'},
#              'A-15': {'W. Anderson Lane, Suite A-15'},
#              'A500': {'Burnet Rd Ste, A500'},
#              'Acres': {'Green Acres'},
#              'Adventurer': {'Adventurer'},
#              'Affirmed': {'Affirmed'},
#              'Alley': {'Oak Alley'},
#              'Alps': {'Julian Alps'},
#              'Alto': {'Camino Alto', 'Palo Alto'},
#              'Amistad': {'Circulo de Amistad'},
#              'Apache': {'Apache'},
#              'Arbolago': {'Camino Arbolago'},
#              'Arrow': {'Broken Arrow'},
#              'Atlantic': {'Atlantic'},
#              'Austin': {'Research Blvd, Austin'},
#              'Ave': {'Barstow Ave',
#               'E. University Ave',
#               'Round Rock Ave',
#               'S Congress Ave',
#               'South Congress Ave'},
#              'Ave.': {'Woodrow Ave.'},
#              'Avene': {'South Congress Avene'},
#              'B': {'Avenue B', 'South Interstate 35, Suite B'},
#              'B100': {'North Lamar Boulevard suite #B100'},
#              'Barrhead': {'Barrhead'},
#              'Bend': {'Allende Bend',
#               'Badger Bend',
#               'Banbury Bend',
#               'Bangor Bend',
#               'Bantom Woods Bend',
#               'Bar Harbor Bend',
#               'Barrel Bend',
#               'Basie Bend',
#               'Basket Flower Bend',
#               'Bay City Bend',
#               'Bayou Bend',
#               'Bonaparte Bend',
#               'Brantley Bend',
#               'Brubeck Bend',
#               'Burley Bend',
#               'Cactus Bend',
#               'Canola Bend',
#               'Chrighton Castle Bend',
#               'Chukar Bend',
#               'Concho Creek Bend',
#               'Cypress Bend',
#               'Dartford Bend',
#               'Derecho Bend',
#               'East Custers Creek Bend',
#               'Georgia Coleman Bend',
#               'Giblin Bend',
#               'Hayden Bend',
#               'Hitcher Bend',
#               'Hondo Bend',
#               'Honeybee Bend',
#               'Horseshoe Bend',
#               'Huckabee Bend',
#               'Indian Oak Bend',
#               'Iriona Bend',
#               'Izoro Bend',
#               'Keystone Bend',
#               'La Barzola Bend',
#               'La Siesta Bend',
#               'Magee Bend',
#               'Mancuso Bend',
#               'Mead Bend',
#               'Melekhin Bend',
#               'Mercedes Bend',
#               'Misty Bend',
#               'Moonlight Bend',
#               'New Boston Bend',
#               'Parker Bend',
#               'Piney Creek Bend',
#               'Rainbow Bend',
#               'Rifle Bend',
#               'River Bend',
#               'Shadow Bend',
#               'Silkgrass Bend',
#               'Summit Bend',
#               'Sun Shower Bend',
#               'Sunhillow Bend',
#               'Tiombe Bend',
#               'Turtle Mountain Bend',
#               'Waterway Bend',
#               'West Custers Creek Bend'},
#              'Birch': {'River Birch'},
#              'Blackfoot': {'Blackfoot'},
#              'Bluff': {"Bubba's Bluff",
#               'Bullick Bluff',
#               'Crescent Bluff',
#               'Scout Bluff',
#               'Travis Bluff'},
#              'Blvd': {'10000 Research Blvd',
#               'Airport Blvd',
#               'E Palm Valley Blvd',
#               'Escarpment Blvd',
#               'Industrial Blvd',
#               'Industrial Oaks Blvd',
#               'N Bell Blvd',
#               'N. Lamar Blvd',
#               'North Lamar Blvd',
#               'North Research Blvd',
#               'Research Blvd',
#               'South Bell Blvd',
#               'South Lamar Blvd',
#               'Stonelake Blvd',
#               'Swenson Farms Blvd',
#               'West Louis Henna Blvd'},
#              'Blvd.': {'East Old Settlers Blvd.',
#               'Research Blvd.',
#               'South Exposition Blvd.',
#               'South Lamar Blvd.',
#               'Tandem Blvd.',
#               'W North Loop Blvd.'},
#              'Boggy': {'Big Boggy'},
#              'Bonanza': {'Bonanza'},
#              'Bonita': {'Sendera Bonita'},
#              'Bottom': {'Creek Bottom'},
#              'Branch': {'Malaquita Branch', 'Spring Branch'},
#              'Bridge': {'Knights Bridge'},
#              'Buckskin': {'Buckskin'},
#              'C': {'Avenue C'},
#              'C-200': {'9600 IH 35 C-200'},
#              'C1-100': {'Hill Country Blvd., Suite C1-100'},
#              'Caliche': {'Calle Caliche'},
#              'Calle': {'Medio Calle'},
#              'Camelback': {'Camelback'},
#              'Camino': {'El Viejo Camino'},
#              'Cannon': {'West William Cannon'},
#              'Cantera': {'La Cantera'},
#              'Canterwood': {'Canterwood'},
#              'Canyon': {'Ambush Canyon',
#               'Critter Canyon',
#               'Long Arrow Canyon',
#               'Shadow Canyon',
#               'Spearfish Canyon',
#               'Ventana Canyon'},
#              'Capri': {'Capri'},
#              'Carrara': {'Carrara'},
#              'Casitas': {'Casitas'},
#              'Castle': {'Caisteal Castle'},
#              'CastlePath': {'Raglan CastlePath'},
#              'Catcher': {'Dream Catcher'},
#              'Catorce': {'Real Catorce'},
#              'Cave': {'Wind Cave'},
#              'Cc': {'Misty Heights Cc'},
#              'Challenger': {'Challenger'},
#              'Chase': {'Glen Rose Chase',
#               'Mustang Chase',
#               'Pecan Chase',
#               'Pony Chase',
#               'Shetland Chase'},
#              'Chavez': {'West Cesar Chavez'},
#              'Circle': {'Abbate Circle',
#               'Abbey Circle',
#               'Aberdeen Circle',
#               'Aguila Circle',
#               'Alameda Trace Circle',
#               'Alazan Circle',
#               'Alcorn Circle',
#               'Aldford Circle',
#               'Alpine Circle',
#               'Amy Circle',
#               'Antelope Circle',
#               'Apache Springs Circle',
#               'Apple Springs Circle',
#               'Apple Valley Circle',
#               'Apple Vista Circle',
#               'Arbor Circle',
#               'Ardmore Circle',
#               'Arronimink Circle',
#               'Artesian Circle',
#               'Ashland Circle',
#               'Augusta Circle',
#               'Aurora Circle',
#               'Avebury Circle',
#               'Bahia Circle',
#               'Balcones Woods Circle',
#               'Barranca Circle',
#               'Barton Point Circle',
#               'Barton Village Circle',
#               'Bat Hawk Circle',
#               'Baxter Circle',
#               'Bay Circle',
#               'Beaconsdale Circle',
#               'Beartree Circle',
#               'Beauregard Circle',
#               'Beck Circle',
#               'Beckett Circle',
#               'Bee Hill Circle',
#               'Bee Tree Circle',
#               'Begonia Circle',
#               'Belclaire Circle',
#               'Bell Rock Circle',
#               'Bella Montagna Circle',
#               'Belmont Circle',
#               'Belo Horizonte Circle',
#               'Bent Oak Circle',
#               'Benwick Circle',
#               'Berry Hill Circle',
#               'Berrylawn Circle',
#               'Berwyn Circle',
#               'Bexton Circle',
#               'Big Horn Circle',
#               'Big Oak Circle',
#               'Big Trail Circle',
#               'Bighorn Circle',
#               'Birdlip Circle',
#               'Birdwood Circle',
#               'Bissel Circle',
#               'Bitteroot Circle',
#               'Blake Manor Circle',
#               'Blanco Circle',
#               'Blinn Circle',
#               'Blue Spruce Circle',
#               'Blue Water Circle',
#               'Bluebell Circle',
#               'Blueberry Circle',
#               'Bluebonnet Circle',
#               'Bluestone Circle',
#               'Bluff Park Circle',
#               'Bluffridge Circle',
#               'Boca Chica Circle',
#               'Boffi Circle',
#               'Bolles Circle',
#               'Booth Circle',
#               'Botany Bay Circle',
#               'Bramble Bush Circle',
#               'Bramblewood Circle',
#               'Brandywine Circle',
#               'Breezeknoll Circle',
#               'Briar Wood Circle',
#               'Bridlington Circle',
#               'Brighton Circle',
#               'Brock Circle',
#               'Brompton Circle',
#               'Bronco Circle',
#               'Brook Valley Circle',
#               'Brookwood Circle',
#               'Brown Bluff Circle',
#               'Brownlee Circle',
#               'Bruno Circle',
#               'Buckhorn Circle',
#               'Buckingham Circle',
#               'Buena Vista Circle',
#               'Bull Run Circle',
#               'Bundy Crest Circle',
#               'Bundyhill Circle',
#               'Bunratty Circle',
#               'Bunyon Circle',
#               'Burly Oak Circle',
#               'Burning Tree Circle',
#               'Burnside Circle',
#               'Burnt Circle',
#               'Burris Circle',
#               'Butler Circle',
#               'Button Bend Circle',
#               'Cade Circle',
#               'Cadiz Circle',
#               'Caisson Circle',
#               'Caladium Circle',
#               'Camelot Circle',
#               'Canard Circle',
#               'Candleberry Circle',
#               'Cannes Circle',
#               'Canteen Circle',
#               'Canyon Glen Circle',
#               'Canyonbend Circle',
#               'Caravan Circle',
#               'Carbine Circle',
#               'Cardinal Hill Circle',
#               'Carefree Circle',
#               'Cascade Circle',
#               'Cedar Circle',
#               'Cedar Ridge Circle',
#               'Cedar Springs Circle',
#               'Cedarhurst Circle',
#               'Cedarlawn Circle',
#               'Celeste Circle',
#               'Centimeter Circle',
#               'Central Commerce Circle',
#               'Ceylon Tea Circle',
#               'Chalet Circle',
#               'Chama Circle',
#               'Champions Circle',
#               'Channing Circle',
#               'Charla Circle',
#               'Charm Circle',
#               'Chase Circle',
#               'Chatsworth Circle',
#               'Chayton Circle',
#               'Cherry Meadow Circle',
#               'Cherry Tree Circle',
#               'Cherrylawn Circle',
#               'Chevy Circle',
#               'Cheyenne Circle',
#               'Chicadee Circle',
#               'Chimney Creek Circle',
#               'Chippewa Circle',
#               'Chittim Circle',
#               'Chukar Circle',
#               'Cima Circle',
#               'Citation Circle',
#               'Clarewood Circle',
#               'Clearsky Circle',
#               'Clemente Circle',
#               'Cliff Circle',
#               'Cliffwood Circle',
#               'Clivden Circle',
#               'Cloudberry Circle',
#               'Coats Circle',
#               'Cocao Circle',
#               'Colmenero Circle',
#               'Commodore Circle',
#               'Compass Circle',
#               'Cone Circle',
#               'Congressional Circle',
#               'Constantino Circle',
#               'Constellation Circle',
#               'Cooper Circle',
#               'Coral Ridge Circle',
#               'Cornish Circle',
#               'Coronado Circle',
#               'Cottonwood Circle',
#               'Countryside Circle',
#               'Courtland Circle',
#               'Courtleigh Circle',
#               'Craigwood Circle',
#               'Craybrough Circle',
#               'Cree Circle',
#               'Creeks Edge Circle',
#               'Creekwood Circle',
#               'Crest Ridge Circle',
#               'Cromwell Circle',
#               'Crosby Circle',
#               'Crosswind Circle',
#               'Crownspoint Circle',
#               'Crystal Creek Circle',
#               'Culebra Circle',
#               'Current Circle',
#               'Currywood Circle',
#               'Cypress Knee Circle',
#               'Dakota Circle',
#               'Darvone Circle',
#               'Dawn Hill Circle',
#               'Dawnridge Circle',
#               'De Soto Circle',
#               'Debba Circle',
#               'Declaration Circle',
#               'Deep Circle',
#               'Deer Ridge Circle',
#               'Deercreek Circle',
#               'Denell Circle',
#               'Desert Oak Circle',
#               'Devon Circle',
#               'Diamond Head Circle',
#               'Dill Circle',
#               'Dillard Circle',
#               'Dime Circle',
#               'Disraeli Circle',
#               'Diversion Circle',
#               'Dondale Circle',
#               'Donovan Circle',
#               'Dormax Circle',
#               'Dorsett Oaks Circle',
#               'Dove Springs Circle',
#               'Dry Run Circle',
#               'Dueling Oak Circle',
#               'Dumaine Circle',
#               'Dupree Circle',
#               'Dymalor Circle',
#               'Eanes Circle',
#               'Earl Circle',
#               'East Leslie Circle',
#               'Edge Park Circle',
#               'Egret Circle',
#               'Elder Circle',
#               'Eleos Circle',
#               'Elk Park Circle',
#               'Ellington Circle',
#               'Elm Grove Circle',
#               'Emerald Forest Circle',
#               'Encino Circle',
#               'Enclave Mesa Circle',
#               'Endeavor Circle',
#               'Eric Circle',
#               'Esplanade Circle',
#               'Evadean Circle',
#               'Evening Sky Circle',
#               'Ewing Circle',
#               'Fairlake Circle',
#               'Fairmont Circle',
#               'Fathom Circle',
#               'Fawn Circle',
#               'Fawnridge Circle',
#               'Federal Circle',
#               'Ferndale Circle',
#               'Firestone Circle',
#               'Fitchburg Circle',
#               'Flagstaff Circle',
#               'Flinnwood Circle',
#               'Flintlock Circle',
#               'Flintrock Circle',
#               'Flynn Circle',
#               'Foley Circle',
#               'Folklore Circle',
#               'Fora Circle',
#               'Fort Sumter Circle',
#               'Founders Circle',
#               'Fountainbleu Circle',
#               'Fox Chase Circle',
#               'Framingham Circle',
#               'Freemont Circle',
#               'Frost Circle',
#               'Galleria Circle',
#               'Galliano Circle',
#               'Gallo Circle',
#               'Garcreek Circle',
#               'Garrison Circle',
#               'Gateshead Circle',
#               'Gavilan Circle',
#               'Gem Circle',
#               'Geneva Circle',
#               'Gentilly Circle',
#               'Glazier Circle',
#               'Glencoe Circle',
#               'Glenhaven Circle',
#               'Glenview Circle',
#               'Glowworm Circle',
#               'Goeth Circle',
#               'Golden Hills Circle',
#               'Grand Oak Circle',
#               'Green Shore Circle',
#               'Greenslope Circle',
#               'Grove Crest Circle',
#               'Guajolote Circle',
#               'Gungrove Circle',
#               'Gunsmoke Circle',
#               'Haddick Circle',
#               'Hamden Circle',
#               'Hamilton Point Circle',
#               'Hanging Oak Circle',
#               'Hardy Circle',
#               'Harvest Circle',
#               'Harwill Circle',
#               'Hayride Circle',
#               'Headway Circle',
#               'Heathercrest Circle',
#               'Hedder Circle',
#               'Helmway Circle',
#               'Hidden Hill Circle',
#               'Hidden View Circle',
#               'High Mountain Circle',
#               'Highland Hills Circle',
#               'Highpoint Circle',
#               'Hill Meadow Circle',
#               'Hillbrook Circle',
#               'Hillside Circle',
#               'Hillspring Circle',
#               'Hillview Circle',
#               'Hilwin Circle',
#               'Hitching Post Circle',
#               'Hogan Circle',
#               'Holly Oak Circle',
#               'Homedale Circle',
#               'Honeycomb Circle',
#               'Honeycomb Rock Circle',
#               'Hood Circle',
#               'Howden Circle',
#               'Howerington Circle',
#               'Hubbard Circle',
#               'Hull Circle',
#               'Hundred Oaks Circle',
#               'Huntridge Circle',
#               'Hupa Circle',
#               'Hurst Creek Circle',
#               'Hyclimb Circle',
#               'Hyland Circle',
#               'Hymeadow Circle',
#               'Iguana Circle',
#               'Indian Quail Circle',
#               'Indio Circle',
#               'Inspiration Circle',
#               'Inverrary Circle',
#               'Inwood Circle',
#               'Irongate Circle',
#               'Ironwood Circle',
#               'Javelina Circle',
#               'Jekel Circle',
#               'Jester Circle',
#               'Jill Sue Circle',
#               'Jolena Circle',
#               'Joshua Tree Circle',
#               'Juno Circle',
#               'Kafka Circle',
#               'Kentshire Circle',
#               'Knight Circle',
#               'Knollpark Circle',
#               'Knollwood Circle',
#               'Kollmeyer Circle',
#               'Konstanty Circle',
#               'Lake Wood Circle',
#               'Lakefront Circle',
#               'Lakehead Circle',
#               'Lakeland Circle',
#               'Lakepoint Circle',
#               'Lakeridge Circle',
#               'Lakeshore Circle',
#               'Lakeview Circle',
#               'Lambert Circle',
#               'Lamplight Village Circle',
#               'Lampwick Circle',
#               'Laurel Circle',
#               'Laurel Creek Circle',
#               'Lazy Brook Circle',
#               'Leaf Circle',
#               'Leaning Oak Circle',
#               'Leaning Rock Circle',
#               'Ledgerock Circle',
#               'Lee Sage Circle',
#               'Leesburg Circle',
#               'Lewood Circle',
#               'Libyan Circle',
#               'Lime Stone Circle',
#               'Lindenwood Circle',
#               'Little Creek Circle',
#               'Little Hill Circle',
#               'Little Oak Circle',
#               'Live Oak Circle',
#               'Lomita Verde Circle',
#               'Lost Creek Circle',
#               'Lost Ridge Circle',
#               'Lostwood Circle',
#               'Lyra Circle',
#               'Madrone Circle',
#               'Maha Circle',
#               'Manana Mountain Circle',
#               'Manchester Circle',
#               'Mandeville Circle',
#               'Manor Circle',
#               'Mansfield Circle',
#               'Map Circle',
#               'Maplelawn Circle',
#               'Maplewood Circle',
#               'Marks Circle',
#               'Marlborough Circle',
#               'Marston Circle',
#               'Marywood Circle',
#               'Mason Dixon Circle',
#               'Masters Circle',
#               'Masthead Circle',
#               'Matador Circle',
#               'Mathis Circle',
#               'Maywood Circle',
#               'Mc Carthy Circle',
#               'Meadgreen Circle',
#               'Meadow Circle',
#               'Meadow Creek Circle',
#               'Mecca Circle',
#               'Merion Circle',
#               'Merion Cricket Circle',
#               'Merrybrook Circle',
#               'Merrywing Circle',
#               'Mesa Oaks Circle',
#               'Mesa Trails Circle',
#               'Mesa Verde Circle',
#               'Metairie Circle',
#               'Mia Tia Circle',
#               'Michele Circle',
#               'Midoak Circle',
#               'Minda Circle',
#               'Mini Circle',
#               'Minot Circle',
#               'Mission Hill Circle',
#               'Mistyglen Circle',
#               'Mistywood Circle',
#               'Monmouth Circle',
#               'Monticello Circle',
#               'Montoya Circle',
#               'Mooring Circle',
#               'Morado Circle',
#               'Morningstar Circle',
#               'Mosquero Circle',
#               'Mosswood Circle',
#               'Mount Bonnell Circle',
#               'Mount View Circle',
#               'Mountain Lake Circle',
#               'Mountain Path Circle',
#               'Mountain Ridge Circle',
#               'Mountain Top Circle',
#               'Mountain Villa Circle',
#               'Mountainwood Circle',
#               'Mountbatten Circle',
#               'Mourning Dove Circle',
#               'Murillo Circle',
#               'Mustang Island Circle',
#               'Mystic Oaks Circle',
#               'Newfoundland Circle',
#               'Nob Hill Circle',
#               'North Ridge Circle',
#               'North Scout Island Circle',
#               'Northcrest Circle',
#               'Northland Circle',
#               'Northwood Circle',
#               'Oak Cliff Circle',
#               'Oak Creek Circle',
#               'Oak Grove Circle',
#               'Oak Haven Circle',
#               'Oak Meadow Circle',
#               'Oak Shadows Circle',
#               'Oakdale Circle',
#               'Oakleaf Circle',
#               'Oakmountain Circle',
#               'Oakwood Circle',
#               'Oliver Circle',
#               'Orangewood Circle',
#               'Orchard Park Circle',
#               'Overland Hills Circle',
#               'Overlook Circle',
#               'Overstreet Circle',
#               'Oxbow Circle',
#               'Paddington Circle',
#               'Palm Circle',
#               'Palma Circle',
#               'Palmetto Circle',
#               'Paloma Circle',
#               'Paradise Manor Circle',
#               'Park Circle',
#               'Park Thirty Five Circle',
#               'Parkview Circle',
#               'Partage Circle',
#               'Partridge Circle',
#               'Paseo de Vaca Circle',
#               'Patio Circle',
#               'Pebblestone Circle',
#               'Pecan Circle',
#               'Penelope Circle',
#               'Pescado Circle',
#               'Phillips Circle',
#               'Pinehurst Circle',
#               'Pinto Circle',
#               'Pistol Pass Circle',
#               'Plateau Circle',
#               'Pleasant Meadow Circle',
#               'Plumcreek Circle',
#               'Poe Circle',
#               'Pond View Circle',
#               'Post Oak Circle',
#               'Poteau Circle',
#               'Powell Circle',
#               'Prairie Dove Circle',
#               'Prestonwood Circle',
#               'Pringle Circle',
#               'Quail Cover Circle',
#               'Quail Hill Circle',
#               'Quail Rock Circle',
#               'Quailfield Circle',
#               'Quartz Circle',
#               'Quicksilver Circle',
#               'Rabbit Run Circle',
#               'Radam Circle',
#               'Rainbow Ridge Circle',
#               'Raleigh Circle',
#               'Rampart Circle',
#               'Randy Circle',
#               'Range Oak Circle',
#               'Red Oak Circle',
#               'Reeves Circle',
#               'Riata Vista Circle',
#               'Ridgeview Circle',
#               'Rimrock Circle',
#               'Rising Hills Circle',
#               'Rita Blanca Circle',
#               'River Crossing Circle',
#               'Robinwood Circle',
#               'Rock Terrace Circle',
#               'Rockcrest Circle',
#               'Rockdale Circle',
#               'Rockingham Circle',
#               'Rockpark Circle',
#               'Rockpoint Circle',
#               'Rockwood Circle',
#               'Rose Hill Circle',
#               'Round Mountain Circle',
#               'Roundtop Circle',
#               'Running Rope Circle',
#               'Rush Pea Circle',
#               'Rustling Circle',
#               'Saddle Circle',
#               'Sage Hen Circle',
#               'Sage Hollow Circle',
#               'Sagebrush Circle',
#               "Saint Edward's Circle",
#               "Saint John's Circle",
#               'Salem Meadow Circle',
#               'Salt Block Circle',
#               'Sam Houston Circle',
#               'Sambuca Circle',
#               'Sandhurst Circle',
#               'Sandringham Circle',
#               'Sandshof Circle',
#               'Sandy Meadow Circle',
#               'Santa Cruz Circle',
#               'Santa Elena Circle',
#               'Sawatch Circle',
#               'Scarlet Circle',
#               'Scenic Circle',
#               'Scenic Oaks Circle',
#               'Sea Ash Circle',
#               'Seneca Circle',
#               'Shawnee Circle',
#               'Shumard Circle',
#               'Silone Circle',
#               'Silver Circle',
#               'Silver Dale Circle',
#               'Silver Dollar Circle',
#               'Silver Hill Circle',
#               'Silverado Circle',
#               'Silverarrow Circle',
#               'Silvercrest Circle',
#               'Silverhill Circle',
#               'Silverleaf Circle',
#               'Silverplume Circle',
#               'Single Shot Circle',
#               'Skyway Circle',
#               'Socorro Circle',
#               'Soft Wind Circle',
#               'South Crest Circle',
#               'South Ridge Circle',
#               'Southgate Circle',
#               'Southill Circle',
#               'Spancreek Circle',
#               'Sparkling Creek Circle',
#               'Spiceland Circle',
#               'Split Oak Circle',
#               'Spotted Fawn Circle',
#               'Spotted Owl Circle',
#               'Spring Circle',
#               'Springmail Circle',
#               'Spruceleaf Circle',
#               'Squirrel Oak Circle',
#               'Stableford Circle',
#               'Stage Stop Circle',
#               'Star Grass Circle',
#               'Steamline Circle',
#               'Stone Gate Circle',
#               'Stone Ledge Circle',
#               'Stone Ridge Circle',
#               'Stonecliff Circle',
#               'Stoneham Circle',
#               'Stonehaven Circle',
#               'Stoutwood Circle',
#               'Stow Circle',
#               'Strader Circle',
#               'Stroup Circle',
#               'Stuart Circle',
#               'Stubble Quail Circle',
#               'Summer Circle',
#               'Summer Wind Circle',
#               'Sunnylawn Circle',
#               'Sunrise Circle',
#               'Sunset Circle',
#               'Sunset Heights Circle',
#               'Sunset River Circle',
#               'Sweeney Circle',
#               'Tahoe Parke Circle',
#               'Taline Circle',
#               'Talon Circle',
#               'Talyne Chaise Circle',
#               'Tamarisk Circle',
#               'Tanager Circle',
#               'Tangleridge Circle',
#               'Tawny Circle',
#               'Teaberry Circle',
#               'Teck Circle',
#               'Tejon Circle',
#               'Ten Oaks Circle',
#               'Tern Circle',
#               'Terra Oak Circle',
#               'Terraza Circle',
#               'Thames Circle',
#               'The Circle',
#               'Thousand Oaks Circle',
#               'Three Oaks Circle',
#               'Thurgood Circle',
#               'Tiber Circle',
#               'Timber Circle',
#               'Timber Creek Circle',
#               'Timber Wolf Circle',
#               'Timberwood Circle',
#               'Timothy Circle',
#               'Tolstoy Circle',
#               'Tom Kite Circle',
#               'Tophill Circle',
#               'Towana Circle',
#               'Towbridge Circle',
#               'Town Lake Circle',
#               'Townesouth Circle',
#               'Trail Crest Circle',
#               'Trailridge Circle',
#               'Transit Circle',
#               'Travis Circle',
#               'Travis Country Circle',
#               'Treaty Oak Circle',
#               'Trone Circle',
#               'Tumbling Circle',
#               'Tuscola Circle',
#               'Twin Lake Circle',
#               'Twin Ledge Circle',
#               'Twin Valley Circle',
#               'Union Circle',
#               'Universe Circle',
#               'Utah Circle',
#               'Valburn Circle',
#               'Valencia Circle',
#               'Valiant Circle',
#               'Valley High Circle',
#               'Valley Hill Circle',
#               'Valleyridge Circle',
#               'Vance Circle',
#               'Vanderbilt Circle',
#               'Verde Bank Circle',
#               'Versante Circle',
#               'Vigen Circle',
#               'Villa Oaks Circle',
#               'Villacliff Circle',
#               'Village Circle',
#               'Village Creek Circle',
#               'Village Trail Circle',
#               'Vinca Circle',
#               'Vista View Circle',
#               'Walden Circle',
#               'Walton Heath Circle',
#               'Washoe Circle',
#               'Waterton Parke Circle',
#               'Waxwing Circle',
#               'Welland Circle',
#               'West Beach Circle',
#               'Westbluff Circle',
#               'Westgate Circle',
#               'Westledge Circle',
#               'Westslope Circle',
#               'Westwood Circle',
#               'Wheel Rim Circle',
#               'Wheeler Branch Circle',
#               'Whispering Creek Circle',
#               'Whispering Hollow Circle',
#               'White Hills Circle',
#               'White Magnolia Circle',
#               'Wickford Circle',
#               'Wigwam Circle',
#               'Wild Oak Circle',
#               'Wildridge Circle',
#               'Wildwood Circle',
#               'Williamsburg Circle',
#               'Willowbridge Circle',
#               'Willowood Circle',
#               'Willowwick Circle',
#               'Wilton Circle',
#               'Winding Oak Circle',
#               'Windmill Circle',
#               'Windshill Circle',
#               'Windy Trail Circle',
#               'Winners Ribbon Circle',
#               'Wisteria Circle',
#               'Wood Ibis Circle',
#               'Woodbrook Circle',
#               'Woodlake Circle',
#               'Woodmoor Circle',
#               'Yaupon Springs Circle',
#               'York Bridge Circle',
#               'Zopilote Circle'},
#              'Clark': {'Lake Clark'},
#              'Claro': {'Arroyo Claro'},
#              'Claw': {'Bear Claw'},
#              'Clearwater': {'Clearwater'},
#              'Cliff': {'Eagle Cliff', 'Gila Cliff'},
#              'Cobblestone': {'Cobblestone'},
#              'Colorado': {'Sierra Colorado'},
#              'Comanche': {'Comanche'},
#              'Comet': {'Comet'},
#              'Corners': {'Chimney Corners'},
#              'Corral': {'O K Corral', 'Shepherds Corral'},
#              'Corta': {'Vista Corta'},
#              'Costa': {'Camino La Costa', 'La Costa'},
#              'Creek': {'Boulder Creek',
#               'Canyon Creek',
#               'Cross Creek',
#               'Deep Creek',
#               'Rain Lily Creek',
#               'Rock Creek'},
#              'Crescent': {'Margranita Crescent', 'Scott Crescent'},
#              'Crest': {'Meadow Crest'},
#              'Crestmont': {'Crestmont'},
#              'Criswell': {'Criswell'},
#              'Crossing': {'Bratton Ridge Crossing',
#               'Campina Crossing',
#               'Cherry Hollow Crossing',
#               'Cliff Crossing',
#               'Cloud Mountain Crossing',
#               'Coaches Crossing',
#               'Colorado Crossing',
#               'Dover Ferry Crossing',
#               'Dry Brook Crossing',
#               'Esperanza Crossing',
#               'Fritz Falls Crossing',
#               'Hammetts Crossing',
#               'Hidden Lake Crossing',
#               'Hyson Crossing',
#               'Kenter Crossing',
#               'Kohlers Crossing',
#               'Kyle Crossing',
#               'Lady Lauras Crossing',
#               'Little Deer Crossing',
#               'Mackinaw Crossing',
#               'Mandarin Crossing',
#               'Nuckols Crossing',
#               'Roller Crossing',
#               'Steeds Crossing',
#               'Surveyors Crossing',
#               'Walnut Park Crossing',
#               'West Cave Crossing'},
#              'Ct': {'Claro Vista Ct',
#               'Costello Ct',
#               'Ely Ct',
#               'Krupa Ct',
#               'Sterling Heights Ct',
#               'Stirling Castle Ct',
#               'Sweetgum Ct'},
#              'Cutoff': {'Ferguson Cutoff', 'West 35th Street Cutoff'},
#              'Cv': {'Arbole Cv',
#               'Blue Sky Cv',
#               'Clear Pond Cv',
#               'Copper Point Cv',
#               'Enchanted Cv',
#               'Hal Sutton Cv',
#               'Hilltop Canyon Cv',
#               'La Estrella Cv',
#               'La Roca Cv',
#               'Lapin Cv',
#               'Mallard Cv',
#               'Mock Cherry Cv',
#               'Morning Primrose Cv',
#               'Old Corral Cv',
#               'Peat Moors Cv',
#               'Quiet Meadows Cv',
#               'Red River Cv',
#               'Ripley Castle Cv',
#               'Rooney Cv',
#               'Salem Oak Cv',
#               'Secluded Willow Cv',
#               'Texas Ash Cv',
#               'Tom Kite Cv'},
#              'D': {'Avenue D'},
#              'D1': {'W Hwy 71, STE D1'},
#              'D5000': {'Speedway Stop D5000'},
#              'Dale': {'Michael Dale'},
#              'Dalmahoy': {'Dalmahoy'},
#              'Dance': {'Harvest Dance'},
#              'Dancer': {'Wolf Dancer'},
#              'Divide': {'Vail Divide'},
#              'Dog': {'Laughing Dog'},
#              'Dorado': {'El Dorado', 'North el Dorado', 'South el Dorado'},
#              'Dr': {'Bettis Trophy Dr',
#               'Bill Baker Dr',
#               'Canyon Springs Dr',
#               'Carranzo Dr',
#               'Corral de Tierra Dr',
#               'Creekline Dr',
#               'Dave Silk Dr',
#               'Executive Center Dr',
#               'Forest Creek Dr',
#               'Horse Wagon Dr',
#               'Ivy Dr',
#               'Jack Nicklaus Dr',
#               'Jimmy Clay Dr',
#               'Justin Leonard Dr',
#               'Kyle Center Dr',
#               'Lighthouse Landing Dr',
#               'Octavia Dr',
#               'Rain Song Dr',
#               'Round Rock West Dr',
#               'Via Dono Dr',
#               'Via Ricco Dr',
#               'W Lake Dr',
#               'W William Cannon Dr',
#               'Walter Seaholm Dr',
#               'Winged Elm Dr',
#               'Woodall Dr',
#               'Yaupon Range Dr'},
#              'Dr.': {'11928 Stonehollow Dr.',
#               'Cannon Dr.',
#               'Sportsplex Dr.',
#               'Stonebridge Dr.'},
#              'Dragon': {'Dragon'},
#              'Drive/Rd': {'Spreading Oaks Drive/Rd'},
#              'Dublin': {'Royal Dublin'},
#              'Dunes': {'Indiana Dunes'},
#              'East': {'Alpine Road East',
#               'Applegate Drive East',
#               'Basin Ledge East',
#               'Black Locust Drive East',
#               'Brenham Street East',
#               'Caddo Street East',
#               'Canyon Circle East',
#               'Colorado Drive East',
#               'Covington Drive East',
#               'Cypress Point East',
#               'Hwy 290 East',
#               'Ledgeway East',
#               'Main Street East',
#               'Mockingbird Lane East',
#               'Rapid Springs Cove East',
#               'Rutland Village East',
#               'US 290 East',
#               'Walnut Street East'},
#              'Edenderry': {'Edenderry'},
#              'End': {'The Living End'},
#              'Estates': {'Hidden Estates'},
#              'Explorer': {'Explorer'},
#              'Expressway': {'North Mo-Pac Expressway',
#               'North MoPac Expressway',
#               'North Mopac Expressway',
#               'South MoPac Expressway'},
#              'F': {'Avenue F'},
#              'F-4': {'S. Capitol of Texas Hwy, #F-4'},
#              'FM1431': {'FM1431'},
#              'Fairway': {'Fuzz Fairway'},
#              'Falcon': {'Falcon'},
#              'Fandango': {'Fandango'},
#              'Fields': {'Elysian Fields'},
#              'Firebird': {'Firebird'},
#              'Flat': {'Tortilla Flat'},
#              'Fleur': {'Rue Le Fleur'},
#              'Flower': {'Desert Flower'},
#              'Folkway': {'Kerrville Folkway'},
#              'Ford': {'Meadow Ford'},
#              'Forest': {'Sherwood Forest'},
#              'Fork': {'Roaring Fork'},
#              'Fort': {'Quick Fort'},
#              'Fortuna': {'Via Fortuna'},
#              'Frijolita': {'Frijolita'},
#              'Frontage': {'I-35 Frontage'},
#              'G': {'Avenue G'},
#              'G-145': {'E. Whitestone Blvd #G-145'},
#              'Galaxy': {'Galaxy'},
#              'Gallop': {'Victory Gallop'},
#              'Gap': {'Buffalo Gap', 'Gnu Gap'},
#              'Garden': {'Bayswater Garden'},
#              'Germaine': {'Rue de St Germaine'},
#              'Glade': {'Sylvan Glade'},
#              'Glen': {'Cedar Glen',
#               'Hunters Glen',
#               'Jacob Glen',
#               'Oak Glen',
#               'Welcome Glen',
#               'Willheather Glen'},
#              'Gonzales': {'Gonzales'},
#              'Grande': {'Laguna Grande', 'Mesa Grande', 'Rio Grande'},
#              'Green': {'Palace Green', 'Saint Georges Green'},
#              'Greens': {'Inland Greens'},
#              'Greenway': {'Greenway'},
#              'Grotto': {'Liberty Grotto'},
#              'Grove': {'China Grove'},
#              'Gulch': {'Bachelor Gulch', 'Grubstake Gulch', 'Thunder Gulch'},
#              'Gunsmoke': {'Gunsmoke'},
#              'H': {'Avenue H'},
#              'Hall': {'Panther Hall'},
#              'Hambletonian': {'Hambletonian'},
#              'Harborway': {'Palm Harborway'},
#              'Hat': {'Medicine Hat'},
#              'Haven': {'Circle Haven', 'Troll Haven'},
#              'Highlander': {'Highlander'},
#              'Hill': {'Blueberry Hill',
#               'Chateau Hill',
#               'Chestnut Hill',
#               'Cog Hill',
#               'Coronado Spyglass Hill',
#               'Cromwell Hill',
#               'Dominion Hill',
#               'Indian Hill',
#               'Knob Hill',
#               'Noack Hill',
#               'Observatory Hill',
#               'Rolling Hill',
#               'Stoney Hill',
#               'Wintergreen Hill'},
#              'Hilldale': {'Hilldale'},
#              'Hollow': {'Apple Springs Hollow',
#               'Autumnleaf Hollow',
#               'Balsam Hollow',
#               'Beechwood Hollow',
#               'Big Oak Hollow',
#               'Bittern Hollow',
#               'Black Mesa Hollow',
#               'Breeze Hollow',
#               'Brushy Hollow',
#               'Cave Hollow',
#               'Cedar Hollow',
#               'Chestnut Hollow',
#               'Coachwhip Hollow',
#               'Creek Hollow',
#               'Dewberry Hollow',
#               'Dogwood Hollow',
#               'Fern Hollow',
#               'Firewheel Hollow',
#               'Gardenridge Hollow',
#               'Gold Flower Hollow',
#               'Grass Hollow',
#               'Haley Hollow',
#               'Hickory Hollow',
#               'Hidden Hollow',
#               'Hideaway Hollow',
#               'Honeycomb Hollow',
#               'Hood Hollow',
#               'Horseback Hollow',
#               'Hudson Hollow',
#               'Hurst Hollow',
#               'Jessamine Hollow',
#               'Knapp Hollow',
#               'Lakewood Hollow',
#               'Lantana Hollow',
#               'Logans Hollow',
#               'Lost Oasis Hollow',
#               'Maury Hollow',
#               'Mill Hollow',
#               'Mount Bonnell Hollow',
#               'Paintbrush Hollow',
#               'Pecan Hollow',
#               'Pepper Mill Hollow',
#               'Quail Hollow',
#               'Red Mesa Hollow',
#               'Salt Mill Hollow',
#               'Sandalwood Hollow',
#               'Secluded Hollow',
#               'Squirrel Hollow',
#               'Sunset Hollow',
#               'Turkey Hollow',
#               'Twin Creek Hollow',
#               'Wild Cat Hollow',
#               'Winecup Hollow'},
#              'Horn': {'Big Horn'},
#              'Horse': {'High Horse'},
#              'Hwy': {'S Capital of Texas Hwy'},
#              'I': {'Avenue I'},
#              'I35': {'I35'},
#              'IH-35': {'N IH-35', 'South IH-35'},
#              'IH35': {'1500 S. IH35'},
#              'IH35,': {'N. IH35,'},
#              'Iron': {'Branding Iron'},
#              'Island': {'Channel Island'},
#              'J': {'Business Interstate Highway 35 J'},
#              'Jacinto': {'San Jacinto'},
#              'James': {'Court of Saint James'},
#              'Jr': {'Robert Martinez Jr'},
#              'Juniper': {'Brown Juniper'},
#              'K': {'Avenue K'},
#              'Kiss': {'Sky Kiss'},
#              'Knoll': {'Chamois Knoll', 'Country Knoll'},
#              'L2': {'Research Blvd #L2'},
#              'Lair': {'Lions Lair'},
#              'Lajitas': {'Lajitas'},
#              'Lake': {'Buffalo Lake', 'Crater Lake', 'Plaza on the Lake'},
#              'Lancaster': {'House of Lancaster'},
#              'Landing': {'Longhorn Landing', 'Richfield Landing'},
#              'Lanes': {'Green Lanes'},
#              'Ledge': {'Basin Ledge', 'Warbler Ledge'},
#              'Leon': {'Sierra Leon'},
#              'Liberty': {'W. Liberty'},
#              'Lido': {'Lido'},
#              'Limon': {'Calle Limon'},
#              'Linda': {'Loma Linda'},
#              'Ln': {'Buzz Schneider Ln',
#               'Calhoun Ln',
#               'Chick Pea Ln',
#               'Hidden Hills Ln',
#               'Laguna Seca Ln',
#               'Lantana Ln',
#               'Pasadera Ln',
#               'Pfennig Ln',
#               'Rockwood Ln',
#               'Rocky Top Ln',
#               'Sky Ridge Ln',
#               'W Anderson Ln',
#               'W Braker Ln',
#               'West Parmer Ln'},
#              'Lodge': {'Wild Basin Lodge'},
#              'Lonesome': {'High Lonesome'},
#              'Loop': {'Amberwood Loop',
#               'Anarosa Loop',
#               'Austral Loop',
#               'Barrow Glen Loop',
#               'Bastogne Loop',
#               'Bayton Loop',
#               'Briarcreek Loop',
#               'Bronco Bend Loop',
#               'Calhoun Canyon Loop',
#               'Cameron Loop',
#               'Candace Loop',
#               'Cardinal Loop',
#               'Celery Loop',
#               'Cherry Loop',
#               'Christoff Loop',
#               'Circletree Loop',
#               'Colonel Winn Loop',
#               'Corran Ferry Loop',
#               'Crane Creek Loop',
#               'Croydon Loop',
#               'Desert Willow Loop',
#               'Donna Jane Loop',
#               'Double Spur Loop',
#               'Dry Brook Loop',
#               'E. North Loop',
#               'East Hove Loop',
#               'Fantail Loop',
#               'Foothill Farms Loop',
#               'Franklins Tale Loop',
#               'Gerald Allen Loop',
#               'Grand Oaks Loop',
#               'Hansa Loop',
#               'Highland Lake Loop',
#               'Horseshoe Loop',
#               'Hudson Loop',
#               'Independence Loop',
#               'Indigo Broom Loop',
#               'Janet Loop',
#               'Kirtomy Loop',
#               'Knoll Crest Loop',
#               'La Plata Loop',
#               'Lake Loop',
#               'Lakehurst Loop',
#               'Lanark Loop',
#               'Lanna Bluff Loop',
#               'Layne Loop',
#               'Leanna Oaks Loop',
#               'Levander Loop',
#               'Lightwood Loop',
#               'Lily Lake Loop',
#               'Lindeman Loop',
#               'Linden Loop',
#               'Lipton Loop',
#               'Little Loop',
#               'Loch Linnhe Loop',
#               'Lockleven Loop',
#               'Long Hollow Loop',
#               'Magna Carta Loop',
#               'Maravillas Loop',
#               'Marble Creek Loop',
#               'Masi Loop',
#               'Mirasol Loop',
#               'Old Post Loop',
#               'Olympia Fields Loop',
#               'Osprey Ridge Loop',
#               'Outlook Ridge Loop',
#               'Panther Loop',
#               'Ponciana Loop',
#               'Post Oak Bend Loop',
#               'Pusch Ridge Loop',
#               'Rector Loop',
#               'Rennalee Loop',
#               'Ridgeview Loop',
#               'Rising Smoke Loop',
# ...
#              'Skyline': {'Beverly Skyline', 'Hill Country Skyline'},
#              'Skyview': {'Deer Creek Skyview'},
#              'Skyway': {'Barton Skyway', 'Longhorn Skyway'},
#              'Slew': {'Seattle Slew'},
#              'South': {'Amberwood South',
#               'Farm-to-Market Road 973 South',
#               'Ranch Road 620 South',
#               'Sioux Trail South',
#               'Venture Boulevard South',
#               'Whippoorwill Street South'},
#              'Speedway': {'Speedway'},
#              'Spicewood': {'State Highway 71 W Spicewood'},
#              'Spring': {'Stillhouse Spring'},
#              'Springwater': {'Springwater'},
#              'Spur': {'Lohmans Spur', 'Rutledge Spur', 'Silver Spur'},
#              'St': {'Duval St',
#               'E 43rd St',
#               'E 51st St',
#               'E Oltorf St',
#               'N Main St',
#               'Pecan St',
#               'Red River St',
#               'Rio Grande St',
#               'S 1st St',
#               'W 10th St',
#               'W 6th St',
#               'W Annie St',
#               'West Lynn St'},
#              'St.': {'E 38th 1/2 St.', 'E. 43rd St.', 'Pecan St.'},
#              'Stakes': {'Messenger Stakes'},
#              'Stonebridge': {'Stonebridge'},
#              'Stonehedge': {'Old Stonehedge'},
#              'Strip': {'Sunset Strip'},
#              'Summit': {'Indian Summit'},
#              'Sundown': {'Bold Sundown'},
#              'Sunfish': {'Sunfish'},
#              'Sunterro': {'Sunterro'},
#              'Sutton': {'Sutton'},
#              'Tahoe': {'Sierra Tahoe'},
#              'Talamore': {'Talamore'},
#              'Tarlton': {'Old Walsh Tarlton'},
#              'Tealwood': {'Tealwood'},
#              'Terrace': {'Airline Terrace',
#               'Algerita Terrace',
#               'Arch Terrace',
#               'Arren Terrace',
#               'Bayridge Terrace',
#               'Begonia Terrace',
#               'Bonham Terrace',
#               'Box Canyon Terrace',
#               'Breeze Terrace',
#               'Buckingham Gate Terrace',
#               'Callisto Terrace',
#               'Carnation Terrace',
#               'Carrizo Terrace',
#               'Century Oaks Terrace',
#               'Cherry Laurel Terrace',
#               'Club Terrace',
#               'Cradlerock Terrace',
#               'Crystal Terrace',
#               'Dark Star Terrace',
#               'Dunlop Terrace',
#               'Eagle Fledge Terrace',
#               'Eastridge Terrace',
#               'Edgecliff Terrace',
#               'Fargo Terrace',
#               'Foothill Terrace',
#               'Gentle Breeze Terrace',
#               'Green Emerald Terrace',
#               'Greenridge Terrace',
#               'Highgrove Terrace',
#               'Highland Hills Terrace',
#               'Highland Terrace',
#               'Honey Dew Terrace',
#               'Industrial Terrace',
#               'Kisoba Terrace',
#               'Lakewood Hills Terrace',
#               'Larch Terrace',
#               'Ledgestone Terrace',
#               'Lily Terrace',
#               'Lookout Bluff Terrace',
#               'Ludlow Terrace',
#               'Marigold Terrace',
#               'Mifflin Kenedy Terrace',
#               'Niagara Falls Terrace',
#               'Norseman Terrace',
#               'Pinewood Terrace',
#               'Preserve Vista Terrace',
#               'Reagan Terrace',
#               'Ridgetop Terrace',
#               'River Terrace',
#               'Rockbridge Terrace',
#               'Rosedale Terrace',
#               'Shady Oak Terrace',
#               'Ski Shores Terrace',
#               'Spanish Oak Terrace',
#               'Star Light Terrace',
#               'Sterling Panorama Terrace',
#               'Stoneridge Terrace',
#               'Swelfling Terrace',
#               'Tallison Terrace',
#               'Tay Terrace',
#               'Teasdale Terrace',
#               'Theckla Terrace',
#               'Timarou Terrace',
#               'Trailview Mesa Terrace',
#               'Vikki Terrace',
#               'Westwood Terrace',
#               'White Rim Terrace',
#               'Windy Terrace',
#               'Yellowpine Terrace'},
#              'Terrance': {'Holly Crest Terrance'},
#              'Thunder': {'Buffalo Thunder'},
#              'Thunderbird': {'Thunderbird'},
#              'Tiempo': {'Pasa Tiempo'},
#              'Toro': {'Paseo del Toro'},
#              'Tr': {'Posse Tr', 'Sunflower Tr', 'Sycamore Tr'},
#              'Trace': {'Dayflower Trace',
#               'Flintrock Trace',
#               'Hampton Bliss Trace',
#               'Hunters Trace',
#               'Juniper Trace',
#               'Mill Ridge Trace',
#               'Outpost Trace',
#               'Shadowglen Trace',
#               'Shadowlawn Trace',
#               'Single Trace',
#               'Tall Sky Trace',
#               'Tercel Trace'},
#              'Track': {'Deer Track'},
#              'Triangle': {'Piland Triangle'},
#              'Trl': {'Harrier Flight Trl',
#               'Poppy Hills Trl',
#               'Scenic Overlook Trl'},
#              'Tropez': {'Rue de St Tropez'},
#              'Tundra': {'Buffalo Tundra'},
#              'Turn': {'Clubhouse Turn'},
#              'Turnback': {'Turnback'},
#              'Vale': {'East Meadow Vale'},
#              'Valley': {'Green Valley',
#               'Lost Valley',
#               'Smokey Valley',
#               'Spurlock Valley'},
#              'Van': {'Clara Van'},
#              'Vanguard': {'Vanguard'},
#              'Verde': {'Casa Verde', 'Cuesta Verde', 'Encino Verde'},
#              'Verdes': {'Palos Verdes'},
#              'Viejo': {'Camino Viejo'},
#              'Viento': {'Lago Viento'},
#              'View': {'Canyon View',
#               'Hurst View',
#               'Key View',
#               'La Fauna View',
#               'Morning View',
#               'Panoramic View',
#               'Pleasant Panorama View',
#               'Rotunda View',
#               'Sea Eagle View',
#               'Summit View',
#               'Sunset View',
#               'Valley View',
#               'Woody Ridge View'},
#              'Vista': {'Agua Vista',
#               'Buena Vista',
#               'Mira Vista',
#               'Puerta Vista',
#               'Twilight Vista',
#               'Verde Vista'},
#              'Voyageurs': {'Voyageurs'},
#              'W': {'Highway 71 W', 'Hwy 290 W'},
#              'Walk': {'Fairfax Walk',
#               'Gillians Walk',
#               'Julies Walk',
#               'Liberty Walk',
#               "Melanie's Walk",
#               'Midland Walk',
#               'Regents Walk',
#               'Village Walk',
#               'Whitemarsh Valley Walk',
#               'Winding Walk'},
#              'Way': {'Aberdeen Way',
#               'Adrian Way',
#               'Aftonshire Way',
#               'Airole Way',
#               'Albania Way',
#               'Almarion Way',
#               'Altona Way',
#               'Alverstone Way',
#               'Amanda Ellis Way',
#               'Amblewood Way',
#               'Andres Way',
#               'Antigua Way',
#               'Antonio Way',
#               'Appennini Way',
#               'Arbor Glen Way',
#               'Arnulfo Alonso Way',
#               'Ascot Way',
#               'Ashley Way',
#               'Autumn Sage Way',
#               'Avispa Way',
#               'Azzuro Way',
#               'Balcones Way',
#               'Bark Way',
#               'Barnsdale Way',
#               'Barrington Way',
#               'Bella Toscana Way',
#               'Ben Crenshaw Way',
#               'Benevento Way',
#               'Benson Way',
#               'Berryhill Way',
#               'Berryline Way',
#               'Best Way',
#               'Bethel Way',
#               'Bidermann Way',
#               'Blue Clearing Way',
#               'Blue Spring Way',
#               'Bluesky Way',
#               'Bold Ruler Way',
#               'Boyds Way',
#               'Brandon Way',
#               'Brecourt Manor Way',
#               'Breeze Way',
#               'Brindisi Way',
#               'Brista Way',
#               'Brougham Way',
#               'Broughton Way',
#               'Busleigh Castle Way',
#               'Cactus Wren Way',
#               'Calistoga Way',
#               'Canyon Vista Way',
#               'Carillon Way',
#               'Cassiopeia Way',
#               'Castellano Way',
#               'Castlekeep Way',
#               'Cerca Viejo Way',
#               'Chamois Way',
#               'Champion Grandview Way',
#               'Chateau Village Way',
#               'Cilantro Way',
#               'Clancy Way',
#               'Collaborative Way',
#               'Collazo Way',
#               'Comburg Castle Way',
#               'Commonwealth Way',
#               'Companeros Way',
#               'Cool Spring Way',
#               'Coronation Way',
#               'Cosmos Way',
#               'Craig Patrick Way',
#               'Crossvine Way',
#               'Crystal Way',
#               'Cummins Way',
#               'Delgado Way',
#               'Dell Way',
#               'Desert Willow Way',
#               'Destination Way',
#               'Dimmit Way',
#               'Dunblane Way',
#               'Earp Way',
#               'Edgewood Way',
#               'Elfen Way',
#               'Elm View Way',
#               'Elvas Way',
#               'Ernest Robles Way',
#               'Falconers Way',
#               'Fallsprings Way',
#               'Fishermans Way',
#               'Flatters Way',
#               'Forest Way',
#               'Gate Way',
#               'Glen Springs Way',
#               'Golden Eagle Way',
#               'Grand Mission Way',
#               'Harness Race Way',
#               'Havant Way',
#               'Hedgebrook Way',
#               'Hereford Way',
#               'Heritage Way',
#               'Hightrail Way',
#               'Howellwood Way',
#               'Huntleigh Way',
#               'IKEA Way',
#               'Island Way',
#               'James Ryan Way',
#               'Jamie Glen Way',
#               'Jarrett Way',
#               'Johnson Way',
#               'Jonwood Way',
#               'Judy Scholl Way',
#               'Juniper Berry Way',
#               'Kind Way',
#               'Lago Vista Way',
#               'Lake Edge Way',
#               'Lance Way',
#               'Lancelot Way',
#               'Lantana Way',
#               'Little Emily Way',
#               'Lombardi Way',
#               'Lonesome Lilly Way',
#               'Luna Montana South Way',
#               'Maddy Way',
#               'Mangan Way',
#               'Mankins Way',
#               'Margalene Way',
#               'Marigold Way',
#               'Marina View Way',
#               'Maritime Alps Way',
#               'Marly Way',
#               'Marshitahs Way',
#               'Matoca Way',
#               'Mayan Way',
#               'Mc Donald Way',
#               'Meacham Way',
#               'Meandering Way',
#               'Medina River Way',
#               'Melwas Way',
#               'Milford Way',
#               'Mimebark Way',
#               'Mira Vista Way',
#               "Miss Allison's Way",
#               'Montclair Way',
#               'Morelia Way',
#               'Mountain Laurel Way',
#               'Murrelet Way',
#               'Naruna Way',
#               'Natural Spring Way',
#               'Natures Way',
#               'Nesting Way',
#               'Night Sky Way',
#               'Ocelot Way',
#               'Old Wick Castle Way',
#               'Orange Blossom Way',
#               'Owling Way',
#               'Oxen Way',
#               'Palm Way',
#               'Palo Alto Way',
#               'Paloma Blanca Way',
#               'Pappys Way',
#               'Pauma Valley Way',
#               'Pecangate Way',
#               'Prince Phillip Way',
#               'Pure Brook Way',
#               'Queens Way',
#               'Quitman Mountain Way',
#               'Rae Way',
#               'Renfert Way',
#               'Rias Way',
#               'Rivers Edge Way',
#               'Rochester Castle Way',
#               'Rock Way',
#               'Rose Mallow Way',
#               'Running Water Way',
#               "Saint Andrew's Way",
#               'Salem House Way',
#               'Sally Lunn Way',
#               'Sandra Muraida Way',
#               'Sangremon Way',
#               'Sarong Way',
#               'Segovia Way',
#               'Shady Meadow Way',
#               'Shakespearean Way',
#               'Shallot Way',
#               'Sika Way',
#               'Silent Water Way',
#               'Sommerland Way',
#               'South Webberwood Way',
#               'Southampton Way',
#               'Spiers Way',
#               'Split Stone Way',
#               "Stacia's Way",
#               'Stagecoach Way',
#               'Stamford Way',
#               'Star Flower Way',
#               'Star Gazer Way',
#               'Steven Creek Way',
#               'Stonepath Way',
#               'Stonethrow Way',
#               'Sunnysky Way',
#               'Tallow Field Way',
#               'Tamango Way',
#               'Tartar Way',
#               'Technology Way',
#               'Terrace Meadow Way',
#               'Thannas Way',
#               'Thistle Hill Way',
#               'Tiger Lily Way',
#               'Tockington Way',
#               'Tournament Way',
#               'Travesia Way',
#               'Tree Sap Way',
#               'Treys Way',
#               'Trickling Springs Way',
#               'Truth Way',
#               'Tulloch Way',
#               'Tuscany Way',
#               "Velia's Way",
#               'Verdant Way',
#               'Villa Montana Way',
#               'Viridian Way',
#               'Voelker Reinhardt Way',
#               'Wadsworth Way',
#               'Wafer Ash Way',
#               'Wagon Way',
#               'Wales Way',
#               'Wampton Way',
#               'Wandering Way',
#               'Warbler Way',
#               'Warfield Way',
#               'Warwick Way',
#               'Waterford Run Way',
#               'Watermelon Way',
#               'Watson Way',
#               'Webbwood Way',
#               'Welsh Way',
#               'Wendts Way',
#               'Wessex Way',
#               'Westgate Way',
#               'Wethersby Way',
#               'Whifflewind Way',
#               'Whispering Wind Way',
#               'White Water Way',
#               'Whitney Way',
#               'Wickett Way',
#               'Wild Petunia Way',
#               'Wild Plum Way',
#               'Wiley Way',
#               'Willers Way',
#               'William Wallace Way',
#               'Williams Ridge Way',
#               'Willow Way',
#               'Windcliff Way',
#               'Windless Way',
#               'Windrift Way',
#               'Winecap Way',
#               'Wingate Way',
#               'Winwick Way',
#               'Withers Way',
#               'Woodcutters Way',
#               'Yarmont Way',
#               "Zachary's Way",
#               'Zagros Way',
#               'Zen Gardens Way',
#               'Zion Way'},
#              'West': {'Alpine Road West',
#               'Carrie Manor Street West',
#               'Crystalbrook West',
#               'Old 2243 West',
#               'Pfluger Street West',
#               'Rutland Village West',
#               'Saint Elmo Road West',
#               'View West',
#               'Wagon Road West'},
#              'Wheel': {'Wagon Wheel'},
#              'William': {'Prince William'},
#              'Willo': {'Switch Willo'},
#              'Withers': {'Tall Withers'},
#              'Wood': {'Five Acre Wood'},
#              'Woods': {'Point O Woods', 'Trail of the Woods'},
#              'Wow': {'Pow Wow'},
#              'Wren': {'House Wren'},
#              'Yard': {'Scotland Yard'},
#              'York': {'House of York'},
#              'court': {'Fleming court'},
#              'cove': {'devonshire cove'},
#              'lane': {'brigadoon lane'},
#              'pass': {'Raven Caw pass'},
#              'street': {'East main street',
#               'South 1st street',
#               'White House street',
#               'south church street'},
#              'suite#L131': {'N. Lamar suite#L131'},
#              'texas': {'9901 N Capital Of texas'},
#              'way': {'Physicians way'}})

# %% [markdown]
# From looking at the values, some common things to fix are abbreviated street names. Not only are they abbreviated, but they are also abbreviated differently. An example of a case where everything needs to be consistent is the Interstate Highway 35, which is referred to by any of the following values found in the data:
#
# "IH35"
# "I35"
# "I 35"
# "I H 35"
#
# Another complicated case was the Farm-to-Market and Ranch-to-Market roads. Examples are:
#
# "Farm to Market 620"
# "Farm to Market Road 620"
# "FM 620"
# "FM1431"
#
# Cleaning up N (north), I (interstate), H (Highway), E (east) and other single letter abbreviations was needed but this complicated the streets that have values "Avenue N", "Avenue I", "Avenue H", "Avenue E".
#
# Cleaning up St (street) complicated the streets with St for "Saint" (for example, "Rue de Saint Tropez" which was abbreviated "Rue de St Tropez".
#
# All of these were addressed by creating functions shown below. However, some cases were ignored, such as "Highway Interstate 35" which should be "Interstate Highway 35".
#
# To aid in cleaning, the mapping dictionary below was created. The keys are the items to be fixed, and the values are what the keys should be after fixing.

# %%
mapping_street = { "St": "Street",
            "St.": "Street",
            "st": "Street",
            "street": "Street",
            "Street,": "Street",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "Avene": "Avenue",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Boulevard,": "Boulevard",
            "Blvd,": "Boulevard",
            "Blvd.,": "Boulevard",
            "Dr": "Drive",
            "Dr.": "Drive",
            "Ct": "Court",
            "Ct.": "Court",
            "court": "Court",
            "Cv": "Cove",
            "cove": "Cove",
            "Cc": "Cove",
            "Pl": "Place",
            "Pl.": "Place",
            "lane": "Lane",
            "Ln": "Lane",
            "Rd": "Road", 
            "Rd.": "Road",
            "R": "Road",
            "Trl": "Trail",
            "Tr": "Trail",
            "Pkwy": "Parkway",
            "Hwy": "Highway",
            "HWY": "Highway",
            "Hwy,": "Highway",
            "H": "Highway",
            "I35": "Interstate Highway 35",
            "IH35": "Interstate Highway 35",
            "IH35,": "Interstate Highway 35",
            "IH-35": "Interstate Highway 35",
            "I-35": "Interstate Highway 35",
            "IH": "Interstate Highway",
            "I": "Interstate",
            "35,": "35",
            "main": "Main",
            "N": "North",
            "N.": "North",
            "Ovlk": "Overlook",
            "pass": "Pass",
            "Ps": "Pass",
            "W": "West",
            "W.": "West",
            "E": "East",
            "E.": "East",
            "texas": "Texas",
            "TX": "Texas",
            "FM": "Farm-to-Market Road",
            "F.M.": "Farm-to-Market Road",
            "U.S.": "United States",
            "US": "United States",
            "RM": "Ranch-to-Market Road",
            "RM1431": "Ranch-to-Market Road 1431",
            "RR": "Ranch Road",
            "S": "South",
            "S.": "South",
            "south": "South",
            "Bldg": "Building",
            "Bldg.": "Building",
            "Bld": "Building",
            "Ste": "Suite",
            "Ste,": "Suite",
            "STE": "Suite",
            "Ste.": "Suite",
            "suite": "Suite",
            "C": "Country",
            "church": "Church",
            "brigadoon": "Brigadoon",
            "Drive/Rd": "Drive/Road",
            "Mo-Pac": "MoPac", 
            "Avenue,Ste": "Avenue Suite",
            "suite#L131": "Suite L131"}

# %% [markdown]
# ##### Appends "Highway" if is it needed:

# %%
def append_highway(name):
    newparts = []
    parts = name.split()
    for item in parts:
        if (item == "Interstate" or item == "States") and "Highway" not in parts:
            newparts.append(item)
            newparts.append("Highway")
        else:
            newparts.append(item)
    name = ' '.join(newparts)
    return name

# %% [markdown]
# ##### Updates the FM and RM roads:

# %%
def update_farm_ranch_to_market(name):
    parts = name.split()
    if "Farm-to-Market" in parts or "Ranch-to-Market" in parts:
        if "Road" in parts:
            return name
        else:
            try:
                parts.insert(parts.index("Farm-to-Market")+1, "Road")
                name = " ".join(parts)
            except ValueError:
                parts.insert(parts.index("Ranch-to-Market")+1, "Road")  
                name = " ".join(parts)
    elif "Farm" in parts and "to" in parts and "Market" in parts:
        newname = []
        for i in range(parts.index("Farm")):
            newname.append(parts[parts.index(i)])
        newname.append("Farm-to-Market")
        newname += parts[parts.index("Market")+1:]

        if "Road" in parts:
            name = " ".join(newname)
        else:
            newname.insert(newname.index("Farm-to-Market")+1,"Road")
            name = " ".join(newname)
    
    elif "Ranch" in parts and "to" in parts and "Market" in parts:
        newname = []
        for i in range(parts.index("Ranch")):
            newname.append(parts[parts.index(i)])
        newname.append("Ranch-to-Market")
        newname += parts[parts.index("Market")+1:]

        if "Road" in parts:
            name = " ".join(newname)
        else:
            newname.insert(newname.index("Ranch-to-Market")+1,"Road")
            name = " ".join(newname)
        
    return name

# %% [markdown]
# ##### Updates the name based on mapping dictionary and also fixes other items, such as St., N, C, I , H:

# %%
def update_name(name, mapping):
    parts = name.split()
    newparts = []
    for item in parts:
        if item == "St" and "Rue" in parts:
            newparts.append("Saint")
        elif item == "N" or item == "C" or item == "I" or item == "H": 
            try:
                if newparts[0] == "Avenue":
                    newparts.append(item)
                else:
                    newparts.append(mapping[item])
            except IndexError:
                newparts.append(mapping[item])
        else:
            if item in mapping.keys():
                newparts.append(mapping[item])
            else:
                newparts.append(item)
    name = ' '.join(newparts)
    name = append_highway(name)
    name = update_farm_ranch_to_market(name)
    return name

# %% [markdown]
# elif statements make possible the updating of St for Saint instead of Street, and N, C, I, H to be left alone instead of substituting them for "North", "Country", etc.

# %% [markdown]
# The following code shows if the updates can occur using "update_name" function.

# %%
for st_type, ways in st_types.iteritems():
    for name in ways:
        for each in name.split():
            if each in mapping.keys():
                better_name = update_name(name, mapping)
                print name, "=>", better_name
# Out:
# Royal Birkdale Ovlk => Royal Birkdale Overlook
# N I-35 Suite 298 => North Interstate Highway 35 Suite 298
# N I-35 Suite 298 => North Interstate Highway 35 Suite 298
# W. Highway 290 => West Highway 290
# East Hwy 290 => East Highway 290
# C R 290 => Country Road 290
# C R 290 => Country Road 290
# W Hwy 290 => West Highway 290
# W Hwy 290 => West Highway 290
# U.S. 290 => United States Highway 290
# West US Highway 290 => West United States Highway 290
# E Hwy 290 => East Highway 290
# E Hwy 290 => East Highway 290
# US Highway 290 => United States Highway 290
# W Highway 290 => West Highway 290
# W HWY 290 => West Highway 290
# W HWY 290 => West Highway 290
# Helios Way, Bldg 2, Suite 290 => Helios Way, Building 2, Suite 290
# US 290 => United States Highway 290
# south church street => South Church Street
# south church street => South Church Street
# south church street => South Church Street
# East main street => East Main Street
# East main street => East Main Street
# South 1st street => South 1st Street
# White House street => White House Street
# Raven Caw pass => Raven Caw Pass
# Hwy 290 East => Highway 290 East
# US 290 East => United States Highway 290 East
# W. Anderson Lane, Suite A-15 => West Anderson Lane, Suite A-15
# Woodrow Ave. => Woodrow Avenue
# Avery Ranch Blvd Building A #100 => Avery Ranch Boulevard Building A #100
# 4207 James Casey st #101 => 4207 James Casey Street #101
# S 1st St, Suite 104 => South 1st St, Suite 104
# N. IH35, => North Interstate Highway 35
# N. IH35, => North Interstate Highway 35
# N. IH 35 => North Interstate Highway 35
# N. IH 35 => North Interstate Highway 35
# S Interstate 35 => South Interstate Highway 35
# N Interstate Highway 35 => North Interstate Highway 35
# North IH 35 => North Interstate Highway 35
# South I 35 => South Interstate Highway 35
# I 35 => Interstate Highway 35
# S Interstate Highway 35 => South Interstate Highway 35
# 9600 S IH 35 => 9600 South Interstate Highway 35
# 9600 S IH 35 => 9600 South Interstate Highway 35
# Avenue N => Avenue N
# IH 35 N => Interstate Highway 35 North
# IH 35 N => Interstate Highway 35 North
# Capital of TX Hwy N => Capital of Texas Highway North
# Capital of TX Hwy N => Capital of Texas Highway North
# Capital of TX Hwy N => Capital of Texas Highway North
# Farm to Market 620 N => Farm-to-Market Road 620 North
# Pecan St. => Pecan Street
# E 38th 1/2 St. => East 38th 1/2 Street
# E 38th 1/2 St. => East 38th 1/2 Street
# E. 43rd St. => East 43rd Street
# E. 43rd St. => East 43rd Street
# N IH 35 Bldg. 6 => North Interstate Highway 35 Building 6
# N IH 35 Bldg. 6 => North Interstate Highway 35 Building 6
# N IH 35 Bldg. 6 => North Interstate Highway 35 Building 6
# FM 1626 => Farm-to-Market Road 1626
# F.M. 1626 => Farm-to-Market Road 1626
# South I-35 Service SB => South Interstate Highway 35 Service SB
# West Parmer Ln => West Parmer Lane
# Hidden Hills Ln => Hidden Hills Lane
# Calhoun Ln => Calhoun Lane
# Buzz Schneider Ln => Buzz Schneider Lane
# Laguna Seca Ln => Laguna Seca Lane
# Lantana Ln => Lantana Lane
# Sky Ridge Ln => Sky Ridge Lane
# W Braker Ln => West Braker Lane
# W Braker Ln => West Braker Lane
# W Anderson Ln => West Anderson Lane
# W Anderson Ln => West Anderson Lane
# Rocky Top Ln => Rocky Top Lane
# Chick Pea Ln => Chick Pea Lane
# Pfennig Ln => Pfennig Lane
# Pasadera Ln => Pasadera Lane
# Rockwood Ln => Rockwood Lane
# Fleming court => Fleming Court
# 9600 IH 35 C-200 => 9600 Interstate Highway 35 C-200
# Research Blvd #L2 => Research Boulevard #L2
# South Congress Avene => South Congress Avenue
# FM 685 => Farm-to-Market Road 685
# Burnet Rd Ste, A500 => Burnet Road Suite A500
# Burnet Rd Ste, A500 => Burnet Road Suite A500
# S. Capitol of Texas Hwy, #F-4 => South Capitol of Texas Highway #F-4
# S. Capitol of Texas Hwy, #F-4 => South Capitol of Texas Highway #F-4
# Red Pebble Rd => Red Pebble Road
# Barley Rd => Barley Road
# Barton Springs Rd => Barton Springs Road
# Moon Rock Rd => Moon Rock Road
# Bee Creek Rd => Bee Creek Road
# N Interstate 35 Frontage Rd => North Interstate Highway 35 Frontage Road
# N Interstate 35 Frontage Rd => North Interstate Highway 35 Frontage Road
# Spicewood Springs Rd => Spicewood Springs Road
# Big Meadow Rd => Big Meadow Road
# Palomino Ranch Rd => Palomino Ranch Road
# Commons Rd => Commons Road
# Burnet Rd => Burnet Road
# Tawny Farms Rd => Tawny Farms Road
# N. Lamar suite#L131 => North Lamar Suite L131
# N. Lamar suite#L131 => North Lamar Suite L131
# North Lakeline Boulevard, Ste. 400 => North Lakeline Boulevard Suite 400
# North Lakeline Boulevard, Ste. 400 => North Lakeline Boulevard Suite 400
# 9901 N Capital Of texas => 9901 North Capital Of Texas
# 9901 N Capital Of texas => 9901 North Capital Of Texas
# E. Whitestone Blvd #G-145 => East Whitestone Boulevard #G-145
# E. Whitestone Blvd #G-145 => East Whitestone Boulevard #G-145
# Hill Country Blvd., Suite C1-100 => Hill Country Boulevard Suite C1-100
# Rue de St Tropez => Rue de Saint Tropez
# W. Liberty => West Liberty
# FM 619 => Farm-to-Market Road 619
# 1500 S. IH35 => 1500 South Interstate Highway 35
# 1500 S. IH35 => 1500 South Interstate Highway 35
# N I H 35 Bldg 7 => North Interstate Highway 35 Building 7
# N I H 35 Bldg 7 => North Interstate Highway 35 Building 7
# N I H 35 Bldg 7 => North Interstate Highway 35 Building 7
# N I H 35 Bldg 7 => North Interstate Highway 35 Building 7
# RM1431 => Ranch-to-Market Road 1431
# I35 => Interstate Highway 35
# Highway 71 W => Highway 71 West
# Hwy 290 W => Highway 290 West
# Hwy 290 W => Highway 290 West
# IH 35 North => Interstate Highway 35 North
# FM 620 North => Farm-to-Market Road 620 North
# Tandem Blvd. => Tandem Boulevard
# South Lamar Blvd. => South Lamar Boulevard
# South Exposition Blvd. => South Exposition Boulevard
# W North Loop Blvd. => West North Loop Boulevard
# W North Loop Blvd. => West North Loop Boulevard
# East Old Settlers Blvd. => East Old Settlers Boulevard
# Research Blvd. => Research Boulevard
# RM 620 => Ranch-to-Market Road 620
# FM 620 => Farm-to-Market Road 620
# N FM 620 => North Farm-to-Market Road 620
# N FM 620 => North Farm-to-Market Road 620
# RR 620 => Ranch Road 620
# Country Rd. 452 => Country Road 452
# N Farm-To-Market Road 973 => North Farm-To-Market Road 973
# US 183 => United States Highway 183
# US Highway 183 => United States Highway 183
# U.S. 183 => United States Highway 183
# N HWY 183 => North Highway 183
# N HWY 183 => North Highway 183
# South Interstate 35, Suite B => South Interstate Highway 35 Suite B
# West 11th Street, Suite 275 => West 11th Street Suite 275
# W. University Avenue,Ste 320 => West University Avenue Suite 320
# W. University Avenue,Ste 320 => West University Avenue Suite 320
# Woodall Dr => Woodall Drive
# Walter Seaholm Dr => Walter Seaholm Drive
# Yaupon Range Dr => Yaupon Range Drive
# Lighthouse Landing Dr => Lighthouse Landing Drive
# Round Rock West Dr => Round Rock West Drive
# W Lake Dr => West Lake Drive
# W Lake Dr => West Lake Drive
# W William Cannon Dr => West William Cannon Drive
# W William Cannon Dr => West William Cannon Drive
# Dave Silk Dr => Dave Silk Drive
# Forest Creek Dr => Forest Creek Drive
# Bill Baker Dr => Bill Baker Drive
# Corral de Tierra Dr => Corral de Tierra Drive
# Ivy Dr => Ivy Drive
# Jack Nicklaus Dr => Jack Nicklaus Drive
# Winged Elm Dr => Winged Elm Drive
# Carranzo Dr => Carranzo Drive
# Kyle Center Dr => Kyle Center Drive
# Canyon Springs Dr => Canyon Springs Drive
# Jimmy Clay Dr => Jimmy Clay Drive
# Justin Leonard Dr => Justin Leonard Drive
# Octavia Dr => Octavia Drive
# Horse Wagon Dr => Horse Wagon Drive
# Via Ricco Dr => Via Ricco Drive
# Creekline Dr => Creekline Drive
# Bettis Trophy Dr => Bettis Trophy Drive
# Rain Song Dr => Rain Song Drive
# Executive Center Dr => Executive Center Drive
# Via Dono Dr => Via Dono Drive
# West Ben White Boulevard, #203 => West Ben White Boulevard #203
# W Hwy 71 => West Highway 71
# W Hwy 71 => West Highway 71
# TX 71 => Texas 71
# Hwy 71 => Highway 71
# U.S. 79 => United States Highway 79
# N. IH 35 Pflugerville => North Interstate Highway 35 Pflugerville
# N. IH 35 Pflugerville => North Interstate Highway 35 Pflugerville
# West Louis Henna Blvd => West Louis Henna Boulevard
# Airport Blvd => Airport Boulevard
# Swenson Farms Blvd => Swenson Farms Boulevard
# Industrial Oaks Blvd => Industrial Oaks Boulevard
# N Bell Blvd => North Bell Boulevard
# N Bell Blvd => North Bell Boulevard
# North Lamar Blvd => North Lamar Boulevard
# Industrial Blvd => Industrial Boulevard
# N. Lamar Blvd => North Lamar Boulevard
# N. Lamar Blvd => North Lamar Boulevard
# Stonelake Blvd => Stonelake Boulevard
# Escarpment Blvd => Escarpment Boulevard
# E Palm Valley Blvd => East Palm Valley Boulevard
# E Palm Valley Blvd => East Palm Valley Boulevard
# South Lamar Blvd => South Lamar Boulevard
# South Bell Blvd => South Bell Boulevard
# North Research Blvd => North Research Boulevard
# Research Blvd => Research Boulevard
# 10000 Research Blvd => 10000 Research Boulevard
# W Hwy 71, STE D1 => West Highway 71, Suite D1
# W Hwy 71, STE D1 => West Highway 71, Suite D1
# W Hwy 71, STE D1 => West Highway 71, Suite D1
# RM 2244 => Ranch-to-Market Road 2244
# Old FM 2243 => Old Farm-to-Market Road 2243
# Avenue H => Avenue H
# North Lamar Boulevard suite #B100 => North Lamar Boulevard Suite #B100
# FM 1825 => Farm-to-Market Road 1825
# Deer Shadow Ps => Deer Shadow Pass
# Bidens Pl => Bidens Place
# Veletta Pl => Veletta Place
# Shoal Creek Blvd, Bld 3 => Shoal Creek Boulevard Building 3
# Shoal Creek Blvd, Bld 3 => Shoal Creek Boulevard Building 3
# Avenue C => Avenue C
# South IH-35 => South Interstate Highway 35
# N IH-35 => North Interstate Highway 35
# N IH-35 => North Interstate Highway 35
# Spreading Oaks Drive/Rd => Spreading Oaks Drive/Road
# Misty Heights Cc => Misty Heights Cove
# FM 969 => Farm-to-Market Road 969
# Blue Sky Cv => Blue Sky Cove
# Texas Ash Cv => Texas Ash Cove
# Tom Kite Cv => Tom Kite Cove
# Quiet Meadows Cv => Quiet Meadows Cove
# Peat Moors Cv => Peat Moors Cove
# La Estrella Cv => La Estrella Cove
# Morning Primrose Cv => Morning Primrose Cove
# Mallard Cv => Mallard Cove
# Rooney Cv => Rooney Cove
# Copper Point Cv => Copper Point Cove
# Old Corral Cv => Old Corral Cove
# Red River Cv => Red River Cove
# Secluded Willow Cv => Secluded Willow Cove
# Hilltop Canyon Cv => Hilltop Canyon Cove
# Hal Sutton Cv => Hal Sutton Cove
# La Roca Cv => La Roca Cove
# Arbole Cv => Arbole Cove
# Clear Pond Cv => Clear Pond Cove
# Salem Oak Cv => Salem Oak Cove
# Ripley Castle Cv => Ripley Castle Cove
# Enchanted Cv => Enchanted Cove
# Lapin Cv => Lapin Cove
# Mock Cherry Cv => Mock Cherry Cove
# Claro Vista Ct => Claro Vista Court
# Ely Ct => Ely Court
# Krupa Ct => Krupa Court
# Sterling Heights Ct => Sterling Heights Court
# Sweetgum Ct => Sweetgum Court
# Costello Ct => Costello Court
# Stirling Castle Ct => Stirling Castle Court
# North Mo-Pac Expressway => North MoPac Expressway
# Harrier Flight Trl => Harrier Flight Trail
# Poppy Hills Trl => Poppy Hills Trail
# Scenic Overlook Trl => Scenic Overlook Trail
# S Capital of Texas Hwy => South Capital of Texas Highway
# S Capital of Texas Hwy => South Capital of Texas Highway
# Avenue I => Avenue I
# Rue de St Raphael => Rue de Saint Raphael
# Greenlawn Pkwy => Greenlawn Parkway
# Roger Hanks Pkwy => Roger Hanks Parkway
# Soter Pkwy => Soter Parkway
# Riata Trace Pkwy => Riata Trace Parkway
# S Interstate 35, #260 => South Interstate Highway 35 #260
# S Interstate 35, #260 => South Interstate Highway 35 #260
# FM 535 => Farm-to-Market Road 535
# FM 1327 => Farm-to-Market Road 1327
# Stonebridge Dr. => Stonebridge Drive
# Sportsplex Dr. => Sportsplex Drive
# Cannon Dr. => Cannon Drive
# 11928 Stonehollow Dr. => 11928 Stonehollow Drive
# 321 W Ben White Blvd #300 => 321 West Ben White Boulevard #300
# 321 W Ben White Blvd #300 => 321 West Ben White Boulevard #300
# S Bell Blvd., Suite 301 => South Bell Boulevard Suite 301
# S Bell Blvd., Suite 301 => South Bell Boulevard Suite 301
# Hwy 290 W. Ste. 301 => Highway 290 West Suite 301
# Hwy 290 W. Ste. 301 => Highway 290 West Suite 301
# Hwy 290 W. Ste. 301 => Highway 290 West Suite 301
# Meadows Dr #306 => Meadows Drive #306
# E. North Loop => East North Loop
# Rue de St Germaine => Rue de Saint Germaine
# Research Blvd #3000a => Research Boulevard #3000a
# N Interstate 35, Suite 1805 => North Interstate Highway 35 Suite 1805
# N Interstate 35, Suite 1805 => North Interstate Highway 35 Suite 1805
# Research Blvd, Austin => Research Boulevard Austin
# FM 3177 => Farm-to-Market Road 3177
# Round Rock Ave => Round Rock Avenue
# Barstow Ave => Barstow Avenue
# South Congress Ave => South Congress Avenue
# E. University Ave => East University Avenue
# E. University Ave => East University Avenue
# S Congress Ave => South Congress Avenue
# S Congress Ave => South Congress Avenue
# IH-35 South, #150 => Interstate Highway 35 South, #150
# Sycamore Tr => Sycamore Trail
# Posse Tr => Posse Trail
# Sunflower Tr => Sunflower Trail
# State Highway 71 W Spicewood => State Highway 71 West Spicewood
# TX 45 => Texas 45
# I-35 Frontage => Interstate Highway 35 Frontage
# devonshire cove => devonshire Cove
# Pecan St => Pecan Street
# N Main St => North Main Street
# N Main St => North Main Street
# S 1st St => South 1st Street
# S 1st St => South 1st Street
# E Oltorf St => East Oltorf Street
# E Oltorf St => East Oltorf Street
# E 43rd St => East 43rd Street
# E 43rd St => East 43rd Street
# Red River St => Red River Street
# W 10th St => West 10th Street
# W 10th St => West 10th Street
# W Annie St => West Annie Street
# W Annie St => West Annie Street
# E 51st St => East 51st Street
# E 51st St => East 51st Street
# Rio Grande St => Rio Grande Street
# W 6th St => West 6th Street
# W 6th St => West 6th Street
# West Lynn St => West Lynn Street
# Duval St => Duval Street
# brigadoon lane => Brigadoon Lane
# brigadoon lane => Brigadoon Lane

# %% [markdown]
# ##### More things to fix:
#
# - Ranch Road 620 is also Farm-to-Market 620. Which one is correct? I don't know. I'll just leave it as is.
# - US highway 290 is also country road 290, etc. Will not fix that one either.

# %% [markdown]
# ### Other parameters to look at (other values of k under tag)

# %%
k = set()
for event, element in ET.iterparse(SAMPLE_FILE):
    if element.tag == "tag" or element.tag == "way":
        for tag in element.iter("tag"):
             k.add(tag.attrib['k'])

# %%
len(k)
# Out:
# 347

# %%
k
# Out:
# {'FIXME',
#  'NHS',
#  'Texas_Trunk_System',
#  'abandoned',
#  'access',
#  'addr:city',
#  'addr:country',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:unit',
#  'admin_level',
#  'aeroway',
#  'alt_name',
#  'amenity',
#  'area',
#  'artist_name',
#  'artwork_type',
#  'atm',
#  'attribution',
#  'barrier',
#  'basin',
#  'bench',
#  'bicycle',
#  'bicycle_parking',
#  'boat',
#  'border_type',
#  'boundary',
#  'brand',
#  'bridge',
#  'bridge:name',
#  'building',
#  'building:levels',
#  'building:min_level',
#  'building_1',
#  'bus',
#  'button_operated',
#  'cables',
#  'capacity',
#  'capacity:disabled',
#  'capital',
#  'car_wash',
#  'cash',
#  'cash_in',
#  'census:population',
#  'circuits',
#  'coa:place_id',
#  'colour',
#  'commercial',
#  'construction',
#  'contact:phone',
#  'covered',
#  'craft',
#  'created_by',
#  'crop',
#  'crossing',
#  'cuisine',
#  'currency:XBT',
#  'cutting',
#  'cycleway',
#  'cycleway:foot',
#  'cycleway:left',
#  'cycleway:right',
#  'delivery',
#  'denomination',
#  'description',
#  'description:en',
#  'design',
#  'designation',
#  'destination',
#  'destination:left',
#  'destination:ref',
#  'destination:ref:to',
#  'destination:right',
#  'destination:street',
#  'diet:gluten_free',
#  'direction',
#  'dispensing',
#  'disused:amenity',
#  'disused:highway',
#  'drive_in',
#  'drive_through',
#  'drive_thru',
#  'ele',
#  'electrified',
#  'elevation',
#  'emergency',
#  'entrance',
#  'exit_to',
#  'expressway',
#  'fax',
#  'fee',
#  'fence_type',
#  'fire_hydrant:type',
#  'fixme',
#  'foot',
#  'footway',
#  'ford',
#  'frequency',
#  'from',
#  'fuel:diesel',
#  'fuel:e10',
#  'garage',
#  'gauge',
#  'generator:method',
#  'generator:output:electricity',
#  'generator:source',
#  'generator:type',
#  'gnis:Class',
#  'gnis:County',
#  'gnis:County_num',
#  'gnis:ST_alpha',
#  'gnis:ST_num',
#  'gnis:county_id',
#  'gnis:county_name',
#  'gnis:created',
#  'gnis:feature_id',
#  'gnis:feature_type',
#  'gnis:id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'gnis:state_id',
#  'golf',
#  'golf_cart',
#  'grades',
#  'have_riverbed',
#  'height',
#  'hgv',
#  'highway',
#  'historic',
#  'horse',
#  'import',
#  'import_uuid',
#  'information',
#  'intermittent',
#  'internet_access',
#  'is_in',
#  'is_in:country',
#  'is_in:country_code',
#  'is_in:iso_3166_2',
#  'is_in:state',
#  'is_in:state_code',
#  'isced:level',
#  'junction',
#  'landuse',
#  'lanes',
#  'lanes:backward',
#  'lanes:both_ways',
#  'lanes:forward',
#  'layer',
#  'lcn',
#  'lcn_ref',
#  'leisure',
#  'leisure_1',
#  'length',
#  'level',
#  'line',
#  'lit',
#  'loc_name',
#  'location',
#  'man_made',
#  'material',
#  'maxheight',
#  'maxspeed',
#  'menu',
#  'microbrewery',
#  'military',
#  'modifier',
#  'motor_vehicle',
#  'mtb:scale',
#  'name',
#  'name:en',
#  'name:es',
#  'name:ja',
#  'name:pl',
#  'name:ru',
#  'name:ta',
#  'name:uk',
#  'name_1',
#  'name_2',
#  'name_3',
#  'natural',
#  'network',
#  'nist:fips_code',
#  'nist:state_fips',
#  'noexit',
#  'noref',
#  'note',
#  'note:odbl',
#  'noturn',
#  'nrhp:id',
#  'odbl',
#  'odbl:note',
#  'office',
#  'official_name',
#  'official_ref',
#  'old_name',
#  'old_railway_operator',
#  'old_ref',
#  'oneway',
#  'oneway:bicycle',
#  'opening_date',
#  'opening_hours',
#  'operator',
#  'organic',
#  'outdoor_seating',
#  'park_ride',
#  'parking',
#  'parking:condition:both',
#  'parking:lane:both',
#  'payment:bitcoin',
#  'payment:notes',
#  'phone',
#  'place',
#  'population',
#  'power',
#  'proposed',
#  'public_transport',
#  'public_transport:version',
#  'railway',
#  'ref',
#  'ref:shop:num',
#  'reference',
#  'reg_name',
#  'reg_ref',
#  'religion',
#  'restriction',
#  'roof:shape',
#  'roundabout',
#  'route',
#  'route_master',
#  'route_ref',
#  'sac_scale',
#  'school_type',
#  'segregated',
#  'service',
#  'service:bicycle:chain_tool',
#  'shelter',
#  'shelter_type',
#  'shop',
#  'shoulder',
#  'shoulder:width',
#  'sidewalk',
#  'smoking',
#  'smoothness',
#  'social_facility',
#  'social_facility:for',
#  'source',
#  'source:Texas_Trunk_System',
#  'source:geometry',
#  'source:maxspeed',
#  'source:name',
#  'source_ref',
#  'sport',
#  'state_capital',
#  'stop',
#  'structure',
#  'studio',
#  'substance',
#  'substation',
#  'supervised',
#  'surface',
#  'surveillance',
#  'surveillance:type',
#  'symbol',
#  'takeaway',
#  'text',
#  'tiger:CLASSFP',
#  'tiger:CPI',
#  'tiger:FUNCSTAT',
#  'tiger:LSAD',
#  'tiger:MTFCC',
#  'tiger:NAME',
#  'tiger:NAMELSAD',
#  'tiger:PCICBSA',
#  'tiger:PCINECTA',
#  'tiger:PLACEFP',
#  'tiger:PLACENS',
#  'tiger:PLCIDFP',
#  'tiger:STATEFP',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_base_2',
#  'tiger:name_base_3',
#  'tiger:name_direction_prefix',
#  'tiger:name_direction_prefix_1',
#  'tiger:name_direction_prefix_2',
#  'tiger:name_direction_suffix',
#  'tiger:name_direction_suffix_1',
#  'tiger:name_direction_suffix_2',
#  'tiger:name_direction_suffix_3',
#  'tiger:name_type',
#  'tiger:name_type_1',
#  'tiger:name_type_2',
#  'tiger:name_type_3',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:upload_uuid',
#  'tiger:zip_left',
#  'tiger:zip_left_1',
#  'tiger:zip_left_2',
#  'tiger:zip_left_3',
#  'tiger:zip_left_4',
#  'tiger:zip_right',
#  'tiger:zip_right_1',
#  'tiger:zip_right_2',
#  'tiger:zip_right_3',
#  'tiger:zip_right_4',
#  'to',
#  'toilets:disposal',
#  'toilets:wheelchair',
#  'toll',
#  'tourism',
#  'tower:type',
#  'tracktype',
#  'traffic_calming',
#  'traffic_sign',
#  'traffic_signals',
#  'traffic_signals:sound',
#  'trees',
#  'tunnel',
#  'turn',
#  'turn:lanes',
#  'turn:lanes:backward',
#  'turn:lanes:both_ways',
#  'turn:lanes:forward',
#  'type',
#  'undefined',
#  'unsigned_ref',
#  'usage',
#  'voltage',
#  'waste',
#  'water',
#  'waterway',
#  'website',
#  'wheelchair',
#  'width',
#  'width:lanes:backward',
#  'width:lanes:forward',
#  'wifi',
#  'wikipedia'}

# %% [markdown]
# From above, there are a lot of parameters to look at and see if the data are consistent, but for this project, only the street names, phone number, postcode, and city names were explored.
#
# ### Auditing and Cleaning Phone Numbers

# %% [markdown]
# Following the methods for auditing street names, is_phone function was created:

# %%
def is_phone(element):
    return (element.attrib['k'] == "phone" or element.attrib['k'] == "contact:phone")

# %% [markdown]
# Regex for phone number:

# %%
phone_re = re.compile(r'^\d\d\d\-\d\d\d\-\d\d\d\d$')

# %% [markdown]
# Printing out the phone numbers in the sample osm file that do not follow the regex above:

# %%
for event, element in ET.iterparse(SAMPLE_FILE):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_phone(tag):
                if phone_re.search(tag.attrib['v']) == None:
                    print tag.attrib['v']
# Out:
# (512) 782-5659
# (512) 892-6699
# +1 512-472-1666
# (512) 494-9300
# (512)482-8244
# +1-512-821-9472
# (512) 336-7200
# (512) 478-8086
# (512) 336-7706
# (512) 312-0907
# +1 512 357 4143
# 51224990093
# +1 512-275-0852
# (512) 524-1311
# (512) 246-7645
# (512) 528-0027
# +1-512-918-0890
# +1 512 219 5008
# +1 512 634 0070
# (512) 528-7700
# 512 466-3937
# (512) 733-6828
# (512) 255-3629
# 5124282500
# +1 (512) 469-7000
# +1 512 477 4430
# (512) 312-1615
# +1 512 268 5326
# +1 (512) 974-9920
# 512.386.1295
# +1 512 478-8600
# +1 512 4771101
# +1-512-462-0202
# (512) 259-5500
# +1-512-690-9340

# %% [markdown]
# The following function cleans up the phone numbers:

# %%
def update_phone(number):
    phone_re = re.compile(r'^\d\d\d\-\d\d\d\-\d\d\d\d$')
    if phone_re.search(number) == None:
        phno = []
        number = list(number.lstrip("+1"))
        for char in number:
            try:
                if int(char) in [x for x in range(10)]:
                    phno.append(char)
            except ValueError:
                continue
        number = "".join(phno)
        number = number[:3] + "-" + number[3:6] + "-" + number[6:]
                    
    return number

# %% [markdown]
# Testing this function:

# %%
update_phone("+1 512-472-1666")
# Out:
# '512-472-1666'

# %%
for event, element in ET.iterparse(SAMPLE_FILE):
    for tag in element.iter("tag"):
            if is_phone(tag):
                print tag.attrib['v'], "=>", update_phone(tag.attrib['v'])
# Out:
# +1 512 322-9168 => 512-322-9168
# +1 512 322-9168 => 512-322-9168
# (512) 282-0182 => 512-282-0182
# (512) 282-0182 => 512-282-0182
# 512-442-0655 => 512-442-0655
# 512-442-0655 => 512-442-0655
# 512-386-3300 => 512-386-3300
# 512-386-3300 => 512-386-3300
# 512-447-8288 => 512-447-8288
# 512-342-2252 => 512-342-2252
# 512-342-2252 => 512-342-2252
# 512-338-2241 => 512-338-2241
# 512-338-2241 => 512-338-2241
# (512) 469-5966 => 512-469-5966
# (512) 469-5966 => 512-469-5966
# (512) 892-6699 => 512-892-6699
# (512) 892-6699 => 512-892-6699
# (512) 339-7860 => 512-339-7860
# (512) 339-7860 => 512-339-7860
# (512) 832-8788 => 512-832-8788
# (512) 832-8788 => 512-832-8788
# (512) 444-2205 => 512-444-2205
# (512) 444-2205 => 512-444-2205
# (512) 431-2133 => 512-431-2133
# (512) 431-2133 => 512-431-2133
# (512) 444-7770 => 512-444-7770
# (512) 444-7770 => 512-444-7770
# (512) 494-9336 => 512-494-9336
# (512) 494-9336 => 512-494-9336
# (512) 472-9240 => 512-472-9240
# (512) 472-9240 => 512-472-9240
# (512) 861-7020 => 512-861-7020
# (512) 861-7020 => 512-861-7020
# (512) 476-1490 => 512-476-1490
# (512) 476-1490 => 512-476-1490
# +1 512-472-1666 => 512-472-1666
# +1 512-472-1666 => 512-472-1666
# +1 512-478-2491 => 512-478-2491
# +1 512-478-2491 => 512-478-2491
# +1 512-494-1335 => 512-494-1335
# +1 512-494-1335 => 512-494-1335
# (512) 255 - 3629 => 512-255-3629
# (512) 255 - 3629 => 512-255-3629
# (512) 238-8008 => 512-238-8008
# (512) 238-8008 => 512-238-8008
# (512) 244-2222 => 512-244-2222
# (512) 244-2222 => 512-244-2222
# (512) 255-6952 => 512-255-6952
# (512) 255-6952 => 512-255-6952
# (512) 334-4684 => 512-334-4684
# (512) 334-4684 => 512-334-4684
# 512-476-3131 => 512-476-3131
# 512-476-3131 => 512-476-3131
# (512) 494-9300 => 512-494-9300
# (512) 494-9300 => 512-494-9300
# +1-512-712-5700 => 512-712-5700
# +1-512-712-5700 => 512-712-5700
# (512) 477-2676 => 512-477-2676
# (512) 477-2676 => 512-477-2676
# (512) 501-6738 => 512-501-6738
# (512) 501-6738 => 512-501-6738
# 512-782-0546 => 512-782-0546
# 512-782-0546 => 512-782-0546
# (512) 472-8306 => 512-472-8306
# (512) 472-8306 => 512-472-8306
# (512) 693-2464 => 512-693-2464
# (512) 693-2464 => 512-693-2464
# (512) 996-8900 => 512-996-8900
# (512) 996-8900 => 512-996-8900
# (512) 495-9425 => 512-495-9425
# (512) 495-9425 => 512-495-9425
# (512) 474-7749 => 512-474-7749
# (512) 474-7749 => 512-474-7749
# (512) 494-1150 => 512-494-1150
# (512) 494-1150 => 512-494-1150
# (512) 336-5999 => 512-336-5999
# (512) 336-5999 => 512-336-5999
# (512) 335-5115 => 512-335-5115
# (512) 335-5115 => 512-335-5115
# (512) 335-0300 => 512-335-0300
# (512) 335-0300 => 512-335-0300
# (512) 336-8888 => 512-336-8888
# (512) 336-8888 => 512-336-8888
# 512) 719-5575 => 512-719-5575
# 512) 719-5575 => 512-719-5575
# (512) 832-9722 => 512-832-9722
# (512) 832-9722 => 512-832-9722
# (512) 833-8188 => 512-833-8188
# (512) 833-8188 => 512-833-8188
# 512-930-3673 => 512-930-3673
# 512-930-6250 => 512-930-6250
# +1 512 262 0070 => 512-262-0070

# %% [markdown]
# The test above revealed that some phone numbers are not properly cleaned, such as if there are two phone numbers provided. This might be cleaned by creating another field for the other phone number. This will not be done here. Instead the update_phone function will be modified:

# %%
def update_phone(number):
    phone_re = re.compile(r'^\d\d\d\-\d\d\d\-\d\d\d\d$')
    if phone_re.search(number) == None:
        phno = []
        number = list(number.lstrip("+1"))
        for char in number:
            try:
                if int(char) in [x for x in range(10)]:
                    if len(phno) == 10:
                        continue
                    phno.append(char)
            except ValueError:
                continue
        number = "".join(phno)
        number = number[:3] + "-" + number[3:6] + "-" + number[6:]
                    
    return number

# %% [markdown]
# Testing the function below:

# %%
update_phone("+1-512-666-5286;+1-855-444-8301")
# Out:
# '512-666-5286'

# %% [markdown]
# #### Postal Code
#
# Exploration of k values from parsing the whole osm file revealed that postcode is referred to as addr:postcode or postal_code. Hence, the following function for returning postcode values:

# %%
def is_postcode(element):
    return (element.attrib['k'] == "addr:postcode" or element.attrib['k'] == "postal_code")

# %% [markdown]
# Regex for postcode:

# %%
postcode_re = re.compile(r'^7\d\d\d\d$')

# %% [markdown]
# To explore the postcode, here we use a counter and the get_element function used in making the sample file on the whole file instead of the sample osm file:

# %%
counter = 0
for element in get_element(OSM_FILE):
    if counter == 25:
        break
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_postcode(tag):
                if postcode_re.search(tag.attrib['v']) == None:
                    print tag.attrib['v']
                    counter += 1
# Out:
# 78704-5639
# 78753-4150
# 78728-1275
# 78758-7008
# 78758-7013
# 14150
# 78704-7205
# 76574-4649
# TX 78613
# TX 78728
# 78640-4520
# TX 78724
# 78640-6137
# TX 78758
# TX 78745
# TX 78735
# 78728-1275
# 78759-3504
# 78724-1199
# 78724-1199
# 78724-1199
# 78724-1199
# 78724-1199
# Texas
# 78640-6137

# %% [markdown]
# Based on these values, the function below was created to update the data:

# %%
def update_postcode(postcode):
    try:
        postcode = re.compile(r'7\d\d\d\d').search(postcode).group()
    except AttributeError:
        postcode = 'None'
    return postcode

# %% [markdown]
# Testing the function:

# %%
for element in get_element(OSM_FILE):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_postcode(tag):
                if postcode_re.search(tag.attrib['v']) == None:
                    print tag.attrib['v'], "=>", update_postcode(tag.attrib['v'])
# Out:
# 78704-5639 => 78704
# 78753-4150 => 78753
# 78728-1275 => 78728
# 78758-7008 => 78758
# 78758-7013 => 78758
# 14150 => None
# 78704-7205 => 78704
# 76574-4649 => 76574
# TX 78613 => 78613
# TX 78728 => 78728
# 78640-4520 => 78640
# TX 78724 => 78724
# 78640-6137 => 78640
# TX 78758 => 78758
# TX 78745 => 78745
# TX 78735 => 78735
# 78728-1275 => 78728
# 78759-3504 => 78759
# 78724-1199 => 78724
# 78724-1199 => 78724
# 78724-1199 => 78724
# 78724-1199 => 78724
# 78724-1199 => 78724
# Texas => None
# 78640-6137 => 78640
# 78626‎ => 78626
# 78754-5701 => 78754
# tx => None

# %% [markdown]
# To completely clean this parameter, it is best to create another field for county codes, instead of getting rid of them. I will not be doing this here.
#
# ### Auditing the city data

# %%
def is_city(element):
    return element.attrib['k'] == "addr:city"

# %% [markdown]
# Here, it is probably best to create a list of expected cities:

# %%
expectedcities = ['Austin', 'Buda', 'Round Rock', 'Leander', 'Lago Vista', 'Kyle', 'Pflugerville',
                  'Cedar Park', 'Manchaca', 'Del Valle', 'Dripping Springs', 'Bee Cave', 'Bastrop', 
                  'Cedar Creek', 'Creedmoor', 'Driftwood', 'Elgin', 'Georgetown', 'Hutto', 
                  'Jonestown', 'Lakeway', 'Lost Pines', 'Manor', 'Maxwell', 'San Marcos', 
                  'Smithville', 'Spicewood', 'Sunset Valley', 'Taylor', 'Webberville',
                  'West Lake Hills', 'Wimberley']

# %% [markdown]
# Auditing the cities:

# %%
cities = set()
for element in get_element(OSM_FILE):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_city(tag):
                if tag.attrib['v'] not in expectedcities:
                    cities.add(tag.attrib['v'])

# %%
cities
# Out:
# {'Austin, TX',
#  'Austin, Tx',
#  'Austin;TX;USA',
#  'Barton Creek',
#  'Bastrop, TX',
#  'Cedar Park, TX',
#  'Dripping Springs TX',
#  'Dripping Springs, Tx',
#  'Elgin, TX',
#  'Georgetown, TX',
#  'Kyle, TX',
#  'Leander, TX',
#  'Manchaca,',
#  'N Austin',
#  'Pflugerville, TX',
#  'Round Rock, TX',
#  'San Gabriel Village Boulevard',
#  'Spicewood, TX',
#  'Ste 128, Austin',
#  'Taylor, TX',
#  'Westlake Hills, TX',
#  'austin',
#  'kyle'}

# %% [markdown]
# From above, the errant values have ", TX" or the first letter is not capitalized. A few are not cities at all, but probably a street address.
#
# As in update_name function for street names, a dictionary for mapping is good to use:

# %%
mapping_city = {
    "austin": "Austin",
    "Austin, TX": "Austin",
    "Cedar Park, TX": "Cedar Park",
    "Round Rock, TX": "Round Rock",
    "Dripping Springs, TX": "Dripping Springs",
    "Westlake Hills, TX": "West Lake Hills",
    "kyle": "Kyle",
    "Austin;TX;USA": "Austin",
    "Barton Creek": "Austin",
    "Austin, Tx": "Austin",
    "Taylor, TX": "Taylor",
    "San Gabriel Village Boulevard": "Georgetown",
    "Spicewood, TX": "Spicewood",
    "Ste 128, Austin": "Austin",
    "Pflugerville, TX": "Pflugerville",
    "Manchaca,": "Manchacha",
    "Elgin, TX": "Elgin",
    "Kyle, TX": "Kyle",
    "Dripping Springs, Tx": "Dripping Springs",
    "Bastrop, TX": "Bastrop",
    "Georgetown, TX": "Georgetown",
    "Dripping Springs TX": "Dripping Springs",
    "Leander, TX": "Leander",
    "N Austin": "Austin"
}

# %%
def update_city(city):
    if city not in expectedcities:
        if city in mapping_city.keys():
            city = mapping_city[city]
        else:
            city = "None"
    return city

# %% [markdown]
# Testing the function:

# %%
for element in get_element(OSM_FILE):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if is_city(tag):
                if tag.attrib['v'] not in expectedcities:
                    print tag.attrib['v'], "=>", update_city(tag.attrib['v'])
# Out:
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Pflugerville, TX => Pflugerville
# Elgin, TX => Elgin
# Austin, TX => Austin
# Spicewood, TX => Spicewood
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Pflugerville, TX => Pflugerville
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Cedar Park, TX => Cedar Park
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Westlake Hills, TX => West Lake Hills
# Bastrop, TX => Bastrop
# Dripping Springs, Tx => Dripping Springs
# Georgetown, TX => Georgetown
# Austin, TX => Austin
# Round Rock, TX => Round Rock
# Taylor, TX => Taylor
# Austin, TX => Austin
# Cedar Park, TX => Cedar Park
# Barton Creek => Austin
# austin => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Kyle, TX => Kyle
# Austin, TX => Austin
# Austin, TX => Austin
# austin => Austin
# Austin, Tx => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Ste 128, Austin => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# San Gabriel Village Boulevard => Georgetown
# Cedar Park, TX => Cedar Park
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# N Austin => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Westlake Hills, TX => West Lake Hills
# Austin, TX => Austin
# Manchaca, => Manchacha
# Pflugerville, TX => Pflugerville
# Leander, TX => Leander
# Austin, TX => Austin
# Pflugerville, TX => Pflugerville
# Austin, TX => Austin
# Austin, TX => Austin
# Dripping Springs, Tx => Dripping Springs
# Dripping Springs, Tx => Dripping Springs
# Taylor, TX => Taylor
# Dripping Springs TX => Dripping Springs
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin, TX => Austin
# Bastrop, TX => Bastrop
# Elgin, TX => Elgin
# Austin, TX => Austin
# Austin, TX => Austin
# Austin;TX;USA => Austin
# Austin, TX => Austin
# kyle => Kyle
# kyle => Kyle
# Georgetown, TX => Georgetown
# Austin, TX => Austin
# Austin, TX => Austin
# N Austin => Austin
# N Austin => Austin
# N Austin => Austin
# Elgin, TX => Elgin
# Cedar Park, TX => Cedar Park
# austin => Austin

# %% [markdown]
# The update_city function is better written as such:

# %%
def update_city(city, expectedcities, mapping_city):
    if city not in expectedcities:
        if city in mapping_city.keys():
            city = mapping_city[city]
        else:
            city = "None"
    return city

# %% [markdown]
# Testing the function:

# %%
update_city("Austin, TX", expectedcities, mapping_city)
# Out:
# 'Austin'

# %% [markdown]
# ### Combination of all the update functions: clean function
#
# To make it easier to write the shape_element function (see part 2), a function which combines all the update functions created above was created:

# %%
def clean(value, tag, mapping_street, expectedcities, mapping_city):
    if is_street_name(tag):
        value = update_name(value, mapping_street)
    elif is_phone(tag):
        value = update_phone(value)
    elif is_postcode(tag):
        value = update_postcode(value)
    elif is_city(tag):
        value = update_city(value, expectedcities, mapping_city)
    return value

# %% [markdown]
# Testing the function:

# %%
counter = 0
for element in get_element(SAMPLE_FILE):
    if counter == 1:
        break
    if element.tag == 'node':
        for tag in element.iter('tag'):
            if is_street_name(tag) or is_phone(tag) or is_postcode(tag) or is_city(tag):
                print tag.attrib['v'], '=>', clean(tag.attrib['v'], tag, mapping_street, expectedcities, mapping_city)
                counter += 1
# Out:
# 512-444-0762 => 512-444-0762
# Austin => Austin
# Burleson Road => Burleson Road
# 78741 => 78741
# Austin => Austin
# (512) 782-5659 => 512-782-5659
# Austin => Austin
# West 35th Street => West 35th Street
# 78703 => 78703
# W. Slaughter Lane => West Slaughter Lane
# Brodie Lane => Brodie Lane
# W North Loop Blvd. => West North Loop Boulevard
# 78751 => 78751
# Round Rock Avenue => Round Rock Avenue
# 78681 => 78681
# South IH-35 => South Interstate Highway 35
# 78744 => 78744
# South 1st Street => South 1st Street
# E 43rd St => East 43rd Street
# 78751 => 78751
# 512-338-2241 => 512-338-2241
# Austin => Austin
# Research Blvd => Research Boulevard
# 78759 => 78759
# (512) 892-6699 => 512-892-6699
# Westgate Boulevard => Westgate Boulevard
# 78745 => 78745
# +1 512-472-1666 => 512-472-1666
# Round Rock Avenue => Round Rock Avenue
# 78681 => 78681
# (512) 494-9300 => 512-494-9300
# W Anderson Ln => West Anderson Lane
# 78757 => 78757
# Riata Trace Parkway => Riata Trace Parkway
# 512-249-6464 => 512-249-6464
# US 290 => United States Highway 290
# Commons Rd => Commons Road
# 78620 => 78620
# 512-301-1007 => 512-301-1007
# Austin => Austin
# Escarpment Blvd => Escarpment Boulevard
# 78749 => 78749
# Austin => Austin
# Guadalupe Street => Guadalupe Street
# 78705 => 78705
# San Jacinto Boulevard => San Jacinto Boulevard
# (512)482-8244 => 512-482-8244
# 888-619-2272 => 888-619-2272
# +1-512-821-9472 => 512-821-9472
# Austin => Austin
# West Parmer Lane => West Parmer Lane
# 78727 => 78727
# Austin => Austin
# Barton Hills Drive => Barton Hills Drive
# Research Boulevard => Research Boulevard
# 78757 => 78757
# Golf Course Road => Golf Course Road
# Austin => Austin
# N I H 35 Bldg 7 => North Interstate Highway 35 Building 7
# 78753 => 78753
# (512) 336-7200 => 512-336-7200
# Austin => Austin
# Riata Trace Pkwy => Riata Trace Parkway
# 78727 => 78727
# Austin => Austin
# Brodie Lane => Brodie Lane
# 78748 => 78748
# (512) 478-8086 => 512-478-8086
# Austin, TX => Austin
# East 7th Street => East 7th Street
# 78702 => 78702
# (512) 336-7706 => 512-336-7706
# Austin, TX => Austin
# Ranch Road 620 => Ranch Road 620
# 78726 => 78726
# Austin => Austin
# 78741 => 78741
# Austin => Austin
# East Ben White Boulevard => East Ben White Boulevard
# 78741 => 78741
# Austin => Austin
# West 15th Street => West 15th Street
# Austin => Austin
# Congress Avenue => Congress Avenue
# Austin => Austin
# East 5th Street => East 5th Street
# 78701 => 78701
# Austin => Austin
# Vargas Road => Vargas Road
# Austin => Austin
# West 17th Street => West 17th Street
# 78701 => 78701
# Austin => Austin
# Rio Grande Street => Rio Grande Street
# 512-382-9106 => 512-382-9106
# Ranch-to-Market Road 620 => Ranch-to-Market Road 620
# 512-716-1118 => 512-716-1118
# Buda => Buda
# 78610 => 78610
# Farm-to-Market Road 1626 => Farm-to-Market Road 1626
# Round Rock => Round Rock
# Twin Ridge Parkway => Twin Ridge Parkway
# 78664 => 78664
# Leander => Leander
# Crystal Falls Parkway => Crystal Falls Parkway
# 78646 => 78646
# Austin => Austin
# Balcones Club Drive => Balcones Club Drive
# 78750 => 78750
# Lago Vista => Lago Vista
# Rimrock Drive => Rimrock Drive
# 78645 => 78645
# 512-467-2225 => 512-467-2225
# Kyle => Kyle
# west Center Street => west Center Street
# 78640 => 78640
# Austin => Austin
# Desert Willow Way => Desert Willow Way
# Austin => Austin
# Desert Willow Way => Desert Willow Way
# Austin => Austin
# Desert Willow Way => Desert Willow Way
# Austin => Austin
# Open Sky Road => Open Sky Road
# Austin => Austin
# Red River Cv => Red River Cove
# Austin => Austin
# Blazing Star Drive => Blazing Star Drive
# Austin => Austin
# Blazing Star Drive => Blazing Star Drive
# Austin => Austin
# Running Water Way => Running Water Way
# Austin => Austin
# Grassy Field Road => Grassy Field Road
# Austin => Austin
# Blazing Star Drive => Blazing Star Drive
# (512) 312-0907 => 512-312-0907
# Buda => Buda
# I 35 => Interstate Highway 35
# 78610 => 78610
# 512-343-8020 => 512-343-8020
# Austin => Austin
# Far West Boulevard => Far West Boulevard
# 78731 => 78731
# South Congress Avenue => South Congress Avenue
# Guadalupe Street => Guadalupe Street
# South Lamar Boulevard => South Lamar Boulevard
# Manor Road => Manor Road
# South Congress Avenue => South Congress Avenue
# 512-345-7238 => 512-345-7238
# Austin => Austin
# Mesa Drive => Mesa Drive
# 78731 => 78731
# Austin => Austin
# East 6th Street => East 6th Street
# 78702 => 78702
# West 2nd Street => West 2nd Street
# +1 512 357 4143 => 512-357-4143
# Maxwell => Maxwell
# El Camino Real => El Camino Real
# 78656 => 78656
# 512-447-6633 => 512-447-6633
# Austin => Austin
# Berkeley Avenue => Berkeley Avenue
# 78745 => 78745
# 51224990093 => 512-249-9009
# +1 512-275-0852 => 512-275-0852
# 512-472-2783 => 512-472-2783
# Kyle => Kyle
# Evans Drive => Evans Drive
# 78640 => 78640
# 512-444-0561 => 512-444-0561
# I 35 Frontage Road => Interstate Highway 35 Frontage Road
# Austin => Austin
# Crestone Road => Crestone Road
# Austin => Austin
# Cardin Drive => Cardin Drive
# 78759 => 78759
# Austin => Austin
# Cardin Drive => Cardin Drive
# 78759 => 78759
# Austin => Austin
# Cardin Drive => Cardin Drive
# 78759 => 78759
# Austin => Austin
# Cordero Drive => Cordero Drive
# 78717 => 78717
# (512) 524-1311 => 512-524-1311
# Austin => Austin
# East Cesar Chavez Street => East Cesar Chavez Street
# 78702 => 78702
# Georgetown => Georgetown
# West 7th Street => West 7th Street
# 78626 => 78626
# Austin => Austin
# East Highland Mall Boulevard => East Highland Mall Boulevard
# Airport Boulevard => Airport Boulevard
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# Airport Boulevard => Airport Boulevard
# Tirado Street => Tirado Street
# Middle Fiskville Road => Middle Fiskville Road
# Delmar Avenue => Delmar Avenue
# East Saint John's Avenue => East Saint John's Avenue
# Blackson Avenue => Blackson Avenue
# Delmar Avenue => Delmar Avenue
# Delmar Avenue => Delmar Avenue
# Eastcrest Drive => Eastcrest Drive
# I 35 Frontage Road => Interstate Highway 35 Frontage Road
# East Huntland Drive => East Huntland Drive
# Kenniston Drive => Kenniston Drive
# West Saint John's Avenue => West Saint John's Avenue
# Airport Boulevard => Airport Boulevard
# West Saint John's Avenue => West Saint John's Avenue
# Nelray Boulevard => Nelray Boulevard
# East 53rd Street => East 53rd Street
# East Koenig Lane => East Koenig Lane
# Duval Street => Duval Street
# Middle Fiskville Road => Middle Fiskville Road
# Middle Fiskville Road => Middle Fiskville Road
# East 53rd Street => East 53rd Street
# East 53rd Street => East 53rd Street
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# Airport Boulevard => Airport Boulevard
# East 53rd Street => East 53rd Street
# Jekel Circle => Jekel Circle
# Jekel Circle => Jekel Circle
# Pecan Street => Pecan Street
# Pecan Street => Pecan Street
# Technology Boulevard => Technology Boulevard
# Blackfoot Trail => Blackfoot Trail
# Mc Neil Drive => Mc Neil Drive
# Mc Neil Drive => Mc Neil Drive
# Jesse E. Segovia Street => Jesse East Segovia Street
# Holly Street => Holly Street
# Riverview Street => Riverview Street
# Haskell Street => Haskell Street
# Holly Street => Holly Street
# Riverview Street => Riverview Street
# Holly Street => Holly Street
# Canterbury Street => Canterbury Street
# Anthony Street => Anthony Street
# Potters Trail => Potters Trail
# Mc Neil Drive => Mc Neil Drive
# Dallas Drive => Dallas Drive
# East North Loop Boulevard => East North Loop Boulevard
# East North Loop Boulevard => East North Loop Boulevard
# East North Loop Boulevard => East North Loop Boulevard
# Nelray Boulevard => Nelray Boulevard
# North Lamar Boulevard => North Lamar Boulevard
# Genard Street => Genard Street
# Nelray Boulevard => Nelray Boulevard
# Clermont Avenue => Clermont Avenue
# Flores Street => Flores Street
# Haskell Street => Haskell Street
# Haskell Street => Haskell Street
# Holly Street => Holly Street
# Haskell Street => Haskell Street
# Haskell Street => Haskell Street
# Riverview Street => Riverview Street
# Riverview Street => Riverview Street
# Waller Street => Waller Street
# Waller Street => Waller Street
# Clermont Avenue => Clermont Avenue
# Research Boulevard => Research Boulevard
# Brentwood Street => Brentwood Street
# Guadalupe Street => Guadalupe Street
# Dillard Circle => Dillard Circle
# Bitter Creek Drive => Bitter Creek Drive
# Bitter Creek Drive => Bitter Creek Drive
# Bitter Creek Drive => Bitter Creek Drive
# Bitter Creek Drive => Bitter Creek Drive
# Bitter Creek Drive => Bitter Creek Drive
# Bucks Run => Bucks Run
# Elm Creek Drive => Elm Creek Drive
# Commodore Circle => Commodore Circle
# Branchwood Drive => Branchwood Drive
# Commodore Circle => Commodore Circle
# Commodore Circle => Commodore Circle
# Dillard Circle => Dillard Circle
# East Koenig Lane => East Koenig Lane
# Burns Street => Burns Street
# North Lamar Boulevard => North Lamar Boulevard
# North Lamar Boulevard => North Lamar Boulevard
# Gaylor Street => Gaylor Street
# West Croslin Street => West Croslin Street
# Morrow Street => Morrow Street
# North Lamar Boulevard => North Lamar Boulevard
# North Lamar Boulevard => North Lamar Boulevard
# Woodland Avenue => Woodland Avenue
# Alameda Drive => Alameda Drive
# 78704 => 78704
# Alameda Drive => Alameda Drive
# 78704 => 78704
# Kenwood Avenue => Kenwood Avenue
# 78704 => 78704
# Alta Vista Avenue => Alta Vista Avenue
# East Live Oak Street => East Live Oak Street
# Dillard Circle => Dillard Circle
# Northland Drive => Northland Drive
# Bull Creek Road => Bull Creek Road
# East Cesar Chavez Street => East Cesar Chavez Street
# East Cesar Chavez Street => East Cesar Chavez Street
# Garden Street => Garden Street
# Canterbury Street => Canterbury Street
# Canterbury Street => Canterbury Street
# Canterbury Street => Canterbury Street
# Canterbury Street => Canterbury Street
# East Cesar Chavez Street => East Cesar Chavez Street
# East Cesar Chavez Street => East Cesar Chavez Street
# Willow Street => Willow Street
# East Cesar Chavez Street => East Cesar Chavez Street
# Lynn Street => Lynn Street
# Pedernales Street => Pedernales Street
# Garden Street => Garden Street
# East Cesar Chavez Street => East Cesar Chavez Street
# East Cesar Chavez Street => East Cesar Chavez Street
# Spence Street => Spence Street
# Lambie Street => Lambie Street
# Taylor Street => Taylor Street
# Canterbury Street => Canterbury Street
# Taylor Street => Taylor Street
# Garden Street => Garden Street
# Garden Street => Garden Street
# Garden Street => Garden Street
# Holly Street => Holly Street
# Comal Street => Comal Street
# San Marcos Street => San Marcos Street
# Spence Street => Spence Street
# Taylor Street => Taylor Street
# Navasota Street => Navasota Street
# Willow Street => Willow Street
# Canterbury Street => Canterbury Street
# Garden Street => Garden Street
# Canterbury Street => Canterbury Street
# Holly Street => Holly Street
# East Cesar Chavez Street => East Cesar Chavez Street
# Canterbury Street => Canterbury Street
# Garden Street => Garden Street
# Willow Street => Willow Street
# Canterbury Street => Canterbury Street
# Willow Street => Willow Street
# East Cesar Chavez Street => East Cesar Chavez Street
# Navasota Street => Navasota Street
# Caswell Avenue => Caswell Avenue
# Eilers Avenue => Eilers Avenue
# Caswell Avenue => Caswell Avenue
# East 48th Street => East 48th Street
# Evans Avenue => Evans Avenue
# Eilers Avenue => Eilers Avenue
# East 49th Street => East 49th Street
# East 45th Street => East 45th Street
# Palma Circle => Palma Circle
# Espinosa Drive => Espinosa Drive
# Olmos Drive => Olmos Drive
# La Posada Drive => La Posada Drive
# La Posada Drive => La Posada Drive
# Hoeke Lane => Hoeke Lane
# La Posada Drive => La Posada Drive
# Palomino Trail => Palomino Trail
# Palomino Trail => Palomino Trail
# Palma Circle => Palma Circle
# McCall Lane => McCall Lane
# Autumn Bay Drive => Autumn Bay Drive
# Breckenridge Drive => Breckenridge Drive
# Breckenridge Drive => Breckenridge Drive
# Bronco Bend Loop => Bronco Bend Loop
# Breckenridge Drive => Breckenridge Drive
# Breckenridge Drive => Breckenridge Drive
# Breckenridge Drive => Breckenridge Drive
# Breckenridge Drive => Breckenridge Drive
# Autumn Bay Drive => Autumn Bay Drive
# Breckenridge Drive => Breckenridge Drive
# Palma Circle => Palma Circle
# Creede Drive => Creede Drive
# Creede Drive => Creede Drive
# Olmos Drive => Olmos Drive
# Metropolis Drive => Metropolis Drive
# East Ben White Boulevard => East Ben White Boulevard
# Crestone Road => Crestone Road
# Crestone Road => Crestone Road
# Crestone Road => Crestone Road
# Crestone Road => Crestone Road
# Burleson Road => Burleson Road
# Crestone Road => Crestone Road
# Metropolis Drive => Metropolis Drive
# Crestone Road => Crestone Road
# Crestone Road => Crestone Road
# Outfitter Drive => Outfitter Drive
# South Glenn Street => South Glenn Street
# East Ben White Boulevard => East Ben White Boulevard
# Metro Center Drive => Metro Center Drive
# East Riverside Drive => East Riverside Drive
# Metropolis Drive => Metropolis Drive
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# Willow Street => Willow Street
# Rainey Street => Rainey Street
# Davis Street => Davis Street
# East Avenue => East Avenue
# Lambie Street => Lambie Street
# Rainey Street => Rainey Street
# Red River Street => Red River Street
# Roxie Drive => Roxie Drive
# Pond Springs Road => Pond Springs Road
# Austin => Austin
# West 22nd Street => West 22nd Street
# 78705 => 78705
# Austin => Austin
# Robbins Place => Robbins Place
# 78705 => 78705
# Austin => Austin
# Shoal Creek Boulevard => Shoal Creek Boulevard
# 78705 => 78705
# Austin => Austin
# San Gabriel Street => San Gabriel Street
# 78705 => 78705
# Austin => Austin
# Rio Grande Street => Rio Grande Street
# 78705 => 78705
# Austin => Austin
# West 23rd Street => West 23rd Street
# 78705 => 78705
# Austin => Austin
# West 22nd Street => West 22nd Street
# 78705 => 78705
# Austin => Austin
# West 21st Street => West 21st Street
# 78705 => 78705
# Austin => Austin
# West 21st Street => West 21st Street
# 78705 => 78705
# Austin => Austin
# Pearl Street => Pearl Street
# 78705 => 78705
# Austin => Austin
# Pearl Street => Pearl Street
# 78705 => 78705
# Austin => Austin
# West 25th Street => West 25th Street
# 78705 => 78705
# Austin => Austin
# West 25th Street => West 25th Street
# 78705 => 78705
# Austin => Austin
# Rio Grande Street => Rio Grande Street
# 78705 => 78705
# Austin => Austin
# San Antonio Street => San Antonio Street
# 78705 => 78705
# Austin => Austin
# Rio Grande Street => Rio Grande Street
# 78705 => 78705
# Austin => Austin
# Guadalupe Street => Guadalupe Street
# 78705 => 78705
# Austin => Austin
# San Antonio Street => San Antonio Street
# 78705 => 78705
# Austin => Austin
# Nueces Street => Nueces Street
# 78705 => 78705
# Austin => Austin
# San Antonio Street => San Antonio Street
# 78705 => 78705
# Austin => Austin
# West 23rd Street => West 23rd Street
# 78705 => 78705
# Austin => Austin
# West 22nd Street => West 22nd Street
# 78705 => 78705
# La Calma Drive => La Calma Drive
# 78752 => 78752
# Cameron Road => Cameron Road
# 78752 => 78752
# I 35 Frontage Road => Interstate Highway 35 Frontage Road
# 78752 => 78752
# Morrow Street => Morrow Street
# 78757 => 78757
# Morrow Street => Morrow Street
# 78757 => 78757
# Sugaree Avenue => Sugaree Avenue
# 78757 => 78757
# Morrow Street => Morrow Street
# 78757 => 78757
# West Anderson Lane => West Anderson Lane
# 78757 => 78757
# Easy Wind Drive => Easy Wind Drive
# 78757 => 78757
# Wolverine Street => Wolverine Street
# 78757 => 78757
# Wildcat Pass => Wildcat Pass
# 78757 => 78757
# Wolverine Street => Wolverine Street
# 78757 => 78757
# Wolverine Street => Wolverine Street
# 78757 => 78757
# Pantherpaw Street => Pantherpaw Street
# 78757 => 78757
# Wolverine Street => Wolverine Street
# 78757 => 78757
# Wildcat Pass => Wildcat Pass
# 78757 => 78757
# Easy Wind Drive => Easy Wind Drive
# 78757 => 78757
# Pantherpaw Street => Pantherpaw Street
# 78757 => 78757
# Wildcat Pass => Wildcat Pass
# 78757 => 78757
# Wildcat Pass => Wildcat Pass
# 78757 => 78757
# Pantherpaw Street => Pantherpaw Street
# 78757 => 78757
# Wildcat Pass => Wildcat Pass
# 78757 => 78757
# North Lamar Boulevard => North Lamar Boulevard
# 78757 => 78757
# Wildcat Pass => Wildcat Pass
# 78757 => 78757
# Wolverine Street => Wolverine Street
# 78757 => 78757
# North Lamar Boulevard => North Lamar Boulevard
# 78757 => 78757
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78751 => 78751
# East 45th Street => East 45th Street
# 78751 => 78751
# East 52nd Street => East 52nd Street
# 78751 => 78751
# Karen Avenue => Karen Avenue
# 78757 => 78757
# Grover Avenue => Grover Avenue
# 78757 => 78757
# Brentwood Street => Brentwood Street
# 78757 => 78757
# Barrow Avenue => Barrow Avenue
# 78751 => 78751
# East 41st Street => East 41st Street
# 78751 => 78751
# East 41st Street => East 41st Street
# 78751 => 78751
# Wood Hollow Drive => Wood Hollow Drive
# 78731 => 78731
# East 45th Street => East 45th Street
# 78751 => 78751
# Duval Street => Duval Street
# 78751 => 78751
# Speedway => Speedway
# 78751 => 78751
# Avenue F => Avenue F
# 78751 => 78751
# Towne Park Trail => Towne Park Trail
# 78751 => 78751
# Duval Street => Duval Street
# 78751 => 78751
# East 43rd Street => East 43rd Street
# 78751 => 78751
# Avenue G => Avenue G
# 78751 => 78751
# Towne Park Trail => Towne Park Trail
# 78751 => 78751
# Towne Park Trail => Towne Park Trail
# 78751 => 78751
# Avenue H => Avenue H
# 78751 => 78751
# Summit Bend => Summit Bend
# 78759 => 78759
# Steck Avenue => Steck Avenue
# 78759 => 78759
# Bayberry Drive => Bayberry Drive
# 78759 => 78759
# Bayberry Drive => Bayberry Drive
# 78759 => 78759
# Raintree Place => Raintree Place
# 78759 => 78759
# East Court => East Court
# 78759 => 78759
# Baywood Drive => Baywood Drive
# 78759 => 78759
# Middle Court => Middle Court
# 78759 => 78759
# East Court => East Court
# 78759 => 78759
# Middle Court => Middle Court
# 78759 => 78759
# Forest Mesa Drive => Forest Mesa Drive
# 78759 => 78759
# Middle Court => Middle Court
# 78759 => 78759
# Middle Court => Middle Court
# 78759 => 78759
# Middle Court => Middle Court
# 78759 => 78759
# Greenslope Drive => Greenslope Drive
# 78759 => 78759
# Forest Mesa Drive => Forest Mesa Drive
# 78759 => 78759
# Forest Mesa Drive => Forest Mesa Drive
# 78759 => 78759
# Forest Mesa Drive => Forest Mesa Drive
# 78759 => 78759
# Greenslope Drive => Greenslope Drive
# 78759 => 78759
# Meandering Way => Meandering Way
# 78759 => 78759
# East 40th Street => East 40th Street
# 78751 => 78751
# East 41st Street => East 41st Street
# 78751 => 78751
# Bennett Avenue => Bennett Avenue
# 78751 => 78751
# East 40th Street => East 40th Street
# 78751 => 78751
# Broadview Street => Broadview Street
# 78723 => 78723
# Cameron Road => Cameron Road
# 78723 => 78723
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78723 => 78723
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78723 => 78723
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78723 => 78723
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78723 => 78723
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78723 => 78723
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78723 => 78723
# Cameron Road => Cameron Road
# 78723 => 78723
# Burnet Road => Burnet Road
# 78757 => 78757
# Burnet Road => Burnet Road
# 78757 => 78757
# West Anderson Lane => West Anderson Lane
# 78757 => 78757
# East 40th Street => East 40th Street
# 78722 => 78722
# Cherrywood Road => Cherrywood Road
# 78722 => 78722
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78722 => 78722
# Airport Boulevard => Airport Boulevard
# 78722 => 78722
# Pegram Avenue => Pegram Avenue
# 78757 => 78757
# Cary Drive => Cary Drive
# 78757 => 78757
# Burnet Road => Burnet Road
# 78757 => 78757
# Burnet Road => Burnet Road
# 78757 => 78757
# Philomena Street => Philomena Street
# 78723 => 78723
# East 51st Street => East 51st Street
# 78723 => 78723
# Simond Avenue => Simond Avenue
# 78723 => 78723
# Zach Scott Street => Zach Scott Street
# 78723 => 78723
# Anchor Lane => Anchor Lane
# 78723 => 78723
# Zach Scott Street => Zach Scott Street
# 78723 => 78723
# Robert Browning Street => Robert Browning Street
# 78723 => 78723
# Zach Scott Street => Zach Scott Street
# 78723 => 78723
# Zach Scott Street => Zach Scott Street
# 78723 => 78723
# Zach Scott Street => Zach Scott Street
# 78723 => 78723
# Zach Scott Street => Zach Scott Street
# 78723 => 78723
#
# 78757 => 78757
# Burnet Road => Burnet Road
# 78757 => 78757
# Burnet Road => Burnet Road
# 78757 => 78757
# Burnet Lane => Burnet Lane
# 78757 => 78757
# North Loop Boulevard => North Loop Boulevard
# 78756 => 78756
# Lawnmont Avenue => Lawnmont Avenue
# 78756 => 78756
# Burnet Road => Burnet Road
# 78756 => 78756
# Burnet Road => Burnet Road
# 78756 => 78756
# Burnet Road => Burnet Road
# 78756 => 78756
# Burnet Road => Burnet Road
# 78756 => 78756
# Burnet Road => Burnet Road
# 78756 => 78756
# Speedway => Speedway
# 78751 => 78751
# Avenue D => Avenue D
# 78751 => 78751
# Guadalupe Street => Guadalupe Street
# 78751 => 78751
# West 41st Street => West 41st Street
# 78751 => 78751
# West Koenig Lane => West Koenig Lane
# 78756 => 78756
# Sunshine Drive => Sunshine Drive
# 78756 => 78756
# North Lamar Boulevard => North Lamar Boulevard
# 78756 => 78756
# Sunshine Drive => Sunshine Drive
# 78756 => 78756
# Woodrow Avenue => Woodrow Avenue
# 78756 => 78756
# Houston Street => Houston Street
# 78756 => 78756
# Concordia Avenue => Concordia Avenue
# 78705 => 78705
# East 32nd Street => East 32nd Street
# 78705 => 78705
# Red River Street => Red River Street
# 78705 => 78705
# Robert Dedman Drive => Robert Dedman Drive
# 78712 => 78712
# Red River Street => Red River Street
# 78712 => 78712
# Trinity Street => Trinity Street
# 78705 => 78705
# Swisher Street => Swisher Street
# 78705 => 78705
# East Martin Luther King Jr Boulevard => East Martin Luther King Jr Boulevard
# 78712 => 78712
# Kim Lane => Kim Lane
# 78705 => 78705
# North Interstate Highway 35 Service Road => North Interstate Highway 35 Service Road
# 78705 => 78705
# Harmon Avenue => Harmon Avenue
# 78705 => 78705
# East 20th Street => East 20th Street
# 78712 => 78712
# East 32nd Street => East 32nd Street
# 78705 => 78705
# East Dean Keeton Street => East Dean Keeton Street
# 78705 => 78705
# East 32nd Street => East 32nd Street
# 78705 => 78705
# Keith Lane => Keith Lane
# 78705 => 78705
# West 45th Street => West 45th Street
# 78756 => 78756
# North Lamar Boulevard => North Lamar Boulevard
# 78751 => 78751
# Grover Avenue => Grover Avenue
# 78756 => 78756
# West 47th Street => West 47th Street
# 78751 => 78751
# North Loop Boulevard => North Loop Boulevard
# 78756 => 78756
# Burnet Road => Burnet Road
# 78756 => 78756
# Burnet Road => Burnet Road
# 78756 => 78756
# Jim Hogg Avenue => Jim Hogg Avenue
# 78756 => 78756
# Guadalupe Street => Guadalupe Street
# 78701 => 78701
# Trinity Street => Trinity Street
# 78701 => 78701
# Colorado Street => Colorado Street
# 78701 => 78701
# Red River Street => Red River Street
# 78701 => 78701
# West 2nd Street => West 2nd Street
# 78701 => 78701
# East 6th Street => East 6th Street
# 78701 => 78701
# Brazos Street => Brazos Street
# 78701 => 78701
# East 2nd Street => East 2nd Street
# 78701 => 78701
# Red River Street => Red River Street
# 78701 => 78701
# East 5th Street => East 5th Street
# 78701 => 78701
# Red River Street => Red River Street
# 78701 => 78701
# East 5th Street => East 5th Street
# 78701 => 78701
# West 6th Street => West 6th Street
# 78701 => 78701
# East 10th Street => East 10th Street
# 78701 => 78701
# East 4th Street => East 4th Street
# 78701 => 78701
# West 5th Street => West 5th Street
# 78701 => 78701
# West 4th Street => West 4th Street
# 78701 => 78701
# Nueces Street => Nueces Street
# 78701 => 78701
# West Cesar Chavez Street => West Cesar Chavez Street
# 78701 => 78701
# East 2nd Street => East 2nd Street
# 78701 => 78701
# West 9th Street => West 9th Street
# 78701 => 78701
# West 4th Street => West 4th Street
# 78701 => 78701
# West 3rd Street => West 3rd Street
# 78701 => 78701
# Congress Avenue => Congress Avenue
# 78701 => 78701
# 78739 => 78739
# Black Hills Drive => Black Hills Drive
# 78739 => 78739
# Black Hills Drive => Black Hills Drive
# 78739 => 78739
# Black Hills Drive => Black Hills Drive
# 78739 => 78739
# Bismark Drive => Bismark Drive
# 78739 => 78739
# Bismark Drive => Bismark Drive
# 78739 => 78739
# Bismark Drive => Bismark Drive
# 78739 => 78739
# Fencerail Road => Fencerail Road
# 78652 => 78652
# Turkey Roost Road => Turkey Roost Road
# 78652 => 78652
# Claret Cove => Claret Cove
# 78739 => 78739
# Bear Springs Trail => Bear Springs Trail
# 78739 => 78739
# Bliss Spillar Road => Bliss Spillar Road
# 78652 => 78652
# Bear Springs Trail => Bear Springs Trail
# 78739 => 78739
# Edwards Hollow Cove => Edwards Hollow Cove
# 78739 => 78739
# Green Emerald Terrace => Green Emerald Terrace
# 78739 => 78739
# Bliss Spillar Road => Bliss Spillar Road
# 78652 => 78652
# Bliss Spillar Road => Bliss Spillar Road
# 78652 => 78652
# Bliss Spillar Road => Bliss Spillar Road
# 78652 => 78652
# Baggins Cove => Baggins Cove
# 78739 => 78739
# Bliss Spillar Road => Bliss Spillar Road
# 78652 => 78652
# Lost Oasis Hollow => Lost Oasis Hollow
# 78739 => 78739
# Wyldwood Road => Wyldwood Road
# 78739 => 78739
# Wyldwood Road => Wyldwood Road
# 78739 => 78739
# Mitra Drive => Mitra Drive
# 78739 => 78739
# Mitra Drive => Mitra Drive
# 78739 => 78739
# Mitra Drive => Mitra Drive
# 78739 => 78739
# Mitra Drive => Mitra Drive
# 78739 => 78739
# Farm-to-Market Road 973 => Farm-to-Market Road 973
# 78617 => 78617
# Meadowild Cove => Meadowild Cove
# 78664 => 78664
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Old Lockhart Highway => Old Lockhart Highway
# 78747 => 78747
# Old Lockhart Highway => Old Lockhart Highway
# 78747 => 78747
# Old Lockhart Highway => Old Lockhart Highway
# 78747 => 78747
# Baythorne Drive => Baythorne Drive
# 78747 => 78747
# Baythorne Drive => Baythorne Drive
# 78747 => 78747
# Baythorne Drive => Baythorne Drive
# 78747 => 78747
# Quinton Drive => Quinton Drive
# 78747 => 78747
# Quinton Drive => Quinton Drive
# 78747 => 78747
# Baythorne Drive => Baythorne Drive
# 78747 => 78747
# Sabrina Drive => Sabrina Drive
# 78747 => 78747
# Springtime Trail => Springtime Trail
# 78747 => 78747
# Marble Ridge Drive => Marble Ridge Drive
# 78747 => 78747
# Forbsdale Drive => Forbsdale Drive
# 78747 => 78747
# Thaxton Road => Thaxton Road
# 78747 => 78747
# Thaxton Road => Thaxton Road
# 78744 => 78744
# Panadero Drive => Panadero Drive
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Panadero Drive => Panadero Drive
# 78747 => 78747
# Panadero Drive => Panadero Drive
# 78747 => 78747
# Alum Rock Drive => Alum Rock Drive
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Alum Rock Drive => Alum Rock Drive
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Wiley Way => Wiley Way
# 78747 => 78747
# Edmundsbury Drive => Edmundsbury Drive
# 78747 => 78747
# Wiley Way => Wiley Way
# 78747 => 78747
# Thaxton Road => Thaxton Road
# 78747 => 78747
# Stambourne Street => Stambourne Street
# 78747 => 78747
# Wiley Way => Wiley Way
# 78747 => 78747
# Wiley Way => Wiley Way
# 78747 => 78747
# Stambourne Street => Stambourne Street
# 78747 => 78747
# Winter Haven Road => Winter Haven Road
# 78747 => 78747
# Edmundsbury Drive => Edmundsbury Drive
# 78747 => 78747
# Thaxton Road => Thaxton Road
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Cheryl Lynn Road => Cheryl Lynn Road
# 78747 => 78747
# Thaxton Road => Thaxton Road
# 78747 => 78747
# Capitol View Drive => Capitol View Drive
# 78747 => 78747
# Pascal Lane => Pascal Lane
# 78746 => 78746
# Weston Lane North => Weston Lane North
# 78733 => 78733
# Pascal Lane => Pascal Lane
# 78746 => 78746
# Lowell Lane North => Lowell Lane North
# 78733 => 78733
# Exton Cove => Exton Cove
# 78733 => 78733
# Wild Basin Road => Wild Basin Road
# 78746 => 78746
# Pascal Lane => Pascal Lane
# 78746 => 78746
# Cousteau Lane => Cousteau Lane
# 78746 => 78746
# Saint Stephen's School Road => Saint Stephen's School Road
# 78746 => 78746
# Weston Lane North => Weston Lane North
# 78733 => 78733
# Hedge Lane => Hedge Lane
# 78746 => 78746
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Coleridge Lane => Coleridge Lane
# 78746 => 78746
# Lowell Lane North => Lowell Lane North
# 78733 => 78733
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Hillbilly Lane => Hillbilly Lane
# 78746 => 78746
# Bunny Run => Bunny Run
# 78746 => 78746
# Bunny Run => Bunny Run
# 78746 => 78746
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Capital of Texas Highway => Capital of Texas Highway
# 78746 => 78746
# Hunterwood Point => Hunterwood Point
# 78746 => 78746
# Weston Lane North => Weston Lane North
# 78733 => 78733
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Bunny Run => Bunny Run
# 78746 => 78746
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Rivercrest Drive => Rivercrest Drive
# 78746 => 78746
# Bunny Run => Bunny Run
# 78746 => 78746
# Weston Lane North => Weston Lane North
# 78733 => 78733
# Saint Stephen's School Road => Saint Stephen's School Road
# 78746 => 78746
# Liveoak Drive => Liveoak Drive
# 78746 => 78746
# Bridge Hill Cove => Bridge Hill Cove
# 78746 => 78746
# Austin => Austin
# Stone River Drive => Stone River Drive
# Windcrest Drive => Windcrest Drive
# 78664 => 78664
# Muirfield Bend Drive => Muirfield Bend Drive
# 78664 => 78664
# Maple Vista Drive => Maple Vista Drive
# 78660 => 78660
# Oak Vista Drive => Oak Vista Drive
# 78660 => 78660
# Heatherwilde Boulevard => Heatherwilde Boulevard
# 78664 => 78664
# Needle Pine Drive => Needle Pine Drive
# 78664 => 78664
# Maple Vista Drive => Maple Vista Drive
# 78660 => 78660
# Palm Vista Drive => Palm Vista Drive
# 78660 => 78660
# Oak Vista Drive => Oak Vista Drive
# 78660 => 78660
# Maple Vista Drive => Maple Vista Drive
# 78660 => 78660
# Pine Vista Drive => Pine Vista Drive
# 78660 => 78660
# Apple Vista Circle => Apple Vista Circle
# 78660 => 78660
# Gattis School Road => Gattis School Road
# 78664 => 78664
# Priem Lane => Priem Lane
# 78664 => 78664
# Austin => Austin
# Swallowtail Drive => Swallowtail Drive
# Austin => Austin
# Swallowtail Drive => Swallowtail Drive
# Austin => Austin
# Firefall Lane => Firefall Lane
# Hamann Lane => Hamann Lane
# 78653 => 78653
# Richland Road => Richland Road
# 78615 => 78615
# Farm-to-Market Road 973 => Farm-to-Market Road 973
# 78653 => 78653
# Saint Therese Road => Saint Therese Road
# 78653 => 78653
# Cameron Road => Cameron Road
# 78653 => 78653
# Cameron Road => Cameron Road
# 78653 => 78653
# Farm-to-Market Road 973 => Farm-to-Market Road 973
# 78653 => 78653
# Engelmann Lane => Engelmann Lane
# 78653 => 78653
# Engelmann Lane => Engelmann Lane
# 78615 => 78615
# Cameron Road => Cameron Road
# 78653 => 78653
# Burr Oak Drive => Burr Oak Drive
# 78615 => 78615
# Cameron Road => Cameron Road
# 78615 => 78615
# Cameron Road => Cameron Road
# 78615 => 78615
# Cameron Road => Cameron Road
# 78615 => 78615
# Cameron Road => Cameron Road
# 78615 => 78615
# Melber Lane => Melber Lane
# 78653 => 78653
# Schmidt Lane => Schmidt Lane
# 78653 => 78653
# Old Bastrop Road => Old Bastrop Road
# 78612 => 78612
# Fallwell Lane => Fallwell Lane
# 78617 => 78617
# Citation Circle => Citation Circle
# 78617 => 78617
# Citation Circle => Citation Circle
# 78617 => 78617
# Man O War Drive => Man O War Drive
# 78617 => 78617
# Caldwell Lane => Caldwell Lane
# 78617 => 78617
# River Timber Drive => River Timber Drive
# 78617 => 78617
# Whirlaway Drive => Whirlaway Drive
# 78617 => 78617
# Whirlaway Drive => Whirlaway Drive
# 78617 => 78617
# Man O War Drive => Man O War Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Whirlaway Drive => Whirlaway Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Citation Drive => Citation Drive
# 78617 => 78617
# Whirlaway Drive => Whirlaway Drive
# 78617 => 78617
# Caldwell Lane => Caldwell Lane
# 78617 => 78617
# Michoacan Drive => Michoacan Drive
# 78617 => 78617
# Mary Street => Mary Street
# 78617 => 78617
# Mary Street => Mary Street
# 78617 => 78617
# Norwood Lane => Norwood Lane
# 78617 => 78617
# Bessie Avenue => Bessie Avenue
# 78617 => 78617
# Buck Lane => Buck Lane
# 78617 => 78617
# Victorine Lane => Victorine Lane
# 78617 => 78617
# River Road => River Road
# 78612 => 78612
# Buck Lane => Buck Lane
# 78617 => 78617
# River Road => River Road
# 78612 => 78612
# Houston Road => Houston Road
# 78617 => 78617
# Houston Road => Houston Road
# 78617 => 78617
# Caldwell Lane => Caldwell Lane
# 78617 => 78617
# Burch Drive => Burch Drive
# 78617 => 78617
# Buck Lane => Buck Lane
# 78617 => 78617
# Burch Drive => Burch Drive
# 78617 => 78617
# Albert Brown Drive => Albert Brown Drive
# 78617 => 78617
# West 45th Street => West 45th Street
# 78751 => 78751
# Guadalupe Street => Guadalupe Street
# 78751 => 78751
# Guadalupe Street => Guadalupe Street
# 78751 => 78751
# West 51st Street => West 51st Street
# 78751 => 78751
# West Walter Avenue => West Walter Avenue
# 78660 => 78660
# Rendova Lane => Rendova Lane
# 78660 => 78660
# West Walter Avenue => West Walter Avenue
# 78660 => 78660
# Bellaire Oaks Drive => Bellaire Oaks Drive
# 78660 => 78660
# South Railroad Avenue => South Railroad Avenue
# 78660 => 78660
# Olympic Drive => Olympic Drive
# 78660 => 78660
# (512) 246-7645 => 512-246-7645
# Austin => Austin
# Avery Ranch Blvd Building A #100 => Avery Ranch Boulevard Building A #100
# 78717 => 78717
# Greystone Drive => Greystone Drive
# 78731 => 78731
# Greystone Drive => Greystone Drive
# 78731 => 78731
# Greystone Drive => Greystone Drive
# 78731 => 78731
# Shadow Hill Drive => Shadow Hill Drive
# 78731 => 78731
# Austin => Austin
# East Cesar Chavez Street => East Cesar Chavez Street
# 78702 => 78702
# Interstate Highway 35 Service Road => Interstate Highway 35 Service Road
# San Gabriel Village Boulevard => Georgetown
# Rio Grande Street => Rio Grande Street
# West Anderson Lane => West Anderson Lane
# 78757 => 78757
# Pflugerville => Pflugerville
# 78660 => 78660
# Grail Hollows Cove => Grail Hollows Cove
# Austin => Austin
# 78754 => 78754
# Dessau Road => Dessau Road
# Austin => Austin
# 78746 => 78746
# South MoPac Expressway => South MoPac Expressway
# Austin => Austin
# 78750 => 78750
# Research Blvd #L2 => Research Boulevard #L2
# 512-358-4379 => 512-358-4379
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-070bf38c562d> in <module>()
#       1 counter = 0
# ----> 2 for element in get_element(SAMPLE_FILE):
#       3     if counter == 1:
#       4         break
#       5     if element.tag == 'node':
#
# <ipython-input-2-92e0ee91b6fe> in get_element(osm_file, tags)
#       4     context = ET.iterparse(osm_file, events=('start', 'end'))
#       5     _, root = next(context)
# ----> 6     for event, elem in context:
#       7         if event == 'end' and elem.tag in tags:
#       8             yield elem
#
# KeyboardInterrupt:
